# %%
from data_gatherer.data_gatherer import DataGatherer

# %% [markdown]
# Instantiate DataGatherer orchestrator with the desired LLM and log level.

# %%
data_gatherer = DataGatherer(llm_name="gemini-2.0-flash", log_level="ERROR")

# %%
data_gatherer.setup_data_fetcher()

# %%
input_article = "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466"

# %%
parsed_data = data_gatherer.process_url(input_article)

# %%
parsed_data
# Out:
#    dataset_identifier data_repository  \
# 0           PHS001049           dbGAP
# 1         PRJNA306801             SRA
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# 5                 NaN             NaN
# 6                 NaN             NaN
# 7                 NaN             NaN
# 8                 NaN             NaN
# 9                 NaN             NaN
# 10                NaN             NaN
# 11                NaN             NaN
# 12                NaN             NaN
# 13                NaN             NaN
# 14                NaN             NaN
#
#                                       dataset_webpage          source_section  \
# 0   https://www.ncbi.nlm.nih.gov/projects/gap/cgi-...       data_availability
# 1   https://www.ncbi.nlm.nih.gov/bioproject/?term=...       data_availability
# ...
