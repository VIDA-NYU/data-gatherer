# %%
from data_gatherer.orchestrator import Orchestrator

# %%
data_gatherer = Orchestrator()
# Out:
# orchestrator.py - line 72 - INFO - Data_Gatherer Orchestrator initialized. Extraction Model: gpt-4o-mini

# %%
input_urls = ["https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11252349/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11320025/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11066909/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11352417/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10855131/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11129317/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11423856/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11015306/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11062922/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11208500/","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10972747","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10982990","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8628860","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5313262","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4836692","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4915822","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11061608","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5460863","https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9506422"]

input_url = input_urls[2]

# %%
raw_data = data_gatherer.fetch_data(input_url, write_htmls_xmls=True, html_xml_dir='tmp/html_xmls/')
raw_data
# Out:
# orchestrator.py - line 179 - INFO - Setting up data fetcher...
# orchestrator.py - line 207 - INFO - Data fetcher setup completed.
# orchestrator.py - line 115 - INFO - Fetching data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/
# data_fetcher.py - line 95 - INFO - Initializing APIClient(('requests', 'PMC_API', 'self.config'))
# data_fetcher.py - line 567 - INFO - Fetching data from request: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=PMC11425778&retmode=xml
# orchestrator.py - line 123 - INFO - Raw Data is XML.
# data_fetcher.py - line 624 - INFO - File already exists: tmp/html_xmls/PMC/Proteomics Analysis of Interactions between Drug-Resistant and Drug-Sensitive Cancer Cells: Comparative Studies of Monoculture and Coculture Cell Systems.xml. Skipping download.
# orchestrator.py - line 129 - INFO - Raw XML saved in tmp/html_xmls/PMC/ directory
# ...

# %%
for key, value in raw_data.items():
    informative = data_gatherer.raw_data_contains_required_sections(value, key, ["data_availability", "supplementary_data"])
    print(f"PMC API Response for article at {key} is complete: {informative}")
# Out:
# data_fetcher.py - line 721 - INFO - ----Checking for data_availability_sections section in raw data.
# data_fetcher.py - line 698 - INFO - Missing section in XML: data_availability_sections
# PMC API Response for article at https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/ is complete: False

# %%
raw_data = data_gatherer.fetch_data(input_url, HTML_fallback=True)
print(f"raw_data fetched for {len(raw_data.values())} input url")
# Out:
# orchestrator.py - line 179 - INFO - Setting up data fetcher...
# orchestrator.py - line 207 - INFO - Data fetcher setup completed.
# orchestrator.py - line 115 - INFO - Fetching data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/
# data_fetcher.py - line 107 - INFO - WebScraper instance: True
# data_fetcher.py - line 108 - INFO - APIClient instance: False
# data_fetcher.py - line 109 - INFO - scraper_tool attribute: True
# data_fetcher.py - line 111 - INFO - Initializing new selenium driver.
# selenium_setup.py - line 11 - INFO - Creating WebDriver for browser: firefox
# selenium_setup.py - line 41 - INFO - No driver path provided, using GeckoDriverManager to auto-install Firefox driver.
# selenium_setup.py - line 43 - INFO - Using GeckoDriverManager to auto-install Firefox driver <selenium.webdriver.firefox.service.Service object at 0x12ade8dc0>.
# raw_data fetched for 1 input url

# %%
data_cited = data_gatherer.parse_data(raw_data, input_url, full_document_read=False, raw_data_format="full_HTML")
# Out:
# orchestrator.py - line 159 - INFO - Parsing data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/ with publisher: PMC
# parser.py - line 137 - INFO - Parser initialized.
# parser.py - line 517 - INFO - Function call: parse_data(api_data(<class 'str'>), PMC, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/, additional_data, full_HTML)
# parser.py - line 631 - INFO - Chunking the HTML content for the parsing step.
# parser.py - line 907 - INFO - Function_call: extract_href_from_html_supplementary_material(tree, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC11425778/)
# parser.py - line 967 - INFO - Extracted 14 unique supplementary material links from HTML.
# parser.py - line 1630 - INFO - Extracting data availability elements from HTML
# parser.py - line 1641 - INFO - Using selector: section.data-availability-statement
# parser.py - line 1641 - INFO - Using selector: section.associated-data
# ...

# %%
data_cited
# Out:
#   dataset_identifier data_repository  \
# 0       MSV000092944         MassIVE
# 0                NaN             NaN
# 8                NaN             NaN
#
#                                      dataset_webpage  \
# 0  https://massive.ucsd.edu/ProteoSAFe/dataset.js...
# 0                                                NaN
# 8                                                NaN
#
#                                                 link  \
# 0                                                NaN
# 0      https://doi.org/10.1021/acs.jproteome.4c00338
# 8  /articles/instance/11425778/bin/NIHMS2020672-s...
#
#                             title     file_info description source_section  \
# 0                             NaN           NaN         NaN            NaN
# 0   10.1021/acs.jproteome.4c00338           n/a         n/a            n/a
# 8  NIHMS2020672-supplement-SI.pdf  (1.4MB, pdf)         n/a        d67e776
#
#                                  section_class  \
# ...

# %%
results = data_gatherer.process_articles(input_urls[:10])
# Out:
# orchestrator.py - line 416 - INFO - 0th function call: self.process_url(https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/)
# orchestrator.py - line 228 - INFO - Processing URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/
# data_fetcher.py - line 95 - INFO - Initializing APIClient(('requests', 'PMC_API', 'self.config'))
# data_fetcher.py - line 567 - INFO - Fetching data from request: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=PMC6141466&retmode=xml
# orchestrator.py - line 263 - INFO - Raw data fetched from source: PMC_API
# data_fetcher.py - line 721 - INFO - ----Checking for data_availability_sections section in raw data.
# ...

# %%
len(results)
# Out:
# 10
