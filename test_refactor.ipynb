# %%
from data_gatherer.orchestrator import Orchestrator

# %%
data_gatherer = Orchestrator()
# Out:
# orchestrator.py - line 72 - INFO - Data_Gatherer Orchestrator initialized. Extraction Model: gpt-4o-mini

# %%
input_url = "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/"

# %%
raw_data = data_gatherer.fetch_data(input_url)
raw_data
# Out:
# orchestrator.py - line 163 - INFO - Setting up data fetcher...
# orchestrator.py - line 191 - INFO - Data fetcher setup completed.
# orchestrator.py - line 110 - INFO - Fetching data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/
# data_fetcher.py - line 95 - INFO - Initializing APIClient(('requests', 'PMC_API', 'self.config'))
# data_fetcher.py - line 566 - INFO - Fetching data from request: https://www.ncbi.nlm.nih.gov/pmc/utils/oa/oa.fcgi?format=xml&article_id=PMC6141466
# {'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/': <Element OA at 0x10ff89ec0>}

# %%
for key, value in raw_data.items():
    informative = data_gatherer.raw_data_contains_required_sections(value, key, ["data_availability", "supplementary_data"])
    print(f"PMC API Response for article at {key} is complete: {informative}")
# Out:
# data_fetcher.py - line 714 - INFO - ----Checking for data_availability_sections section in raw data.
# data_fetcher.py - line 693 - INFO - Missing section in XML: data_availability_sections
# PMC API Response for article at https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/ is complete: False

# %%
raw_data = data_gatherer.fetch_data(input_url,HTML_fallback=True)
print(f"raw_data fetched for {len(raw_data.values())} input url")
# Out:
# orchestrator.py - line 163 - INFO - Setting up data fetcher...
# orchestrator.py - line 191 - INFO - Data fetcher setup completed.
# orchestrator.py - line 110 - INFO - Fetching data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/
# data_fetcher.py - line 107 - INFO - WebScraper instance: True
# data_fetcher.py - line 108 - INFO - APIClient instance: False
# data_fetcher.py - line 109 - INFO - scraper_tool attribute: True
# data_fetcher.py - line 111 - INFO - Initializing new selenium driver.
# selenium_setup.py - line 11 - INFO - Creating WebDriver for browser: firefox
# selenium_setup.py - line 41 - INFO - No driver path provided, using GeckoDriverManager to auto-install Firefox driver.
# selenium_setup.py - line 43 - INFO - Using GeckoDriverManager to auto-install Firefox driver <selenium.webdriver.firefox.service.Service object at 0x104e7a6e0>.
# raw_data fetched for 1 input url

# %%
data_cited = data_gatherer.parse_data(raw_data, input_url, full_document_read=True, raw_data_format="full_HTML")
# Out:
# orchestrator.py - line 143 - INFO - Parsing data from URL: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/ with publisher: PMC
# parser.py - line 137 - INFO - Parser initialized.
# parser.py - line 515 - INFO - Function call: parse_data(api_data(<class 'str'>), PMC, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/, additional_data, full_HTML)
# parser.py - line 607 - INFO - Extracting links from full HTML content.
# parser.py - line 905 - INFO - Function_call: extract_href_from_html_supplementary_material(tree, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/)
# parser.py - line 1089 - INFO - Function_call: reconstruct_download_link(https://doi.org/10.1038/s41467-018-06162-9, pmc-layout__citation font-secondary font-xs, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/)
# parser.py - line 1089 - INFO - Function_call: reconstruct_download_link(http://creativecommons.org/licenses/by/4.0/, d-panel p, https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466/)
# ...

# %%
data_cited
# Out:
#    dataset_identifier data_repository  \
# 0           PHS001049           dbGAP
# 1         PRJNA306801             SRA
# 0                 NaN             NaN
# 18                NaN             NaN
# 19                NaN             NaN
# 20                NaN             NaN
# 21                NaN             NaN
# 22                NaN             NaN
# 23                NaN             NaN
# 24                NaN             NaN
# 25                NaN             NaN
# 26                NaN             NaN
# 27                NaN             NaN
# 28                NaN             NaN
# 29                NaN             NaN
# 30                NaN             NaN
# 31                NaN             NaN
# 32                NaN             NaN
#
#                                       dataset_webpage            access_mode  \
# 0   https://www.ncbi.nlm.nih.gov/projects/gap/cgi-...  Application to access
# ...
