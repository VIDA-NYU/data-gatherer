# %%
import numpy as np
import pandas as pd
import re
import json
import requests
from xml.etree import ElementTree
import time
from dotenv import load_dotenv
import ast  # To safely evaluate string representation of a list
import bdikit as bdi
import os
from experiment_utils import *
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c043216a-5de7-4857-9553-55eaba14212d'>
#   <div id="b4119065-a15e-4953-8240-4822abeb957e" data-root-id="c043216a-5de7-4857-9553-55eaba14212d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"dc83f493-0a31-4add-916c-e1a9b3d83c1d":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c043216a-5de7-4857-9553-55eaba14212d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c0119b9e-57e7-4102-b7e5-155fdaa975ca","attributes":{"plot_id":"c043216a-5de7-4857-9553-55eaba14212d","comm_id":"7b8aa2dbd0bf4f9e8967ee84bfbb4dfe","client_comm_id":"5b2330710b3c4aac860e14ce0c939f27"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"dc83f493-0a31-4add-916c-e1a9b3d83c1d","roots":{"c043216a-5de7-4857-9553-55eaba14212d":"b4119065-a15e-4953-8240-4822abeb957e"},"root_ids":["c043216a-5de7-4857-9553-55eaba14212d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
pmid_doi_mapping_file = "exp_output/pmid_doi_mapping.json"
if os.path.exists(pmid_doi_mapping_file): 
    with open(pmid_doi_mapping_file, "r") as f:
        pmid_doi_mapping = json.load(f)  # read json file
else:
    pmid_doi_mapping = {}

# %%
pmid_pmcid_mapping_file = "exp_output/pmid_pmcid_mapping.json"
if os.path.exists(pmid_pmcid_mapping_file): 
    with open(pmid_pmcid_mapping_file, "r") as f:
        pmid_pmcid_mapping = json.load(f)  # read json file
else:
    pmid_pmcid_mapping = {}

# %%
doi_pmid_mapping_file = "exp_output/doi_pmid_mapping.json"
if os.path.exists(doi_pmid_mapping_file): 
    with open(doi_pmid_mapping_file, "r") as f:
        doi_pmid_mapping = json.load(f)  # read json file
else:
    doi_pmid_mapping = {}

# %%
doi_to_pmcid_mapping_file = "exp_output/doi_pmcid_mapping.json"
if os.path.exists(doi_to_pmcid_mapping_file):
    with open(doi_to_pmcid_mapping_file, "r") as f:
        doi_pmcid_mapping = json.load(f)  # read json file
else:
    doi_pmcid_mapping = {}

# %%
len(pmid_doi_mapping), len(pmid_pmcid_mapping), len(doi_pmid_mapping), len(doi_pmcid_mapping)
# Out:
# (144993, 144993, 125273, 125011)

# %% [markdown]
# ## Extract the datasets data from ProteomeCentral and GEO
#
# Start from the export file from ProteomeCentral: https://proteomecentral.proteomexchange.org/

# %%
export_df = pd.read_csv('exp_input/proteomexchange_search.tsv', sep='\t')
print(f"number of dataset ids in export dataframe from ProteomeCentral: {len(export_df)}")
# Out:
# number of dataset ids in export dataframe from ProteomeCentral: 40137

# %% [markdown]
# to get an idea of the most frequent values in df publication, for all the dataset ids from the source file

# %%
export_df['publication'].value_counts().head()
# Out:
# publication
# Dataset with its publication pending                                                                 11719
# no publication                                                                                        2550
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/35084980" target="_blank">Melani et al. (2022)</a>          56
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/28267743" target="_blank">Matsumoto et al. (2017)</a>       28
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/28071820" target="_blank">Kreutz et al. (2017)</a>          18
# Name: count, dtype: int64

# %% [markdown]
# Clean the `publication` column by filtering out unwanted values like `Dataset with its publication pending`, `no publication`. Remove rows with unwanted values

# %%
filtered_df = export_df[~export_df['publication'].isin(["Dataset with its publication pending", "no publication"])]
print(len(filtered_df),'\n',filtered_df.columns)
# Out:
# 25868
#  Index(['identifier', 'title', 'repository', 'species', 'instrument',
#        'publication', 'lab_head', 'announce_date', 'keywords'],
#       dtype='object')

# %% [markdown]
# Normalize the `publication` column by extracting the links from the html tags

# %%
filtered_df = filtered_df.copy()

filtered_df.loc[:, 'citing_publications_links'] = None

for i, row in filtered_df.iterrows():
    pub = str(row['publication'])  # Ensure string type
    if "href" in pub:
        match = re.findall(r'href=[\'"]([^\'"]+)[\'"]', pub)  # Extract href links
        filtered_df.at[i, 'citing_publications_links'] = match if match else None
    else:
        filtered_df.at[i, 'citing_publications_links'] = None

# Drop rows with missing links safely
filtered_df = filtered_df.dropna(subset=['citing_publications_links']).reset_index(drop=True)
filtered_df.drop(columns=['publication'], inplace=True)  # Drop original column

print(f"# n datasets with publications: {len(filtered_df)}") 
print(filtered_df.columns)
# Out:
# # n datasets with publications: 25696
# Index(['identifier', 'title', 'repository', 'species', 'instrument',
#        'lab_head', 'announce_date', 'keywords', 'citing_publications_links'],
#       dtype='object')

# %% [markdown]
# Normalize links:
#
#
# - if pubmed link, find the pmcid and the doi mapped to the pmid
#
#
# - if doi link, find the doi and the pmcid mapped to the doi

# %%
filtered_df = filtered_df.explode('citing_publications_links', ignore_index=True)  # Split lists into rows
print(f"Length: {len(filtered_df)}")

filtered_df = extract_publication_ids_from_PX_export(filtered_df, pmid_doi_mapping, pmid_pmcid_mapping, doi_pmid_mapping, doi_pmcid_mapping)
print(f"Length should be the same: {len(filtered_df)}")

filtered_df = add_citing_publication_link_columns(filtered_df)
print(f"Length should be greater: {len(filtered_df)}")

filtered_df["citing_publications_links"] = filtered_df["citing_publications_links"].astype(str)
filtered_df["DOI"] = filtered_df["DOI"].astype(str)
filtered_df["PMCID"] = filtered_df["PMCID"].astype(str)

# Now drop duplicates
filtered_df.drop_duplicates(subset=['citing_publications_links', 'DOI', 'PMCID'], inplace=True)
print(f"Length could be a bit smaller: {len(filtered_df)}")

filtered_df[['citing_publications_links','DOI','PMID','PMCID']].sample(10)
# Out:
# Length: 39347
# Length should be the same: 39347
# Before explode sample:                           DOI        PMCID  \
# 0  10.1038/S41467-025-56720-1         None
# 1           10.6019/PXD051312         None
# 2      10.1002/prca.202400095  PMC11895760
# 3      10.1002/prca.202400095  PMC11895760
# 4    10.17159/SAJS.2025/18571         None
# 5   10.1101/2024.04.03.587901         None
# 6   10.1101/2025.02.05.636703         None
# 7  10.1186/S13100-024-00339-4         None
# 8  10.1186/s12964-025-02046-w  PMC11773904
# 9  10.1186/s12964-025-02046-w  PMC11773904
#
#                            citing_publications_links
# 0    [https://dx.doi.org/10.1038/S41467-025-56720-1]
# 1             [https://dx.doi.org/10.6019/PXD051312]
# 2  [https://dx.doi.org/10.1002/prca.202400095, ht...
# 3  [https://dx.doi.org/10.1002/prca.202400095, ht...
# 4      [https://dx.doi.org/10.17159/SAJS.2025/18571]
# 5     [https://dx.doi.org/10.1101/2024.04.03.587901]
# 6     [https://dx.doi.org/10.1101/2025.02.05.636703]
# 7    [https://dx.doi.org/10.1186/S13100-024-00339-4]
# 8  [https://dx.doi.org/10.1186/s12964-025-02046-w...
# 9  [https://dx.doi.org/10.1186/s12964-025-02046-w...
# Final dataframe length: 59833
# Length should be greater: 59833
# Length could be a bit smaller: 38688
#                                citing_publications_links  \
# 23039      https://dx.doi.org/10.1038/S41467-024-44988-8
# 20273      https://dx.doi.org/10.1038/s41423-024-01150-0
# 41660           https://dx.doi.org/10.3390/cells10061306
# 43111  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 1351                https://dx.doi.org/10.6019/PXD046271
# 28362  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9...
# 54036      https://dx.doi.org/10.1038/s41467-018-07321-8
# 34061  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 54198               https://dx.doi.org/10.6019/PXD009649
# 13141  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                               DOI      PMID        PMCID
# 23039  10.1038/S41467-024-44988-8      None         None
# 20273  10.1038/s41423-024-01150-0  38689020  PMC11143349
# 41660       10.3390/cells10061306  34074003   PMC8225046
# 43111  10.1161/ATVBAHA.120.315007  33356393   PMC8105275
# 1351            10.6019/PXD046271      None         None
# 28362  10.1038/s41586-023-05780-8  36859550   PMC9995272
# 54036  10.1038/s41467-018-07321-8  30451861   PMC6242847
# 34061  10.1038/s42003-022-03259-2  35393494   PMC8991201
# 54198           10.6019/PXD009649      None         None
# 13141    10.3389/fcimb.2019.00104  31069174   PMC6491454

# %% [markdown]
# Extraction of data from GEO

# %%
GEO_extract_file = "exp_input/GEO_data.csv"
GEO_df = pd.read_csv(GEO_extract_file, low_memory=False)
print(f"number of dataset ids in GEO dataframe: {len(GEO_df)}")
# Out:
# number of dataset ids in GEO dataframe: 248748

# %% [markdown]
# Extracting all the datasets with eutils api and get all the uids of GEO series datasets

# %%
root = ElementTree.fromstring(requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi", 
                                           params={"db": "gds", "term": '"gse"[Entry Type]', "retmax": "1000000",  "retmode": "xml"}
                                           ).content)

gse_ids = [id_elem.text for id_elem in root.findall(".//Id")]
missing_ids = set(gse_ids)-set([str(x) for x in GEO_df.uid])

print(f"Total datasets found: {len(gse_ids)}")
print("Missing GSE IDs:", len(missing_ids))  # Show difference with data we already got
# Out:
# Total datasets found: 249060
# Missing GSE IDs: 326

# %% [markdown]
# Add new datasets from GEO to the GEO dataframe

# %%
new_GEO_series_data = {}
i, mxm = 0, 1
while True:
    print(f"Progress: {min(i / len(missing_ids), 1) * 100} %")
    if i > len(missing_ids):
        break
    try:
        new_data = fetch_GEO_data(list(missing_ids),"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi",i,mxm)
        for uid, details in new_data["result"].items():
            if uid == "uids":  # Ignore metadata key
                continue
            new_GEO_series_data[uid] = details
    except Exception as e:
        print(f"Error at {i}, {mxm} with error: {e}")
            
    i += 1
    mxm += 1
    time.sleep(0.005) 

add_new_data = False # add new datasets to the GEO_df
if add_new_data:
    GEO_df = pd.concat([GEO_df, pd.DataFrame(new_GEO_series_data).T], axis=0)
# Out:
# Progress: 0.0 %
# Progress: 0.3067484662576687 %
# Progress: 0.6134969325153374 %
# Progress: 0.9202453987730062 %
# Error at 3, 4 with error: 'result'
# Progress: 1.2269938650306749 %
# Error at 4, 5 with error: 'result'
# Progress: 1.5337423312883436 %
# Error at 5, 6 with error: 'result'
# Progress: 1.8404907975460123 %
# Error at 6, 7 with error: 'result'
# Progress: 2.147239263803681 %
# Error at 7, 8 with error: 'result'
# Progress: 2.4539877300613497 %
# Progress: 2.7607361963190185 %
# Progress: 3.067484662576687 %
# Error at 10, 11 with error: 'result'
# Progress: 3.374233128834356 %
# Error at 11, 12 with error: 'result'
# Progress: 3.6809815950920246 %
# Error at 12, 13 with error: 'result'
# Progress: 3.9877300613496933 %
# Error at 13, 14 with error: 'result'
# Progress: 4.294478527607362 %
# Error at 14, 15 with error: 'result'
# Progress: 4.601226993865031 %
# Error at 15, 16 with error: 'result'
# Progress: 4.9079754601226995 %
# Progress: 5.214723926380368 %
# Error at 17, 18 with error: 'result'
# Progress: 5.521472392638037 %
# Error at 18, 19 with error: 'result'
# Progress: 5.828220858895705 %
# Error at 19, 20 with error: 'result'
# Progress: 6.134969325153374 %
# Error at 20, 21 with error: 'result'
# Progress: 6.441717791411043 %
# Error at 21, 22 with error: 'result'
# Progress: 6.748466257668712 %
# Error at 22, 23 with error: 'result'
# Progress: 7.05521472392638 %
# Progress: 7.361963190184049 %
# Progress: 7.668711656441718 %
# Error at 25, 26 with error: 'result'
# Progress: 7.975460122699387 %
# Progress: 8.282208588957054 %
# Progress: 8.588957055214724 %
# Progress: 8.895705521472392 %
# Error at 29, 30 with error: 'result'
# Progress: 9.202453987730062 %
# Error at 30, 31 with error: 'result'
# Progress: 9.509202453987731 %
# Error at 31, 32 with error: 'result'
# Progress: 9.815950920245399 %
# Error at 32, 33 with error: 'result'
# Progress: 10.122699386503067 %
# Error at 33, 34 with error: 'result'
# Progress: 10.429447852760736 %
# Error at 34, 35 with error: 'result'
# Progress: 10.736196319018406 %
# Progress: 11.042944785276074 %
# Error at 36, 37 with error: 'result'
# Progress: 11.349693251533742 %
# Error at 37, 38 with error: 'result'
# Progress: 11.65644171779141 %
# Error at 38, 39 with error: 'result'
# Progress: 11.96319018404908 %
# Error at 39, 40 with error: 'result'
# Progress: 12.269938650306749 %
# Progress: 12.576687116564417 %
# Progress: 12.883435582822086 %
# Error at 42, 43 with error: 'result'
# Progress: 13.190184049079754 %
# Error at 43, 44 with error: 'result'
# Progress: 13.496932515337424 %
# Error at 44, 45 with error: 'result'
# Progress: 13.803680981595093 %
# Error at 45, 46 with error: 'result'
# Progress: 14.11042944785276 %
# Error at 46, 47 with error: 'result'
# Progress: 14.417177914110429 %
# Error at 47, 48 with error: 'result'
# Progress: 14.723926380368098 %
# Error at 48, 49 with error: 'result'
# Progress: 15.030674846625766 %
# Progress: 15.337423312883436 %
# Error at 50, 51 with error: 'result'
# Error at 322, 323 with error: 'result'
# Progress: 99.079754601227 %
# Error at 323, 324 with error: 'result'
# Progress: 99.38650306748467 %
# Error at 324, 325 with error: 'result'
# Progress: 99.69325153374233 %
# Error at 325, 326 with error: 'result'
# Progress: 100.0 %
# Error at 326, 327 with error: 'result'
# Progress: 100 %

# %% [markdown]
# We will update the filtered_df with the new datasets from GEO, after matching the schema

# %% [markdown]
# Add the url to the GEO datasets by reconstruction from pubmedids

# %%
# eval string to list
GEO_df['pubmedids'] = GEO_df['pubmedids'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
print(len(GEO_df))
GEO_df = GEO_df[GEO_df['pubmedids'].astype(bool)]  # Drop rows with empty lists
print(len(GEO_df))
GEO_df = GEO_df.explode('pubmedids', ignore_index=True)  # Split lists into rows
print(len(GEO_df))
# Out:
# 248748
# 194093
# 208151

# %% [markdown]
# - if pubmed link, find the pmcid and the doi mapped to the pmid
#
#
# - Create Links for the publications

# %%
GEO_df['PMCID'] = GEO_df['pubmedids'].map(
    lambda x: pmid_pmcid_mapping.get(x, None) if isinstance(x, str) else None )
GEO_df['DOI'] = GEO_df['pubmedids'].map(
    lambda x: pmid_doi_mapping.get(x, None) if isinstance(x, str) else None)
GEO_df[['pubmedids','PMCID','DOI']].sample(10)
# Out:
#        pubmedids        PMCID                           DOI
# 160949  25204429   PMC4177250      10.1186/1476-4598-13-209
# 72254   34017133         None                          None
# 75702   22955616   PMC3439153           10.1038/nature11247
# 10356   38922876         None                          None
# 203094  17910761   PMC2078596       10.1186/1471-2164-8-349
# 41741   36428978   PMC9688917         10.3390/cells11223549
# 32969   37108567  PMC10138523          10.3390/ijms24087403
# 54127   34010639   PMC9678241  10.1016/j.celrep.2021.109136
# 146641  27058788   PMC4826471  10.1016/j.molcel.2016.03.001
# 168889  24317252   PMC4018771            10.1038/nmeth.2762

# %%
# Generate citing_publications_links as a list of links
GEO_df = add_citing_publication_link_columns(GEO_df)

GEO_df[['pubmedids','PMCID','DOI','citing_publications_links']].sample(10)
# Out:
# Before explode sample:                        DOI        PMCID  \
# 0                     None         None
# 1   10.1093/immhor/vlae005  PMC11841973
# 2      10.1093/nar/gkaf109  PMC11840560
# 3                     None         None
# 4                     None         None
# 5                     None         None
# 6                     None         None
# 7                     None         None
# 8                     None         None
# 9  10.1073/pnas.2416384122  PMC11892594
#
#                            citing_publications_links
# 0                                                 []
# 1  [https://dx.doi.org/10.1093/immhor/vlae005, ht...
# 2  [https://dx.doi.org/10.1093/nar/gkaf109, https...
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9  [https://dx.doi.org/10.1073/pnas.2416384122, h...
# Final dataframe length: 352982
#        pubmedids        PMCID                                DOI  \
# 112075  35184570   PMC8923958  10.1161/CIRCULATIONAHA.121.057613
# 171466  33420030   PMC7794439         10.1038/s41467-020-20447-y
# 39904   38278841  PMC10817939         10.1038/s41467-024-45141-1
# 250313  28334889   PMC5449619                 10.1093/nar/gkx168
# 86351   36073526   PMC9553214                10.7554/eLife.78074
# 247816  31677552   PMC6920132        10.1016/j.redox.2019.101359
# 181385  37172728  PMC10267520          10.1016/j.jbc.2023.104805
# 113274  35140216   PMC8828724         10.1038/s41467-022-28454-x
# 38338   39041647  PMC11605269                  10.1002/art.42958
# 156674  33804598   PMC8003772               10.3390/ijms22063164
#
#                                 citing_publications_links
# 112075  https://dx.doi.org/10.1161/CIRCULATIONAHA.121....
# 171466  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 39904   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 250313  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 86351              https://dx.doi.org/10.7554/eLife.78074
# 247816  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 181385  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 113274      https://dx.doi.org/10.1038/s41467-022-28454-x
# 38338   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 156674            https://dx.doi.org/10.3390/ijms22063164

# %%
# drop NaN citing_publications_links
GEO_df = GEO_df.dropna(subset=['citing_publications_links'])  # Remove NaNs
print(len(GEO_df))
# Out:
# 352982

# %% [markdown]
# Union of the two dataframes

# %%
print(f"len filtered_df: {len(filtered_df)}")
print(f"len GEO_df: {len(GEO_df)}")
# Out:
# len filtered_df: 38688
# len GEO_df: 352982

# %%
column_mappings = { # Manually map columns
    'accession': 'identifier',
    'taxon': 'species',
    'repository': 'entrytype',
    'publication_date': 'pdat',
    'pubmedids': 'PMID',
}

# %%
GEO_df = GEO_df.rename(columns=column_mappings)  # Rename columns
GEO_df['repository'] = 'GEO'  # Add repository column
filtered_df = pd.concat([filtered_df, GEO_df], axis=0, ignore_index=True)  # Concatenate dataframes

# %%
filtered_df.iloc[::10000].head(10)  # Show every 10000th row
# Out:
#       identifier                                              title  \
# 0      PXD059466  Endothelial SHANK3 Regulates Tight Junctions i...
# 10000  PXD049417  Multiomics approach to decipher pathophysiolog...
# 20000  PXD031142  Marine Synechococcus sp. strain WH7803 shows s...
# 30000  PXD014667  Listeria monocytogenes exploits the MICOS comp...
# 40000  GSE268565  BMPR1A-mediated BMP signalling ensures correct...
# 50000  GSE240634  Identification of IKKβ Inhibitor by utilizing ...
# 60000  GSE245526  Replication-competent HIV-1 gRNA Constructs fo...
# 70000  GSE255988  Polygenic Risk for Alcohol Use Disorder Affect...
# 80000  GSE236263  MicroRNA-1 protects the endothelium in acute l...
# 90000  GSE230619  Gene expression data from human adipose-derive...
#
#       repository                              species             instrument  \
# 0          PRIDE                         Mus musculus  Orbitrap Fusion Lumos
# 10000      PRIDE                         Mus musculus        Orbitrap Fusion
# 20000      PRIDE  Bacteria, Synechococcus sp. WH 7803        Orbitrap Fusion
# 30000      PRIDE                         Homo sapiens             Q Exactive
# 40000        GEO                         Mus musculus                    NaN
# 50000        GEO                         Homo sapiens                    NaN
# 60000        GEO       Human immunodeficiency virus 1                    NaN
# 70000        GEO                         Homo sapiens                    NaN
# 80000        GEO                         Homo sapiens                    NaN
# 90000        GEO                         Homo sapiens                    NaN
#
#                            lab_head announce_date  \
# 0                       Il Hwan Kim    2025-02-07
# 10000                   Jiri Petrak    2024-07-03
# 20000  José Manuel García Fernández    2022-07-11
# 30000               Pascale Cossart    2020-02-17
# 40000                           NaN           NaN
# 50000                           NaN           NaN
# 60000                           NaN           NaN
# 70000                           NaN           NaN
# 80000                           NaN           NaN
# 90000                           NaN           NaN
#
#                                                 keywords  \
# 0                           BioID2, SHANK3, bEnd3. Cells
# 10000  Cystathionine beta-synthase, homocystinuria, m...
# 20000  Orbitrap Fusion, Synechococcus WH7803, nitroge...
# 30000  Listeria monocytogenes, MICOS complex, Mic10, ...
# 40000                                                NaN
# 50000                                                NaN
# 60000                                                NaN
# 70000                                                NaN
# 80000                                                NaN
# 90000                                                NaN
#
#                                citing_publications_links      PMID  ...  \
# 0          https://dx.doi.org/10.1038/S41467-025-56720-1      None  ...
# 10000  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...  38843767  ...
# 20000               https://dx.doi.org/10.6019/PXD031142      None  ...
# 30000  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...  32019800  ...
# 40000  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...  39817676  ...
# 50000    https://dx.doi.org/10.1681/ASN.0000000000000460  39133556  ...
# 60000      https://dx.doi.org/10.1038/s41467-024-48228-x  38714682  ...
# 70000          https://dx.doi.org/10.1126/sciadv.ado5820  39514655  ...
# 80000      https://dx.doi.org/10.1172/jci.insight.164816  37737266  ...
# 90000  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...  37445596  ...
#
#              pdat        suppfile  \
# 0             NaN             NaN
# 10000         NaN             NaN
# 20000         NaN             NaN
# 30000         NaN             NaN
# 40000  2025/01/16             TXT
# 50000  2024/08/15             TXT
# 60000  2024/04/15       TAB, XLSX
# 70000  2024/02/19             TSV
# 80000  2023/10/25             TXT
# 90000  2023/07/19  CEL, CHP, XLSX
#
#                                                  samples  relations  \
# 0                                                    NaN        NaN
# 10000                                                NaN        NaN
# 20000                                                NaN        NaN
# 30000                                                NaN        NaN
# 40000  [{'accession': 'GSM8294327', 'title': 'E14.5 f...         []
# 50000  [{'accession': 'GSM7706552', 'title': 'Sample ...         []
# 60000  [{'accession': 'GSM7844529', 'title': 'NL4.3 C...         []
# 70000  [{'accession': 'GSM8083849', 'title': 'Microgl...         []
# 80000  [{'accession': 'GSM7524125', 'title': 'HPMEC c...         []
# 90000  [{'accession': 'GSM7230019', 'title': 'hASCs, ...         []
#
#       extrelations n_samples projects  \
# 0              NaN       NaN      NaN
# 10000          NaN       NaN      NaN
# 20000          NaN       NaN      NaN
# 30000          NaN       NaN      NaN
# 40000           []       8.0       []
# 50000           []      18.0       []
# 60000           []      49.0       []
# 70000           []      18.0       []
# 80000           []       3.0       []
# 90000           []       9.0       []
#
#                                                  ftplink geo2r    bioproject
# 0                                                    NaN   NaN           NaN
# 10000                                                NaN   NaN           NaN
# 20000                                                NaN   NaN           NaN
# 30000                                                NaN   NaN           NaN
# 40000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE268nn...    no  PRJNA1117811
# 50000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE240nn...   yes  PRJNA1004406
# 60000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE245nn...    no  PRJNA1028668
# 70000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE255nn...   yes  PRJNA1077355
# 80000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE236nn...   yes   PRJNA989591
# 90000  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE230nn...   yes   PRJNA962011
#
# [10 rows x 30 columns]

# %%
filtered_df.to_parquet('exp_input/Table_datasets.parquet', index=False)

# %% [markdown]
# ## Creating Publications Data Table

# %% [markdown]
# We start from ProteomeCentral and GEO table we created before

# %%
filtered_df = pd.read_parquet('exp_input/Table_datasets.parquet')

# %%
print(len(filtered_df))
filtered_df.head(3)
# Out:
# 391670
#   identifier                                              title repository  \
# 0  PXD059466  Endothelial SHANK3 Regulates Tight Junctions i...      PRIDE
# 1  PXD051312  Systemic changes in early pregnancy in the mar...      PRIDE
# 2  PXD051312  Systemic changes in early pregnancy in the mar...      PRIDE
#
#           species                            instrument     lab_head  \
# 0    Mus musculus                 Orbitrap Fusion Lumos  Il Hwan Kim
# 1  Equus caballus  Exactive Plus, Orbitrap Exploris 480    Dr Aleona
# 2  Equus caballus  Exactive Plus, Orbitrap Exploris 480    Dr Aleona
#
#   announce_date                                           keywords  \
# 0    2025-02-07                       BioID2, SHANK3, bEnd3. Cells
# 1    2025-02-07  MRP, TTR, biomarker, early pregnancy loss, sec...
# 2    2025-02-07  MRP, TTR, biomarker, early pregnancy loss, sec...
#
#                        citing_publications_links      PMID  ...  pdat  \
# 0  https://dx.doi.org/10.1038/S41467-025-56720-1      None  ...  None
# 1           https://dx.doi.org/10.6019/PXD051312      None  ...  None
# 2      https://dx.doi.org/10.1002/prca.202400095  39912552  ...  None
#
#   suppfile  samples  relations extrelations n_samples projects  ftplink geo2r  \
# 0     None     None       None         None       NaN     None     None  None
# 1     None     None       None         None       NaN     None     None  None
# 2     None     None       None         None       NaN     None     None  None
#
#   bioproject
# 0       None
# 1       None
# 2       None
#
# [3 rows x 30 columns]

# %% [markdown]
# Some statistics on our publications data

# %% [markdown]
# look at the publications one by one

# %%
filtered_df = filtered_df.explode('citing_publications_links')  # Split lists into rows

# %%
df_publications = filtered_df[['citing_publications_links','DOI','PMID','PMCID']]

df_publications = df_publications.sort_values(by='citing_publications_links', key=lambda x: x.str.contains('doi', na=False), ascending=False)

df_publications = df_publications.drop_duplicates(subset=['PMCID', 'DOI'], keep='first')

len(df_publications)
# Out:
# 126461

# %%
print(len(df_publications))
print(df_publications.dtypes)
df_publications.head(3)
# Out:
# 126461
# citing_publications_links    object
# DOI                          object
# PMID                         object
# PMCID                        object
# dtype: object
#                             citing_publications_links  \
# 0       https://dx.doi.org/10.1038/S41467-025-56720-1
# 313946           https://dx.doi.org/10.1038/srep10438
# 163224         https://dx.doi.org/10.1038/nature11247
#
#                                DOI      PMID       PMCID
# 0       10.1038/S41467-025-56720-1      None        None
# 313946           10.1038/srep10438  26039282  PMC4453922
# 163224         10.1038/nature11247  22955616  PMC3439153

# %%
df_publications.astype(str).to_parquet('exp_input/Table_publications.parquet', index=False)

# %% [markdown]
# ## Create the ground truth table
#
# each row is a record of a dataset citation in a doi

# %%
Publications_table = pd.read_parquet('exp_input/Table_publications.parquet')
Datasets_table = pd.read_parquet('exp_input/Table_datasets.parquet')

# %% [markdown]
# We iterate over all the datasets and use their publication urls to find the corresponding dois. Since not all papers had dois, we will create a Publication Identifier table

# %%
Publication_Dataset_Citations_Ground_Truth = Datasets_table[['identifier','repository','citing_publications_links']].copy()

# %%
Publication_Dataset_Citations_Ground_Truth.to_parquet('exp_input/dataset_citation_records_Table.parquet', index=False)
