# %%
import pandas as pd
import re

# %%
urls = None
df = pd.read_csv('exp_input/proteomexchange_search.tsv', sep='\t')
publication_datasets = df[['publication','identifier','repository','title','keywords']]

# %%
# get an idea of values in df publication
publication_datasets['publication'].value_counts()
# Out:
# publication
# Dataset with its publication pending                                                                                                                                                                      11719
# no publication                                                                                                                                                                                             2550
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/35084980" target="_blank">Melani et al. (2022)</a>                                                                                                               56
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/28267743" target="_blank">Matsumoto et al. (2017)</a>                                                                                                            28
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/28071820" target="_blank">Kreutz et al. (2017)</a>                                                                                                               18
#                                                                                                                                                                                                           ...
# <a href="https://dx.doi.org/10.3389/FPLS.2023.1285847" target="_blank">10.3389/FPLS.2023.1285847</a>                                                                                                          1
# <a href="https://dx.doi.org/10.1083/JCB.201902050" target="_blank">10.1083/JCB.201902050</a>                                                                                                                  1
# <a href="https://dx.doi.org/10.1038/S41598-023-47767-5" target="_blank">10.1038/S41598-023-47767-5</a>                                                                                                        1
# <a href="https://dx.doi.org/10.15252/embr.202357741" target="_blank">10.15252/embr.202357741</a>; <a href="https://www.ncbi.nlm.nih.gov/pubmed/38009565" target="_blank">Due Tankmar et al. (2023)</a>        1
# <a href="http://www.ncbi.nlm.nih.gov/pubmed/22874012">Vaudel et al. (2012)</a>                                                                                                                                1
# Name: count, Length: 23462, dtype: int64

# %%
#  clean the `publication` column by filtering out unwanted values like `"Dataset with its publication pending"`, `"no publication"`, and any HTML tags. 
# Remove rows with unwanted values
filtered_df = publication_datasets[~publication_datasets['publication'].isin(["Dataset with its publication pending", "no publication"])]
len(filtered_df)
# Out:
# 25868

# %%
# Ensure filtered_df is a copy, not a slice
filtered_df = filtered_df.copy()

# Create a new column for the links
filtered_df.loc[:, 'publication_link'] = None

# Extract links from 'publication'
for i, row in filtered_df.iterrows():
    pub = str(row['publication'])  # Ensure string type
    if "href" in pub:
        match = re.findall(r'href=[\'"]([^\'"]+)[\'"]', pub)  # Extract href links
        filtered_df.at[i, 'publication_link'] = match if match else None
    else:
        filtered_df.at[i, 'publication_link'] = None

# Drop rows with missing links safely
filtered_df = filtered_df.dropna(subset=['publication_link']).reset_index(drop=True)

# %%
m = 0
for i,row in filtered_df.iterrows():
    id = row['identifier']
    m+=len(row['publication_link'])
print(f"Total number of publications: {m}")
print(f"Average number of publications per dataset: {m/len(filtered_df)}")
# Out:
# Total number of publications: 39347
# Average number of publications per dataset: 1.53125

# %%
filtered_df.columns
# Out:
# Index(['publication', 'identifier', 'repository', 'title', 'keywords',
#        'publication_link'],
#       dtype='object')

# %%
# group by publication_link, concat identifier

filtered_df = filtered_df.explode('publication_link')  # Split lists into rows

df_grouped = filtered_df.groupby('publication_link').agg({
    'identifier': lambda x: ','.join(map(str, x.fillna('n/a'))),
    'repository': lambda x: ','.join(map(str, x.fillna('n/a'))),
    'title': lambda x: ','.join(map(str, x.fillna('n/a'))),
    'keywords': lambda x: ','.join(map(str, x.fillna('n/a')))  # Replace NaN with 'n/a'
}).reset_index()

df_grouped
# Out:
#                                       publication_link  \
# 0                  http://dx.doi.org/10.1002/CAM4.3825
# 1             http://dx.doi.org/10.1002/CBIC.202000870
# 2             http://dx.doi.org/10.1002/PMIC.202000214
# 3             http://dx.doi.org/10.1002/PMIC.202000240
# 4             http://dx.doi.org/10.1002/PMIC.202100036
# ...                                                ...
# 34874      https://www.ncbi.nlm.nih.gov/pubmed/4127907
# 34875      https://www.ncbi.nlm.nih.gov/pubmed/5974087
# 34876      https://www.ncbi.nlm.nih.gov/pubmed/6260970
# 34877      https://www.ncbi.nlm.nih.gov/pubmed/9537338
# 34878  https://www.ncbi.nlm.nih.gov/pubmed/PMC10340108
#
#                                               identifier  \
# 0                                              PXD023689
# 1      PXD023060,PXD023059,PXD023056,PXD023057,PXD023058
# 2                                              PXD020638
# 3                                              PXD023907
# 4                                              PXD022191
# ...                                                  ...
# 34874                                          PXD000055
# 34875                                          PXD009498
# 34876                                          PXD001626
# 34877                                          PXD036326
# 34878                                          PXD037645
#
#                           repository  \
# 0                              PRIDE
# 1      PRIDE,PRIDE,PRIDE,PRIDE,PRIDE
# 2                              PRIDE
# 3                              PRIDE
# 4                              PRIDE
# ...                              ...
# 34874                          PRIDE
# 34875                          PRIDE
# 34876                          PRIDE
# 34877                          PRIDE
# 34878                          iProX
#
#                                                    title  \
# 0      Proteomics reveals the function reverse of MPS...
# 1      Rapid and high coverage profile of human cyste...
# 2      Combining label-free and label-based accurate ...
# 3      Fusarium oxysporum f. sp. vasinfectum (UP00003...
# 4      Spectral library for SARS-COVID proteome and i...
# ...                                                  ...
# 34874  Casein Kinase 1 functions in eukaryotic non-tr...
# 34875         SILAC APMS analysis of CCDC103 interactome
# 34876  Widespread somatic L1 retrotransposition occur...
# 34877  Arterial-Venous Endothelial Cell Cycle Protein...
# 34878  High concentration of prolactin induce oxidati...
#
#                                                 keywords
# 0      prostate CAFs, prostate cancer cells, secretomics
# 1      Cysteine, FAIMS, SP3,Cysteine, FAIMS, SP3,Cyst...
# 2      Beef meat quality, Data-Independent Acquisitio...
# 3                      cotton, fungi, fusarium oxysporum
# 4      HLA, ProteomeXchange project tag: Covid-19, SA...
# ...                                                  ...
# 34874  Ostreococcus tauri, Phosphoproteomics, casein ...
# 34875              APMS, Hela cells, LTQ-Orbitrap, SILAC
# 34876  L1, Retrotransposon, adenoma, carcinoma, color...
# 34877  HUVEC, S/G2/M, cell cycle, early G1, endotheli...
# 34878           Prolactin, ovine ovarian granulosa cells
#
# [34879 rows x 5 columns]

# %%
# count different identifiers for all publication_link
df_grouped['identifier_count'] = df_grouped['identifier'].apply(lambda x: len(x.split(',')))
df_grouped
# Out:
#                                       publication_link  \
# 0                  http://dx.doi.org/10.1002/CAM4.3825
# 1             http://dx.doi.org/10.1002/CBIC.202000870
# 2             http://dx.doi.org/10.1002/PMIC.202000214
# 3             http://dx.doi.org/10.1002/PMIC.202000240
# 4             http://dx.doi.org/10.1002/PMIC.202100036
# ...                                                ...
# 34874      https://www.ncbi.nlm.nih.gov/pubmed/4127907
# 34875      https://www.ncbi.nlm.nih.gov/pubmed/5974087
# 34876      https://www.ncbi.nlm.nih.gov/pubmed/6260970
# 34877      https://www.ncbi.nlm.nih.gov/pubmed/9537338
# 34878  https://www.ncbi.nlm.nih.gov/pubmed/PMC10340108
#
#                                               identifier  \
# 0                                              PXD023689
# 1      PXD023060,PXD023059,PXD023056,PXD023057,PXD023058
# 2                                              PXD020638
# 3                                              PXD023907
# 4                                              PXD022191
# ...                                                  ...
# 34874                                          PXD000055
# 34875                                          PXD009498
# 34876                                          PXD001626
# 34877                                          PXD036326
# 34878                                          PXD037645
#
#                           repository  \
# 0                              PRIDE
# 1      PRIDE,PRIDE,PRIDE,PRIDE,PRIDE
# 2                              PRIDE
# 3                              PRIDE
# 4                              PRIDE
# ...                              ...
# 34874                          PRIDE
# 34875                          PRIDE
# 34876                          PRIDE
# 34877                          PRIDE
# 34878                          iProX
#
#                                                    title  \
# 0      Proteomics reveals the function reverse of MPS...
# 1      Rapid and high coverage profile of human cyste...
# 2      Combining label-free and label-based accurate ...
# 3      Fusarium oxysporum f. sp. vasinfectum (UP00003...
# 4      Spectral library for SARS-COVID proteome and i...
# ...                                                  ...
# 34874  Casein Kinase 1 functions in eukaryotic non-tr...
# 34875         SILAC APMS analysis of CCDC103 interactome
# 34876  Widespread somatic L1 retrotransposition occur...
# 34877  Arterial-Venous Endothelial Cell Cycle Protein...
# 34878  High concentration of prolactin induce oxidati...
#
#                                                 keywords  identifier_count
# 0      prostate CAFs, prostate cancer cells, secretomics                 1
# 1      Cysteine, FAIMS, SP3,Cysteine, FAIMS, SP3,Cyst...                 5
# 2      Beef meat quality, Data-Independent Acquisitio...                 1
# 3                      cotton, fungi, fusarium oxysporum                 1
# 4      HLA, ProteomeXchange project tag: Covid-19, SA...                 1
# ...                                                  ...               ...
# 34874  Ostreococcus tauri, Phosphoproteomics, casein ...                 1
# 34875              APMS, Hela cells, LTQ-Orbitrap, SILAC                 1
# 34876  L1, Retrotransposon, adenoma, carcinoma, color...                 1
# 34877  HUVEC, S/G2/M, cell cycle, early G1, endotheli...                 1
# 34878           Prolactin, ovine ovarian granulosa cells                 1
#
# [34879 rows x 6 columns]

# %%
df_grouped['identifier_count'].sum()
# Out:
# 39347

# %%
# set lower case for the identifier and publication link fields
df_grouped = df_grouped.apply(lambda x: x.str.lower() if x.name in ['identifier', 'publication_link'] else x)
df_grouped
# Out:
#                                       publication_link  \
# 0                  http://dx.doi.org/10.1002/cam4.3825
# 1             http://dx.doi.org/10.1002/cbic.202000870
# 2             http://dx.doi.org/10.1002/pmic.202000214
# 3             http://dx.doi.org/10.1002/pmic.202000240
# 4             http://dx.doi.org/10.1002/pmic.202100036
# ...                                                ...
# 34874      https://www.ncbi.nlm.nih.gov/pubmed/4127907
# 34875      https://www.ncbi.nlm.nih.gov/pubmed/5974087
# 34876      https://www.ncbi.nlm.nih.gov/pubmed/6260970
# 34877      https://www.ncbi.nlm.nih.gov/pubmed/9537338
# 34878  https://www.ncbi.nlm.nih.gov/pubmed/pmc10340108
#
#                                               identifier  \
# 0                                              pxd023689
# 1      pxd023060,pxd023059,pxd023056,pxd023057,pxd023058
# 2                                              pxd020638
# 3                                              pxd023907
# 4                                              pxd022191
# ...                                                  ...
# 34874                                          pxd000055
# 34875                                          pxd009498
# 34876                                          pxd001626
# 34877                                          pxd036326
# 34878                                          pxd037645
#
#                           repository  \
# 0                              PRIDE
# 1      PRIDE,PRIDE,PRIDE,PRIDE,PRIDE
# 2                              PRIDE
# 3                              PRIDE
# 4                              PRIDE
# ...                              ...
# 34874                          PRIDE
# 34875                          PRIDE
# 34876                          PRIDE
# 34877                          PRIDE
# 34878                          iProX
#
#                                                    title  \
# 0      Proteomics reveals the function reverse of MPS...
# 1      Rapid and high coverage profile of human cyste...
# 2      Combining label-free and label-based accurate ...
# 3      Fusarium oxysporum f. sp. vasinfectum (UP00003...
# 4      Spectral library for SARS-COVID proteome and i...
# ...                                                  ...
# 34874  Casein Kinase 1 functions in eukaryotic non-tr...
# 34875         SILAC APMS analysis of CCDC103 interactome
# 34876  Widespread somatic L1 retrotransposition occur...
# 34877  Arterial-Venous Endothelial Cell Cycle Protein...
# 34878  High concentration of prolactin induce oxidati...
#
#                                                 keywords  identifier_count
# 0      prostate CAFs, prostate cancer cells, secretomics                 1
# 1      Cysteine, FAIMS, SP3,Cysteine, FAIMS, SP3,Cyst...                 5
# 2      Beef meat quality, Data-Independent Acquisitio...                 1
# 3                      cotton, fungi, fusarium oxysporum                 1
# 4      HLA, ProteomeXchange project tag: Covid-19, SA...                 1
# ...                                                  ...               ...
# 34874  Ostreococcus tauri, Phosphoproteomics, casein ...                 1
# 34875              APMS, Hela cells, LTQ-Orbitrap, SILAC                 1
# 34876  L1, Retrotransposon, adenoma, carcinoma, color...                 1
# 34877  HUVEC, S/G2/M, cell cycle, early G1, endotheli...                 1
# 34878           Prolactin, ovine ovarian granulosa cells                 1
#
# [34879 rows x 6 columns]

# %%
# save to csv
df_grouped.to_csv('exp_input/publication_data_citations_PXD.csv', index=False)
