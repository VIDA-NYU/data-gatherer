# %%
import re
import requests
from xml.etree import ElementTree
import json
import pandas as pd
import time
from data_fetcher import *
from parser import *
from orchestrator import *
from dotenv import load_dotenv
import ast  # To safely evaluate string representation of a list
import bdikit as bdi

# %%
esearch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
params = {
    "db": "gds",  # Search in GEO database
    "term": '"gse"[Entry Type]',  # Only fetch GEO Series (GSE)
    "retmax": "1000000",  # Maximum records to retrieve (adjust as needed)
    "retmode": "xml"
}

# Request dataset IDs from NCBI
response = requests.get(esearch_url, params=params)
root = ElementTree.fromstring(response.content)

# Extract dataset IDs
gse_ids = [id_elem.text for id_elem in root.findall(".//Id")]

print(f"Total datasets found: {len(gse_ids)}")
print("Sample GSE IDs:", gse_ids[:10])  # Show first 10 results
# Out:
# Total datasets found: 248384
# Sample GSE IDs: ['200291028', '200290741', '200290722', '200290718', '200290678', '200290658', '200290614', '200290157', '200289999', '200289807']

# %%
def fetch_GEO_data(IDs,request_url,start,stop):
    params = {
        "db": "gds",
        "id": ",".join(IDs[start:stop]),  # Query for first 10 datasets
        "retmode": "json"
    }

    response = requests.get(request_url, params=params)
    
    try:
        data = response.json()
    except:
        raise ValueError("Failed to parse JSON response! Please check the response content.")
    
    return data

# %%
pd.DataFrame(fetch_GEO_data(gse_ids,"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi",0,2))
# Out:
#              header                                             result
# type       esummary                                                NaN
# version         0.3                                                NaN
# uids            NaN                             [200291028, 200290741]
# 200291028       NaN  {'uid': '200291028', 'accession': 'GSE291028',...
# 200290741       NaN  {'uid': '200290741', 'accession': 'GSE290741',...

# %%
# load the data from local file
print("Loading local data...")
try:
    df0 = pd.read_csv("exp_input/GEO_data.csv")
    df0 = df0.drop(columns=["Unnamed: 0"])
    # drop null columns
    df0 = df0.dropna(axis=1, how='all')
    print(f"Shape: {df0.shape}")
    print(f"Columns: {df0.columns}")
except:
    df0 = None
    print("No local data found.")
# Out:
# Loading local data...
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_17725/3066063973.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("exp_input/GEO_data.csv")
# Shape: (248387, 21)
# Columns: Index(['uid', 'accession', 'gds', 'title', 'summary', 'gpl', 'gse', 'taxon',
#        'entrytype', 'gdstype', 'pdat', 'suppfile', 'samples', 'relations',
#        'extrelations', 'n_samples', 'pubmedids', 'projects', 'ftplink',
#        'geo2r', 'bioproject'],
#       dtype='object')

# %%
# update dataset with new data whose id is not in the local dataset
if df0 is not None:
    all_ids = set(gse_ids)
    old_ids = set(list(df0["uid"].apply(str)))
    missing_ids = all_ids - old_ids
    
    print(f"Total missing datasets found: {len(missing_ids)}")
    
    data = {}
    step = 1
    
    for i, id in enumerate(missing_ids):
        if i % (len(missing_ids)//10) == 0 and i > 0:
            print(f"Iter {i}")
        try:
            new_data = fetch_GEO_data(list(missing_ids),"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi", i, i+step)
            # print(f"Data: {type(new_data)}")
            # print(f"Data: {new_data.keys()}")
            if "result" not in new_data:
                print(f"new_data: {new_data}")
            for uid, details in new_data['result'].items():
                if uid == "uids":  # Ignore metadata key
                    continue
                data[uid] = details
        except Exception as e:
            raise ValueError(f"Failed to fetch data for {id}! Error: {e}")
        
        time.sleep(0.33)  # Be nice to the server

else:
    data = {}
    i = 0
    mxm = 300
    while True:
        print(i)
        if i > len(gse_ids):
            break
        try:
            new_data = fetch_GEO_data(gse_ids,"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi",i,mxm)
            #print(f"Data: {new_data}")
            for uid, details in new_data["result"].items():
                if uid == "uids":  # Ignore metadata key
                    continue
                data[uid] = details
        except:
            print(f"Error at {i}, {mxm}")
            
        i += 300
        mxm += 300
        time.sleep(0.1)
# Out:
# Total missing datasets found: 0

# %%
df = pd.DataFrame(data).T
df = df.dropna(axis=1, how='all')
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns}")
# Out:
# Shape: (0, 0)
# Columns: RangeIndex(start=0, stop=0, step=1)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# union of both dataframes
df = pd.concat([df0,df])
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns}")
# Out:
# Shape: (248387, 21)
# Columns: Index(['uid', 'accession', 'gds', 'title', 'summary', 'gpl', 'gse', 'taxon',
#        'entrytype', 'gdstype', 'pdat', 'suppfile', 'samples', 'relations',
#        'extrelations', 'n_samples', 'pubmedids', 'projects', 'ftplink',
#        'geo2r', 'bioproject'],
#       dtype='object')

# %%
df.to_csv("exp_input/GEO_data.csv")

# %%
# use False Positives from a data-gatherer model run
gse_FPs = []
# Sample false positives load from txt file where separated by newline
with open("exp_output/model_FPs.txt", "r") as file:
    false_positives = file.read().splitlines()

for fp in false_positives:
    if 'gse' in fp and 'https' in fp:
        fp = fp.split("=")[-1]
        gse_FPs.append(fp)
    elif 'gse' in fp:
        gse_FPs.append(fp)

print(f"Total false positives found: {len(gse_FPs)}")
# Out:
# Total false positives found: 36

# %%
# no capital case in accession
df["accession"] = df["accession"].astype(str).str.lower()
# iterate
i = 0
gse_uids = []
for fp in gse_FPs:
    # check if false positive is in the dataset
    if fp in df["accession"].values:
        i+=1
        # drop false positive from dataset
        #print(f"False positive {fp} FOUND in dataset.")
        gse_uids.append(fp)
    else:
        print(f"False positive {fp} NOT FOUND in dataset.")

print(f"Total false positives found also in local GEO data: {i}")
#print(f"Unique false positives found: {len(set(gse_uids))}")
# Out:
# Total false positives found also in local GEO data: 36

# %%
# get all false positives from dataframe
df_FPs = df[df["accession"].isin(gse_uids)]
df_FPs
# Out:
#               uid  accession  gds  \
# 1936    200247291  gse247291  NaN
# 2349    200195983  gse195983  NaN
# 2759    200252821  gse252821  NaN
# 4767    200267957  gse267957  NaN
# 6823    200283213  gse283213  NaN
# 16154   200269782  gse269782  NaN
# 46541   200229376  gse229376  NaN
# 51322   200228201  gse228201  NaN
# 62852   200197265  gse197265  NaN
# 74285   200165782  gse165782  NaN
# 82664   200169632  gse169632  NaN
# 113698  200132355  gse132355  NaN
# 115816  200148568  gse148568  NaN
# 118628  200132730  gse132730  NaN
# 124924  200138760  gse138760  NaN
# 129003  200119960  gse119960  NaN
# 130045  200135893  gse135893  NaN
# 139212  200122005  gse122005  NaN
# 145418  200119615  gse119615  NaN
# 153914  200094460   gse94460  NaN
# 156237  200106765  gse106765  NaN
# 164315  200081283   gse81283  NaN
# 164741  200087544   gse87544  NaN
# 168059  200087328   gse87328  NaN
# 185759  200074279   gse74279  NaN
# 186108  200072064   gse72064  NaN
# 186747  200066715   gse66715  NaN
# 187788  200060189   gse60189  NaN
# 188147  200071587   gse71587  NaN
# 191222  200059239   gse59239  NaN
# 197567  200053743   gse53743  NaN
# 207278  200036552   gse36552  NaN
# 214737  200037699   gse37699  NaN
# 216946  200038121   gse38121  NaN
# 217758  200036892   gse36892  NaN
# 221705  200031210   gse31210  NaN
#
#                                                     title  \
# 1936    Adipocyte-specific Steap4 deficiency reduced t...
# 2349                Transcriptome profile of EZR_KO cells
# 2759    Sphingolipid metabolism orchestrates the estab...
# 4767    Transcriptome analyses of Leishmania donovani ...
# 6823    Comparative proteomic landscapes provide insig...
# 16154   Defective N-Glycosylation of IL6 Induces Metas...
# 46541   Defining blood-induced microglia functions in ...
# 51322   Reading and writing of mRNA m6A modification o...
# 62852   Translatome and transcriptome co-profiling rev...
# 74285   Ultrasensitive Ribo-seq reveals translational ...
# 82664   Profiling and functional characterization of m...
# 113698  Single cell RNA-Seq identifies mechanisms cont...
# 115816  Grouped ensemble coding of behavioral states b...
# 118628  Design logic of hypothalamus development mappe...
# 124924  High resolution and allelic-specific annotatio...
# 129003  Single cell sequencing of hypothalamus tissues...
# 130045  Single-cell RNA-sequencing reveals profibrotic...
# 139212  Activation of IGFBP7 Drives Resistance to Epid...
# 145418  Translation of upstream open reading frames in...
# 153914                Ribosome profiling of HEK293 cells.
# 156237  Increased expression of Ankyrin repeat domain ...
# 164315  Translational contributions to tissue-specific...
# 164741  Single-cell RNA-seq reveals hypothalamic cell ...
# 168059  eIF1 modulates the recognition of sub-optimal ...
# 185759  Positional proteomics reveals differences in N...
# 186108  Genome-wide profilings of transcriptome and tr...
# 186747  Integrated Transcriptome and Proteome Analyses...
# 187788  IL-8 Confers Acquired Resistance to EGFR Inhib...
# 188147  Gene expression data from HCC4006 and HCC4006E...
# 191222  Acquired resistance to mutant-selective EGFR i...
# 197567  Translational profiling in the unfolded protei...
# 207278  Tracing pluripotency of human early embryos an...
# 214737  Aberrant ERK signaling causes resistance to EG...
# 216946  Gene expression profiling of generated Erlotin...
# 217758  A unifying model for mTORC1-mediated regulatio...
# 221705  Gene expression data for pathological stage I-...
#
#                                                   summary                gpl  \
# 1936    Steap4, highly expressed in adipose tissue, is...              24247
# 2349    To analyze gene expression differences between...              24247
# 2759    Bioactive sphingolipids serve as an essential ...              19057
# 4767    This study was performed with the goal of unde...              34491
# 6823    Understanding mammalian preimplantation develo...              21273
# 16154   The biological consequences of various IL-6 gl...              14550
# 46541   This SuperSeries is composed of the SubSeries ...        21103;24247
# 51322   Background: Maternal and zygotic mRNAs play cr...              21273
# 62852   Translational regulation plays a critical role...              24676
# 74285   In mammals, translational control plays critic...        18480;29177
# 82664   Translational regulation plays an important ro...        19057;13112
# 113698  The hypothalamus is a central regulator of man...              19057
# 115816  We used a plate-based method (SMART-SCRB) to t...              17021
# 118628  Purpose: We aimed to reconstruct the developme...              21103
# 124924  We used an combination of long-read and short-...        24198;24247
# 129003  A single cell suspension was generated from ID...              21103
# 130045  Pulmonary fibrosis (PF) is a form of chronic l...  18573;24676;20301
# 139212  Previous study has demonstrated that HCC827/ge...                570
# 145418  Upstream open reading frames (uORFs) initiate ...              11154
# 153914  The development of the ribosome profiling (rib...              16791
# 156237  EGFR tyrosine kinase inhibitors (EGFR-TKIs) in...              16686
# 164315  BACKGROUND: The daily gene expression oscillat...              17021
# 164741  We performed single-cell RNA-seq of mouse hypo...              17021
# 168059  Alternative translation initiation mechanisms ...              18573
# 185759  To understand the impact of alternative transl...              18573
# 186108  Memory stabilization after learning requires t...              13112
# 186747  Aging is associated with the decline of protei...              14844
# 187788  Previous study has demonstrated that PC9/gef c...                570
# 188147  We generated erlotinib-resistant HCC4006 cells...                570
# 191222  To compare gene copy number in cell population...               9777
# 197567  The unfolded protein response (UPR) couples ce...              13112
# 207278  Find the casual relationship between gene expr...              11154
# 214737  The clinical efficacy of EGFR kinase inhibitor...                571
# 216946  Targeted therapies have provided advantages to...                570
# 217758  Ribsome profiling analysis of mRNA translation...               9250
# 221705  Identification of genes up-regulated in ALK-po...                570
#
#            gse                taxon entrytype  \
# 1936    247291         Mus musculus       GSE
# 2349    195983         Mus musculus       GSE
# 2759    252821         Mus musculus       GSE
# 4767    267957  Leishmania donovani       GSE
# 6823    283213         Mus musculus       GSE
# 16154   269782         Homo sapiens       GSE
# 46541   229376         Mus musculus       GSE
# 51322   228201         Mus musculus       GSE
# 62852   197265         Homo sapiens       GSE
# 74285   165782         Mus musculus       GSE
# 82664   169632         Mus musculus       GSE
# 113698  132355         Mus musculus       GSE
# 115816  148568         Mus musculus       GSE
# 118628  132730         Mus musculus       GSE
# 124924  138760         Mus musculus       GSE
# 129003  119960         Mus musculus       GSE
# 130045  135893         Homo sapiens       GSE
# 139212  122005         Homo sapiens       GSE
# 145418  119615         Homo sapiens       GSE
# 153914   94460         Homo sapiens       GSE
# 156237  106765         Homo sapiens       GSE
# 164315   81283         Mus musculus       GSE
# 164741   87544         Mus musculus       GSE
# 168059   87328         Homo sapiens       GSE
# 185759   74279         Homo sapiens       GSE
# 186108   72064         Mus musculus       GSE
# 186747   66715    Rattus norvegicus       GSE
# 187788   60189         Homo sapiens       GSE
# 188147   71587         Homo sapiens       GSE
# 191222   59239         Homo sapiens       GSE
# 197567   53743         Mus musculus       GSE
# 207278   36552         Homo sapiens       GSE
# 214737   37699         Homo sapiens       GSE
# 216946   38121         Homo sapiens       GSE
# 217758   36892         Mus musculus       GSE
# 221705   31210         Homo sapiens       GSE
#
#                                                   gdstype  ...  \
# 1936    Expression profiling by high throughput sequen...  ...
# 2349    Expression profiling by high throughput sequen...  ...
# 2759    Expression profiling by high throughput sequen...  ...
# 4767    Expression profiling by high throughput sequen...  ...
# 6823    Expression profiling by high throughput sequen...  ...
# 16154                       Expression profiling by array  ...
# 46541   Expression profiling by high throughput sequen...  ...
# 51322   Expression profiling by high throughput sequen...  ...
# 62852   Expression profiling by high throughput sequen...  ...
# 74285   Expression profiling by high throughput sequen...  ...
# 82664   Expression profiling by high throughput sequen...  ...
# 113698  Expression profiling by high throughput sequen...  ...
# 115816  Expression profiling by high throughput sequen...  ...
# 118628  Expression profiling by high throughput sequen...  ...
# 124924  Expression profiling by high throughput sequen...  ...
# 129003  Expression profiling by high throughput sequen...  ...
# 130045  Expression profiling by high throughput sequen...  ...
# 139212                      Expression profiling by array  ...
# 145418  Expression profiling by high throughput sequen...  ...
# 153914                                              Other  ...
# 156237                      Expression profiling by array  ...
# 164315  Expression profiling by high throughput sequen...  ...
# 164741  Expression profiling by high throughput sequen...  ...
# 168059  Expression profiling by high throughput sequen...  ...
# 185759  Expression profiling by high throughput sequen...  ...
# 186108  Expression profiling by high throughput sequen...  ...
# 186747  Expression profiling by high throughput sequen...  ...
# 187788                      Expression profiling by array  ...
# 188147                      Expression profiling by array  ...
# 191222                Genome variation profiling by array  ...
# 197567  Expression profiling by high throughput sequen...  ...
# 207278  Expression profiling by high throughput sequen...  ...
# 214737                      Expression profiling by array  ...
# 216946                      Expression profiling by array  ...
# 217758  Expression profiling by high throughput sequen...  ...
# 221705                      Expression profiling by array  ...
#
#                        suppfile  \
# 1936                        TXT
# 2349                        TXT
# 2759        H5AD, MTX, TSV, TXT
# 4767                        CSV
# 6823                        TXT
# 16154                       TXT
# 46541                  MTX, TSV
# 51322                  TSV, TXT
# 62852         BEDGRAPH, BW, TXT
# 74285                   BW, TXT
# 82664               BIGWIG, TXT
# 113698  CSV, MTX, RDS, TSV, TXT
# 115816                      CSV
# 118628        GRAPHML, RDS, TSV
# 124924            GFF, GTF, TXT
# 129003                      TXT
# 130045  CSV, MTX, RDS, TSV, TXT
# 139212                      CEL
# 145418            FPKM_TRACKING
# 153914                      TXT
# 156237                      CEL
# 164315                      TXT
# 164741          CSV, RDATA, TXT
# 168059                 BEDGRAPH
# 185759                 BEDGRAPH
# 186108                      CSV
# 186747                      TXT
# 187788                      CEL
# 188147                 CEL, CHP
# 191222                      TXT
# 197567                     XLSX
# 207278            BED, TDF, TXT
# 214737                 CEL, CHP
# 216946                 CEL, XLS
# 217758                      TXT
# 221705                      CEL
#
#                                                   samples relations  \
# 1936    [{'accession': 'GSM7886717', 'title': 'Steap4f...        []
# 2349    [{'accession': 'GSM5857265', 'title': 'MEFs, w...        []
# 2759    [{'accession': 'GSM8008506', 'title': 'Epiderm...        []
# 4767    [{'accession': 'GSM8282498', 'title': 'exp 2 s...        []
# 6823    [{'accession': 'GSM8658087', 'title': 'Zfp622_...        []
# 16154   [{'accession': 'GSM8327196', 'title': 'AS2-Vec...        []
# 46541   [{'accession': 'GSM7159423', 'title': 'RNAseq_...        []
# 51322   [{'accession': 'GSM7116568', 'title': 'IP-L2C-...        []
# 62852   [{'accession': 'GSM5911848', 'title': 'h_siTPR...        []
# 74285   [{'accession': 'GSM5049855', 'title': 'mES_sma...        []
# 82664   [{'accession': 'GSM5211316', 'title': 'RNA_Zyg...        []
# 113698  [{'accession': 'GSM3860733', 'title': 'Hypotha...        []
# 115816  [{'accession': 'GSM4473701', 'title': 'Plate_A...        []
# 118628  [{'accession': 'GSM3890940', 'title': 'FC2P10'...        []
# 124924  [{'accession': 'GSM4118745', 'title': 'DBA/2J ...        []
# 129003  [{'accession': 'GSM3389513', 'title': 'Mouse h...        []
# 130045  [{'accession': 'GSM4037321', 'title': 'Lung Bi...        []
# 139212  [{'accession': 'GSM3452892', 'title': 'Acquire...        []
# 145418  [{'accession': 'GSM3378864', 'title': '33315 R...        []
# 153914  [{'accession': 'GSM2867900', 'title': 'HEK293 ...        []
# 156237  [{'accession': 'GSM2850073', 'title': 'HCC827-...        []
# 164315  [{'accession': 'GSM2149109', 'title': 'RP_ZT6_...        []
# 164741  [{'accession': 'GSM2333583', 'title': 'B1-norm...        []
# 168059  [{'accession': 'GSM2327826', 'title': 'Ribosom...        []
# 185759  [{'accession': 'GSM1916181', 'title': 'Lactimi...        []
# 186108  [{'accession': 'GSM1854010', 'title': 'RNA-seq...        []
# 186747  [{'accession': 'GSM1630467', 'title': '241L_mR...        []
# 187788  [{'accession': 'GSM1467270', 'title': 'Acquire...        []
# 188147  [{'accession': 'GSM1841014', 'title': 'HCC4006...        []
# 191222  [{'accession': 'GSM1431151', 'title': 'PC9 WZ4...        []
# 197567  [{'accession': 'GSM1299856', 'title': 'fpWNM1'...        []
# 207278  [{'accession': 'GSM922202', 'title': 'Late bla...        []
# 214737  [{'accession': 'GSM925743', 'title': 'NCI-H197...        []
# 216946  [{'accession': 'GSM935083', 'title': 'HCC 827'...        []
# 217758  [{'accession': 'GSM904899', 'title': 'mRNA-seq...        []
# 221705  [{'accession': 'GSM773774', 'title': 'KH199'},...        []
#
#                                              extrelations n_samples  \
# 1936                                                   []       6.0
# 2349                                                   []       8.0
# 2759                                                   []       4.0
# 4767                                                   []       6.0
# 6823                                                   []      24.0
# 16154                                                  []       9.0
# 46541                                                  []      63.0
# 51322                                                  []      24.0
# 62852                                                  []     226.0
# 74285   [{'relationtype': 'SRA', 'targetobject': 'SRP3...     105.0
# 82664   [{'relationtype': 'SRA', 'targetobject': 'SRP3...      50.0
# 113698  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      27.0
# 115816  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      10.0
# 118628  [{'relationtype': 'SRA', 'targetobject': 'SRP2...       8.0
# 124924  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      21.0
# 129003  [{'relationtype': 'SRA', 'targetobject': 'SRP1...       6.0
# 130045  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      34.0
# 139212                                                 []       6.0
# 145418  [{'relationtype': 'SRA', 'targetobject': 'SRP1...      10.0
# 153914  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       3.0
# 156237                                                 []       6.0
# 164315  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      48.0
# 164741  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      17.0
# 168059  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       6.0
# 185759  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       2.0
# 186108  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      34.0
# 186747  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      24.0
# 187788                                                 []       6.0
# 188147                                                 []       2.0
# 191222                                                 []      14.0
# 197567  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      52.0
# 207278  [{'relationtype': 'SRA', 'targetobject': 'SRP0...     124.0
# 214737                                                 []       6.0
# 216946                                                 []       3.0
# 217758  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      12.0
# 221705                                                 []     246.0
#
#                                                pubmedids projects  \
# 1936                                                  []       []
# 2349                                        ['39937579']       []
# 2759                                                  []       []
# 4767                                                  []       []
# 6823                                                  []       []
# 16154                                       ['39251588']       []
# 46541                                       ['37291385']       []
# 51322                                       ['37024923']       []
# 62852                                       ['36074823']       []
# 74285                                       ['35697785']       []
# 82664                           ['35108058', '36333315']       []
# 113698                          ['32868762', '35045288']       []
# 115816                                                []       []
# 118628  ['32499648', '32442405', '36209152', '39366958']       []
# 124924                                      ['32461551']       []
# 129003                                                []       []
# 130045                                      ['32832598']       []
# 139212                                      ['30609749']       []
# 145418                                      ['31109297']       []
# 153914                                      ['29170441']       []
# 156237                                      ['30291293']       []
# 164315                                      ['28622766']       []
# 164741                                      ['28355573']       []
# 168059                                      ['28541577']       []
# 185759                                      ['26893308']       []
# 186108                                      ['26430118']       []
# 186747                                      ['27135913']       []
# 187788                                      ['25871388']       []
# 188147                                                []       []
# 191222                                      ['25870145']       []
# 197567                          ['25215492', '27161320']       []
# 207278                          ['23934149', '32968278']       []
# 214737                                      ['22961667']       []
# 216946                                      ['22751098']       []
# 217758                                      ['22552098']       []
# 221705                          ['22080568', '23028479']       []
#
#                                                   ftplink geo2r    bioproject
# 1936    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE247nn...    no  PRJNA1037060
# 2349    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE195nn...    no   PRJNA802830
# 2759    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE252nn...    no  PRJNA1062771
# 4767    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE267nn...    no  PRJNA1113700
# 6823    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE283nn...    no  PRJNA1191977
# 16154   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE269nn...   yes  PRJNA1123684
# 46541   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE229nn...    no   PRJNA954299
# 51322   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE228nn...    no   PRJNA947496
# 62852   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE197nn...   yes   PRJNA809587
# 74285   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE165nn...    no   PRJNA697913
# 82664   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nn...    no   PRJNA717246
# 113698  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA547712
# 115816  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE148nn...    no   PRJNA625041
# 118628  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA548917
# 124924  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE138nn...    no   PRJNA577068
# 129003  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE119nn...    no   PRJNA490830
# 130045  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE135nn...    no   PRJNA560492
# 139212  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE122nn...   yes   PRJNA503109
# 145418  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE119nn...   yes   PRJNA489713
# 153914  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE94nnn...    no   PRJNA369756
# 156237  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE106nn...   yes   PRJNA417935
# 164315  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE81nnn...    no   PRJNA321185
# 164741  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE87nnn...    no   PRJNA345147
# 168059  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE87nnn...   yes   PRJNA344393
# 185759  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE74nnn...    no   PRJNA299254
# 186108  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE72nnn...    no   PRJNA292861
# 186747  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE66nnn...    no   PRJNA277771
# 187788  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE60nnn...   yes   PRJNA257715
# 188147  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE71nnn...   yes   PRJNA291569
# 191222  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE59nnn...   yes   PRJNA254803
# 197567  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE53nnn...    no   PRJNA232779
# 207278  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE36nnn...    no   PRJNA153427
# 214737  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE37nnn...   yes   PRJNA162711
# 216946  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE38nnn...   yes   PRJNA167352
# 217758  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE36nnn...    no   PRJNA157105
# 221705  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE31nnn...   yes   PRJNA145977
#
# [36 rows x 21 columns]

# %%
# function to get PMCid and doi from pubmed id
config_path = 'config_experiment.json'  # Config with input file details
load_dotenv()
orchestrator = Orchestrator(config_path)
orchestrator.setup_data_fetcher()
# Out:
# orchestrator.py - line 20 - INFO - Data_Gatherer Orchestrator initialized. Extraction step Model: gemini-2.0-flash-exp
# orchestrator.py - line 45 - INFO - Data fetcher setup completed.
# <selenium.webdriver.firefox.webdriver.WebDriver (session="f8062c9f-b6a3-46a0-9c08-cdcb65ee380a")>

# %%
for i, row in df_FPs.iterrows():
    pubmed_id = row["pubmedids"]
    orchestrator.logger.info(f"PubMed id: {pubmed_id} --item {i+1}")  
    
    # Convert string representation of list to an actual list
    if isinstance(pubmed_id, str) and pubmed_id.startswith("["):
        pubmed_id = ast.literal_eval(pubmed_id)  # Converts to a real list
        pubmed_ids = pubmed_id if pubmed_id else None  # Extract the first element
        
    if pubmed_ids is None:    
        orchestrator.logger.info(f"pubmed_ids is None")  
        continue

    orchestrator.logger.info(f"Type of elements in pubmed_ids <class 'list'>: {[type(item) for item in pubmed_ids]}")  # Should now be <class 'str'>
    
    pmc_ids, dois = [], []
    
    for pmid in pubmed_ids:    
        pmc_id, doi = orchestrator.data_fetcher.get_opendata_from_pubmed_id(pmid)
        pmc_ids.append(pmc_id)
        dois.append(doi)
        
    orchestrator.logger.info(f"PMC ID: {pmc_ids}")
    orchestrator.logger.info(f"DOI: {dois}\n")
    
    #Store results
    df_FPs.loc[i, "pmcids"] = ",".join([str(x) for x in pmc_ids if x]) if any(pmc_ids) else None
    df_FPs.loc[i, "dois"] = ",".join([str(x) for x in dois if x]) if any(dois) else None

orchestrator.data_fetcher.quit()
# Out:
# 328664979.py - line 3 - INFO - PubMed id: [] --item 1937
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: ['39937579'] --item 2350
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/39937579/
# data_fetcher.py - line 207 - INFO - PMCID: PMC11820125
# data_fetcher.py - line 215 - INFO - DOI: 10.7554/eLife.98523
# 328664979.py - line 23 - INFO - PMC ID: ['PMC11820125']
# 328664979.py - line 24 - INFO - DOI: ['10.7554/eLife.98523']
#
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_17725/328664979.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FPs.loc[i, "pmcids"] = ",".join([str(x) for x in pmc_ids if x]) if any(pmc_ids) else None
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_17725/328664979.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FPs.loc[i, "dois"] = ",".join([str(x) for x in dois if x]) if any(dois) else None
# 328664979.py - line 3 - INFO - PubMed id: [] --item 2760
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: [] --item 4768
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: [] --item 6824
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: ['39251588'] --item 16155
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/39251588/
# data_fetcher.py - line 207 - INFO - PMCID: PMC11385228
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-024-51831-7
# 328664979.py - line 23 - INFO - PMC ID: ['PMC11385228']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41467-024-51831-7']
#
# 328664979.py - line 3 - INFO - PubMed id: ['37291385'] --item 46542
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/37291385/
# data_fetcher.py - line 207 - INFO - PMCID: PMC10307624
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41590-023-01522-0
# 328664979.py - line 23 - INFO - PMC ID: ['PMC10307624']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41590-023-01522-0']
#
# 328664979.py - line 3 - INFO - PubMed id: ['37024923'] --item 51323
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/37024923/
# data_fetcher.py - line 207 - INFO - PMCID: PMC10080794
# data_fetcher.py - line 215 - INFO - DOI: 10.1186/s13059-023-02918-9
# 328664979.py - line 23 - INFO - PMC ID: ['PMC10080794']
# 328664979.py - line 24 - INFO - DOI: ['10.1186/s13059-023-02918-9']
#
# 328664979.py - line 3 - INFO - PubMed id: ['36074823'] --item 62853
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/36074823/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1126/science.abo7923
# 328664979.py - line 23 - INFO - PMC ID: [None]
# 328664979.py - line 24 - INFO - DOI: ['10.1126/science.abo7923']
#
# 328664979.py - line 3 - INFO - PubMed id: ['35697785'] --item 74286
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/35697785/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41556-022-00928-6
# 328664979.py - line 23 - INFO - PMC ID: [None]
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41556-022-00928-6']
#
# 328664979.py - line 3 - INFO - PubMed id: ['35108058', '36333315'] --item 82665
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/35108058/
# data_fetcher.py - line 207 - INFO - PMCID: PMC8809684
# data_fetcher.py - line 215 - INFO - DOI: 10.1126/sciadv.abj3967
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/36333315/
# data_fetcher.py - line 207 - INFO - PMCID: PMC9636173
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-022-34427-x
# 328664979.py - line 23 - INFO - PMC ID: ['PMC8809684', 'PMC9636173']
# 328664979.py - line 24 - INFO - DOI: ['10.1126/sciadv.abj3967', '10.1038/s41467-022-34427-x']
#
# 328664979.py - line 3 - INFO - PubMed id: ['32868762', '35045288'] --item 113699
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32868762/
# data_fetcher.py - line 207 - INFO - PMCID: PMC7459115
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-020-18231-z
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/35045288/
# data_fetcher.py - line 207 - INFO - PMCID: PMC8918062
# data_fetcher.py - line 215 - INFO - DOI: 10.1016/j.celrep.2021.110251
# 328664979.py - line 23 - INFO - PMC ID: ['PMC7459115', 'PMC8918062']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41467-020-18231-z', '10.1016/j.celrep.2021.110251']
#
# 328664979.py - line 3 - INFO - PubMed id: [] --item 115817
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: ['32499648', '32442405', '36209152', '39366958'] --item 118629
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32499648/
# data_fetcher.py - line 207 - INFO - PMCID: PMC7292733
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41586-020-2266-0
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32442405/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1016/j.cell.2020.04.034
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/36209152/
# data_fetcher.py - line 207 - INFO - PMCID: PMC9547883
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-022-33584-3
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/39366958/
# data_fetcher.py - line 207 - INFO - PMCID: PMC11452682
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-024-52762-z
# 328664979.py - line 23 - INFO - PMC ID: ['PMC7292733', None, 'PMC9547883', 'PMC11452682']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41586-020-2266-0', '10.1016/j.cell.2020.04.034', '10.1038/s41467-022-33584-3', '10.1038/s41467-024-52762-z']
#
# 328664979.py - line 3 - INFO - PubMed id: ['32461551'] --item 124925
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32461551/
# data_fetcher.py - line 207 - INFO - PMCID: PMC7253418
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-020-16444-w
# 328664979.py - line 23 - INFO - PMC ID: ['PMC7253418']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41467-020-16444-w']
#
# 328664979.py - line 3 - INFO - PubMed id: [] --item 129004
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: ['32832598'] --item 130046
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32832598/
# data_fetcher.py - line 207 - INFO - PMCID: PMC7439444
# data_fetcher.py - line 215 - INFO - DOI: 10.1126/sciadv.aba1972
# 328664979.py - line 23 - INFO - PMC ID: ['PMC7439444']
# 328664979.py - line 24 - INFO - DOI: ['10.1126/sciadv.aba1972']
#
# 328664979.py - line 3 - INFO - PubMed id: ['30609749'] --item 139213
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/30609749/
# data_fetcher.py - line 207 - INFO - PMCID: PMC6356910
# data_fetcher.py - line 215 - INFO - DOI: 10.3390/cancers11010036
# 328664979.py - line 23 - INFO - PMC ID: ['PMC6356910']
# 328664979.py - line 24 - INFO - DOI: ['10.3390/cancers11010036']
#
# 328664979.py - line 3 - INFO - PubMed id: ['31109297'] --item 145419
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/31109297/
# data_fetcher.py - line 207 - INFO - PMCID: PMC6528255
# data_fetcher.py - line 215 - INFO - DOI: 10.1186/s12864-019-5775-1
# 328664979.py - line 23 - INFO - PMC ID: ['PMC6528255']
# 328664979.py - line 24 - INFO - DOI: ['10.1186/s12864-019-5775-1']
#
# 328664979.py - line 3 - INFO - PubMed id: ['29170441'] --item 153915
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/29170441/
# data_fetcher.py - line 207 - INFO - PMCID: PMC5701008
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41467-017-01981-8
# 328664979.py - line 23 - INFO - PMC ID: ['PMC5701008']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41467-017-01981-8']
#
# 328664979.py - line 3 - INFO - PubMed id: ['30291293'] --item 156238
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/30291293/
# data_fetcher.py - line 207 - INFO - PMCID: PMC6173712
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41598-018-33190-8
# 328664979.py - line 23 - INFO - PMC ID: ['PMC6173712']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/s41598-018-33190-8']
#
# 328664979.py - line 3 - INFO - PubMed id: ['28622766'] --item 164316
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/28622766/
# data_fetcher.py - line 207 - INFO - PMCID: PMC5473967
# data_fetcher.py - line 215 - INFO - DOI: 10.1186/s13059-017-1222-2
# 328664979.py - line 23 - INFO - PMC ID: ['PMC5473967']
# 328664979.py - line 24 - INFO - DOI: ['10.1186/s13059-017-1222-2']
#
# 328664979.py - line 3 - INFO - PubMed id: ['28355573'] --item 164742
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/28355573/
# data_fetcher.py - line 207 - INFO - PMCID: PMC5782816
# data_fetcher.py - line 215 - INFO - DOI: 10.1016/j.celrep.2017.03.004
# 328664979.py - line 23 - INFO - PMC ID: ['PMC5782816']
# 328664979.py - line 24 - INFO - DOI: ['10.1016/j.celrep.2017.03.004']
#
# 328664979.py - line 3 - INFO - PubMed id: ['28541577'] --item 168060
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/28541577/
# data_fetcher.py - line 207 - INFO - PMCID: PMC5570006
# data_fetcher.py - line 215 - INFO - DOI: 10.1093/nar/gkx469
# 328664979.py - line 23 - INFO - PMC ID: ['PMC5570006']
# 328664979.py - line 24 - INFO - DOI: ['10.1093/nar/gkx469']
#
# 328664979.py - line 3 - INFO - PubMed id: ['26893308'] --item 185760
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/26893308/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4770386
# data_fetcher.py - line 215 - INFO - DOI: 10.15252/msb.20156662
# 328664979.py - line 23 - INFO - PMC ID: ['PMC4770386']
# 328664979.py - line 24 - INFO - DOI: ['10.15252/msb.20156662']
#
# 328664979.py - line 3 - INFO - PubMed id: ['26430118'] --item 186109
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/26430118/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1126/science.aac7368
# 328664979.py - line 23 - INFO - PMC ID: [None]
# 328664979.py - line 24 - INFO - DOI: ['10.1126/science.aac7368']
#
# 328664979.py - line 3 - INFO - PubMed id: ['27135913'] --item 186748
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/27135913/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4802414
# data_fetcher.py - line 215 - INFO - DOI: 10.1016/j.cels.2015.08.012
# 328664979.py - line 23 - INFO - PMC ID: ['PMC4802414']
# 328664979.py - line 24 - INFO - DOI: ['10.1016/j.cels.2015.08.012']
#
# 328664979.py - line 3 - INFO - PubMed id: ['25871388'] --item 187789
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/25871388/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4496364
# data_fetcher.py - line 215 - INFO - DOI: 10.18632/oncotarget.3389
# 328664979.py - line 23 - INFO - PMC ID: ['PMC4496364']
# 328664979.py - line 24 - INFO - DOI: ['10.18632/oncotarget.3389']
#
# 328664979.py - line 3 - INFO - PubMed id: [] --item 188148
# 328664979.py - line 11 - INFO - pubmed_ids is None
# 328664979.py - line 3 - INFO - PubMed id: ['25870145'] --item 191223
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/25870145/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4605607
# data_fetcher.py - line 215 - INFO - DOI: 10.1158/0008-5472.CAN-14-3167
# 328664979.py - line 23 - INFO - PMC ID: ['PMC4605607']
# 328664979.py - line 24 - INFO - DOI: ['10.1158/0008-5472.CAN-14-3167']
#
# 328664979.py - line 3 - INFO - PubMed id: ['25215492', '27161320'] --item 197568
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/25215492/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4163055
# data_fetcher.py - line 215 - INFO - DOI: 10.1016/j.cell.2014.08.012
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/27161320/
# data_fetcher.py - line 207 - INFO - PMCID: PMC4911741
# data_fetcher.py - line 215 - INFO - DOI: 10.1128/MCB.00190-16
# 328664979.py - line 23 - INFO - PMC ID: ['PMC4163055', 'PMC4911741']
# 328664979.py - line 24 - INFO - DOI: ['10.1016/j.cell.2014.08.012', '10.1128/MCB.00190-16']
#
# 328664979.py - line 3 - INFO - PubMed id: ['23934149', '32968278'] --item 207279
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/23934149/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/nsmb.2660
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/32968278/
# data_fetcher.py - line 207 - INFO - PMCID: PMC7116563
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/s41586-020-2759-x
# 328664979.py - line 23 - INFO - PMC ID: [None, 'PMC7116563']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/nsmb.2660', '10.1038/s41586-020-2759-x']
#
# 328664979.py - line 3 - INFO - PubMed id: ['22961667'] --item 214738
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/22961667/
# data_fetcher.py - line 207 - INFO - PMCID: PMC3477553
# data_fetcher.py - line 215 - INFO - DOI: 10.1158/2159-8290.CD-12-0103
# 328664979.py - line 23 - INFO - PMC ID: ['PMC3477553']
# 328664979.py - line 24 - INFO - DOI: ['10.1158/2159-8290.CD-12-0103']
#
# 328664979.py - line 3 - INFO - PubMed id: ['22751098'] --item 216947
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/22751098/
# data_fetcher.py - line 207 - INFO - PMCID: PMC3408577
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/ng.2330
# 328664979.py - line 23 - INFO - PMC ID: ['PMC3408577']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/ng.2330']
#
# 328664979.py - line 3 - INFO - PubMed id: ['22552098'] --item 217759
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/22552098/
# data_fetcher.py - line 207 - INFO - PMCID: PMC3347774
# data_fetcher.py - line 215 - INFO - DOI: 10.1038/nature11083
# 328664979.py - line 23 - INFO - PMC ID: ['PMC3347774']
# 328664979.py - line 24 - INFO - DOI: ['10.1038/nature11083']
#
# 328664979.py - line 3 - INFO - PubMed id: ['22080568', '23028479'] --item 221706
# 328664979.py - line 14 - INFO - Type of elements in pubmed_ids <class 'list'>: [<class 'str'>, <class 'str'>]
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/22080568/
# data_fetcher.py - line 207 - INFO - PMCID: None
# data_fetcher.py - line 215 - INFO - DOI: 10.1158/0008-5472.CAN-11-1403
# data_fetcher.py - line 220 - INFO - Reconstructed URL: https://pubmed.ncbi.nlm.nih.gov/23028479/
# data_fetcher.py - line 207 - INFO - PMCID: PMC3446964
# data_fetcher.py - line 215 - INFO - DOI: 10.1371/journal.pone.0043923
# 328664979.py - line 23 - INFO - PMC ID: [None, 'PMC3446964']
# 328664979.py - line 24 - INFO - DOI: ['10.1158/0008-5472.CAN-11-1403', '10.1371/journal.pone.0043923']
#
# data_fetcher.py - line 265 - INFO - WebScraper driver quit.

# %%
print(f"Shape: {df_FPs.shape}")
print(f"Columns: {df_FPs.columns}")
# Out:
# Shape: (36, 23)
# Columns: Index(['uid', 'accession', 'gds', 'title', 'summary', 'gpl', 'gse', 'taxon',
#        'entrytype', 'gdstype', 'pdat', 'suppfile', 'samples', 'relations',
#        'extrelations', 'n_samples', 'pubmedids', 'projects', 'ftplink',
#        'geo2r', 'bioproject', 'pmcids', 'dois'],
#       dtype='object')

# %%
df_FPs_copy = df_FPs.copy()

# %%
df1 = pd.read_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")
df1 = df1.drop(columns=["Unnamed: 0"]) if "Unnamed: 0" in df1.columns else df1
print(f"Shape: {df1.shape}")
print(f"Columns: {df1.columns}")
# Out:
# Shape: (239, 7)
# Columns: Index(['publication', 'dataset_uid', 'repo_name', 'doi', 'raw_html',
#        'publisher', 'smallest_elements'],
#       dtype='object')

# %%
df1[['publication', 'dataset_uid', 'repo_name', 'doi']]
# Out:
#                                          publication  \
# 0    https://dx.doi.org/10.1001/JAMANEUROL.2024.4763
# 1          https://dx.doi.org/10.1002/CBIC.202400831
# 2          https://dx.doi.org/10.1002/CBIC.202400882
# 3          https://dx.doi.org/10.1002/PRCA.202300107
# 4          https://dx.doi.org/10.1002/anie.202420149
# ..                                               ...
# 234     https://www.ncbi.nlm.nih.gov/pubmed/39884247
# 235     https://www.ncbi.nlm.nih.gov/pubmed/39900909
# 236     https://www.ncbi.nlm.nih.gov/pubmed/39910101
# 237     https://www.ncbi.nlm.nih.gov/pubmed/39910614
# 238     https://www.ncbi.nlm.nih.gov/pubmed/39912552
#
#                        dataset_uid repo_name                           doi
# 0                        PXD056570     PRIDE  10.1001/jamaneurol.2024.4763
# 1                        PXD055649     PRIDE        10.1002/cbic.202400831
# 2                        PXD060372     PRIDE        10.1002/cbic.202400882
# 3                        PXD028078     PRIDE        10.1002/prca.202300107
# 4    PXD056865,PXD057925,PXD058045     PRIDE        10.1002/anie.202420149
# ..                             ...       ...                           ...
# 234                      PXD054970     PRIDE                           NaN
# 235                      PXD058955     PRIDE                           NaN
# 236                      PXD060051     iProX                           NaN
# 237                      PXD060193     iProX                           NaN
# 238                      PXD051312     PRIDE                           NaN
#
# [239 rows x 4 columns]

# %%
df_FPs.loc[:, "dois"] = df_FPs["dois"].astype(str).str.lower()
df1.loc[:, "doi"] = df1['doi'].astype(str).str.lower()

print(f'FP DOI: {df_FPs["dois"]}')

for dois in df_FPs["dois"]:
    for doi in dois.split(","):
        if doi == "nan":
            continue
        if doi in df1["doi"].values:
            print(f"DOI {doi} found in df1")
        else:
            continue
# Out:
# FP DOI: 1936                                                    nan
# 2349                                    10.7554/elife.98523
# 2759                                                    nan
# 4767                                                    nan
# 6823                                                    nan
# 16154                            10.1038/s41467-024-51831-7
# 46541                            10.1038/s41590-023-01522-0
# 51322                            10.1186/s13059-023-02918-9
# 62852                               10.1126/science.abo7923
# 74285                            10.1038/s41556-022-00928-6
# 82664     10.1126/sciadv.abj3967,10.1038/s41467-022-34427-x
# 113698    10.1038/s41467-020-18231-z,10.1016/j.celrep.20...
# 115816                                                  nan
# 118628    10.1038/s41586-020-2266-0,10.1016/j.cell.2020....
# 124924                           10.1038/s41467-020-16444-w
# 129003                                                  nan
# 130045                               10.1126/sciadv.aba1972
# 139212                              10.3390/cancers11010036
# 145418                            10.1186/s12864-019-5775-1
# 153914                           10.1038/s41467-017-01981-8
# 156237                           10.1038/s41598-018-33190-8
# 164315                            10.1186/s13059-017-1222-2
# 164741                         10.1016/j.celrep.2017.03.004
# 168059                                   10.1093/nar/gkx469
# 185759                                10.15252/msb.20156662
# 186108                              10.1126/science.aac7368
# 186747                           10.1016/j.cels.2015.08.012
# 187788                             10.18632/oncotarget.3389
# 188147                                                  nan
# 191222                        10.1158/0008-5472.can-14-3167
# 197567      10.1016/j.cell.2014.08.012,10.1128/mcb.00190-16
# 207278          10.1038/nsmb.2660,10.1038/s41586-020-2759-x
# 214737                         10.1158/2159-8290.cd-12-0103
# 216946                                      10.1038/ng.2330
# 217758                                  10.1038/nature11083
# 221705    10.1158/0008-5472.can-11-1403,10.1371/journal....
# Name: dois, dtype: object
# DOI 10.1038/s41467-024-51831-7 found in df1

# %%
# explode the dois column which is a string of multiple dois separated by commas
df_FPs = df_FPs.assign(dois=df_FPs["dois"].str.split(",")).explode("dois")
df_FPs
# Out:
#               uid  accession  gds  \
# 1936    200247291  gse247291  NaN
# 2349    200195983  gse195983  NaN
# 2759    200252821  gse252821  NaN
# 4767    200267957  gse267957  NaN
# 6823    200283213  gse283213  NaN
# 16154   200269782  gse269782  NaN
# 46541   200229376  gse229376  NaN
# 51322   200228201  gse228201  NaN
# 62852   200197265  gse197265  NaN
# 74285   200165782  gse165782  NaN
# 82664   200169632  gse169632  NaN
# 82664   200169632  gse169632  NaN
# 113698  200132355  gse132355  NaN
# 113698  200132355  gse132355  NaN
# 115816  200148568  gse148568  NaN
# 118628  200132730  gse132730  NaN
# 118628  200132730  gse132730  NaN
# 118628  200132730  gse132730  NaN
# 118628  200132730  gse132730  NaN
# 124924  200138760  gse138760  NaN
# 129003  200119960  gse119960  NaN
# 130045  200135893  gse135893  NaN
# 139212  200122005  gse122005  NaN
# 145418  200119615  gse119615  NaN
# 153914  200094460   gse94460  NaN
# 156237  200106765  gse106765  NaN
# 164315  200081283   gse81283  NaN
# 164741  200087544   gse87544  NaN
# 168059  200087328   gse87328  NaN
# 185759  200074279   gse74279  NaN
# 186108  200072064   gse72064  NaN
# 186747  200066715   gse66715  NaN
# 187788  200060189   gse60189  NaN
# 188147  200071587   gse71587  NaN
# 191222  200059239   gse59239  NaN
# 197567  200053743   gse53743  NaN
# 197567  200053743   gse53743  NaN
# 207278  200036552   gse36552  NaN
# 207278  200036552   gse36552  NaN
# 214737  200037699   gse37699  NaN
# 216946  200038121   gse38121  NaN
# 217758  200036892   gse36892  NaN
# 221705  200031210   gse31210  NaN
# 221705  200031210   gse31210  NaN
#
#                                                     title  \
# 1936    Adipocyte-specific Steap4 deficiency reduced t...
# 2349                Transcriptome profile of EZR_KO cells
# 2759    Sphingolipid metabolism orchestrates the estab...
# 4767    Transcriptome analyses of Leishmania donovani ...
# 6823    Comparative proteomic landscapes provide insig...
# 16154   Defective N-Glycosylation of IL6 Induces Metas...
# 46541   Defining blood-induced microglia functions in ...
# 51322   Reading and writing of mRNA m6A modification o...
# 62852   Translatome and transcriptome co-profiling rev...
# 74285   Ultrasensitive Ribo-seq reveals translational ...
# 82664   Profiling and functional characterization of m...
# 82664   Profiling and functional characterization of m...
# 113698  Single cell RNA-Seq identifies mechanisms cont...
# 113698  Single cell RNA-Seq identifies mechanisms cont...
# 115816  Grouped ensemble coding of behavioral states b...
# 118628  Design logic of hypothalamus development mappe...
# 118628  Design logic of hypothalamus development mappe...
# 118628  Design logic of hypothalamus development mappe...
# 118628  Design logic of hypothalamus development mappe...
# 124924  High resolution and allelic-specific annotatio...
# 129003  Single cell sequencing of hypothalamus tissues...
# 130045  Single-cell RNA-sequencing reveals profibrotic...
# 139212  Activation of IGFBP7 Drives Resistance to Epid...
# 145418  Translation of upstream open reading frames in...
# 153914                Ribosome profiling of HEK293 cells.
# 156237  Increased expression of Ankyrin repeat domain ...
# 164315  Translational contributions to tissue-specific...
# 164741  Single-cell RNA-seq reveals hypothalamic cell ...
# 168059  eIF1 modulates the recognition of sub-optimal ...
# 185759  Positional proteomics reveals differences in N...
# 186108  Genome-wide profilings of transcriptome and tr...
# 186747  Integrated Transcriptome and Proteome Analyses...
# 187788  IL-8 Confers Acquired Resistance to EGFR Inhib...
# 188147  Gene expression data from HCC4006 and HCC4006E...
# 191222  Acquired resistance to mutant-selective EGFR i...
# 197567  Translational profiling in the unfolded protei...
# 197567  Translational profiling in the unfolded protei...
# 207278  Tracing pluripotency of human early embryos an...
# 207278  Tracing pluripotency of human early embryos an...
# 214737  Aberrant ERK signaling causes resistance to EG...
# 216946  Gene expression profiling of generated Erlotin...
# 217758  A unifying model for mTORC1-mediated regulatio...
# 221705  Gene expression data for pathological stage I-...
# 221705  Gene expression data for pathological stage I-...
#
#                                                   summary                gpl  \
# 1936    Steap4, highly expressed in adipose tissue, is...              24247
# 2349    To analyze gene expression differences between...              24247
# 2759    Bioactive sphingolipids serve as an essential ...              19057
# 4767    This study was performed with the goal of unde...              34491
# 6823    Understanding mammalian preimplantation develo...              21273
# 16154   The biological consequences of various IL-6 gl...              14550
# 46541   This SuperSeries is composed of the SubSeries ...        21103;24247
# 51322   Background: Maternal and zygotic mRNAs play cr...              21273
# 62852   Translational regulation plays a critical role...              24676
# 74285   In mammals, translational control plays critic...        18480;29177
# 82664   Translational regulation plays an important ro...        19057;13112
# 82664   Translational regulation plays an important ro...        19057;13112
# 113698  The hypothalamus is a central regulator of man...              19057
# 113698  The hypothalamus is a central regulator of man...              19057
# 115816  We used a plate-based method (SMART-SCRB) to t...              17021
# 118628  Purpose: We aimed to reconstruct the developme...              21103
# 118628  Purpose: We aimed to reconstruct the developme...              21103
# 118628  Purpose: We aimed to reconstruct the developme...              21103
# 118628  Purpose: We aimed to reconstruct the developme...              21103
# 124924  We used an combination of long-read and short-...        24198;24247
# 129003  A single cell suspension was generated from ID...              21103
# 130045  Pulmonary fibrosis (PF) is a form of chronic l...  18573;24676;20301
# 139212  Previous study has demonstrated that HCC827/ge...                570
# 145418  Upstream open reading frames (uORFs) initiate ...              11154
# 153914  The development of the ribosome profiling (rib...              16791
# 156237  EGFR tyrosine kinase inhibitors (EGFR-TKIs) in...              16686
# 164315  BACKGROUND: The daily gene expression oscillat...              17021
# 164741  We performed single-cell RNA-seq of mouse hypo...              17021
# 168059  Alternative translation initiation mechanisms ...              18573
# 185759  To understand the impact of alternative transl...              18573
# 186108  Memory stabilization after learning requires t...              13112
# 186747  Aging is associated with the decline of protei...              14844
# 187788  Previous study has demonstrated that PC9/gef c...                570
# 188147  We generated erlotinib-resistant HCC4006 cells...                570
# 191222  To compare gene copy number in cell population...               9777
# 197567  The unfolded protein response (UPR) couples ce...              13112
# 197567  The unfolded protein response (UPR) couples ce...              13112
# 207278  Find the casual relationship between gene expr...              11154
# 207278  Find the casual relationship between gene expr...              11154
# 214737  The clinical efficacy of EGFR kinase inhibitor...                571
# 216946  Targeted therapies have provided advantages to...                570
# 217758  Ribsome profiling analysis of mRNA translation...               9250
# 221705  Identification of genes up-regulated in ALK-po...                570
# 221705  Identification of genes up-regulated in ALK-po...                570
#
#            gse                taxon entrytype  \
# 1936    247291         Mus musculus       GSE
# 2349    195983         Mus musculus       GSE
# 2759    252821         Mus musculus       GSE
# 4767    267957  Leishmania donovani       GSE
# 6823    283213         Mus musculus       GSE
# 16154   269782         Homo sapiens       GSE
# 46541   229376         Mus musculus       GSE
# 51322   228201         Mus musculus       GSE
# 62852   197265         Homo sapiens       GSE
# 74285   165782         Mus musculus       GSE
# 82664   169632         Mus musculus       GSE
# 82664   169632         Mus musculus       GSE
# 113698  132355         Mus musculus       GSE
# 113698  132355         Mus musculus       GSE
# 115816  148568         Mus musculus       GSE
# 118628  132730         Mus musculus       GSE
# 118628  132730         Mus musculus       GSE
# 118628  132730         Mus musculus       GSE
# 118628  132730         Mus musculus       GSE
# 124924  138760         Mus musculus       GSE
# 129003  119960         Mus musculus       GSE
# 130045  135893         Homo sapiens       GSE
# 139212  122005         Homo sapiens       GSE
# 145418  119615         Homo sapiens       GSE
# 153914   94460         Homo sapiens       GSE
# 156237  106765         Homo sapiens       GSE
# 164315   81283         Mus musculus       GSE
# 164741   87544         Mus musculus       GSE
# 168059   87328         Homo sapiens       GSE
# 185759   74279         Homo sapiens       GSE
# 186108   72064         Mus musculus       GSE
# 186747   66715    Rattus norvegicus       GSE
# 187788   60189         Homo sapiens       GSE
# 188147   71587         Homo sapiens       GSE
# 191222   59239         Homo sapiens       GSE
# 197567   53743         Mus musculus       GSE
# 197567   53743         Mus musculus       GSE
# 207278   36552         Homo sapiens       GSE
# 207278   36552         Homo sapiens       GSE
# 214737   37699         Homo sapiens       GSE
# 216946   38121         Homo sapiens       GSE
# 217758   36892         Mus musculus       GSE
# 221705   31210         Homo sapiens       GSE
# 221705   31210         Homo sapiens       GSE
#
#                                                   gdstype  ... relations  \
# 1936    Expression profiling by high throughput sequen...  ...        []
# 2349    Expression profiling by high throughput sequen...  ...        []
# 2759    Expression profiling by high throughput sequen...  ...        []
# 4767    Expression profiling by high throughput sequen...  ...        []
# 6823    Expression profiling by high throughput sequen...  ...        []
# 16154                       Expression profiling by array  ...        []
# 46541   Expression profiling by high throughput sequen...  ...        []
# 51322   Expression profiling by high throughput sequen...  ...        []
# 62852   Expression profiling by high throughput sequen...  ...        []
# 74285   Expression profiling by high throughput sequen...  ...        []
# 82664   Expression profiling by high throughput sequen...  ...        []
# 82664   Expression profiling by high throughput sequen...  ...        []
# 113698  Expression profiling by high throughput sequen...  ...        []
# 113698  Expression profiling by high throughput sequen...  ...        []
# 115816  Expression profiling by high throughput sequen...  ...        []
# 118628  Expression profiling by high throughput sequen...  ...        []
# 118628  Expression profiling by high throughput sequen...  ...        []
# 118628  Expression profiling by high throughput sequen...  ...        []
# 118628  Expression profiling by high throughput sequen...  ...        []
# 124924  Expression profiling by high throughput sequen...  ...        []
# 129003  Expression profiling by high throughput sequen...  ...        []
# 130045  Expression profiling by high throughput sequen...  ...        []
# 139212                      Expression profiling by array  ...        []
# 145418  Expression profiling by high throughput sequen...  ...        []
# 153914                                              Other  ...        []
# 156237                      Expression profiling by array  ...        []
# 164315  Expression profiling by high throughput sequen...  ...        []
# 164741  Expression profiling by high throughput sequen...  ...        []
# 168059  Expression profiling by high throughput sequen...  ...        []
# 185759  Expression profiling by high throughput sequen...  ...        []
# 186108  Expression profiling by high throughput sequen...  ...        []
# 186747  Expression profiling by high throughput sequen...  ...        []
# 187788                      Expression profiling by array  ...        []
# 188147                      Expression profiling by array  ...        []
# 191222                Genome variation profiling by array  ...        []
# 197567  Expression profiling by high throughput sequen...  ...        []
# 197567  Expression profiling by high throughput sequen...  ...        []
# 207278  Expression profiling by high throughput sequen...  ...        []
# 207278  Expression profiling by high throughput sequen...  ...        []
# 214737                      Expression profiling by array  ...        []
# 216946                      Expression profiling by array  ...        []
# 217758  Expression profiling by high throughput sequen...  ...        []
# 221705                      Expression profiling by array  ...        []
# 221705                      Expression profiling by array  ...        []
#
#                                              extrelations n_samples  \
# 1936                                                   []       6.0
# 2349                                                   []       8.0
# 2759                                                   []       4.0
# 4767                                                   []       6.0
# 6823                                                   []      24.0
# 16154                                                  []       9.0
# 46541                                                  []      63.0
# 51322                                                  []      24.0
# 62852                                                  []     226.0
# 74285   [{'relationtype': 'SRA', 'targetobject': 'SRP3...     105.0
# 82664   [{'relationtype': 'SRA', 'targetobject': 'SRP3...      50.0
# 82664   [{'relationtype': 'SRA', 'targetobject': 'SRP3...      50.0
# 113698  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      27.0
# 113698  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      27.0
# 115816  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      10.0
# 118628  [{'relationtype': 'SRA', 'targetobject': 'SRP2...       8.0
# 118628  [{'relationtype': 'SRA', 'targetobject': 'SRP2...       8.0
# 118628  [{'relationtype': 'SRA', 'targetobject': 'SRP2...       8.0
# 118628  [{'relationtype': 'SRA', 'targetobject': 'SRP2...       8.0
# 124924  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      21.0
# 129003  [{'relationtype': 'SRA', 'targetobject': 'SRP1...       6.0
# 130045  [{'relationtype': 'SRA', 'targetobject': 'SRP2...      34.0
# 139212                                                 []       6.0
# 145418  [{'relationtype': 'SRA', 'targetobject': 'SRP1...      10.0
# 153914  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       3.0
# 156237                                                 []       6.0
# 164315  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      48.0
# 164741  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      17.0
# 168059  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       6.0
# 185759  [{'relationtype': 'SRA', 'targetobject': 'SRP0...       2.0
# 186108  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      34.0
# 186747  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      24.0
# 187788                                                 []       6.0
# 188147                                                 []       2.0
# 191222                                                 []      14.0
# 197567  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      52.0
# 197567  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      52.0
# 207278  [{'relationtype': 'SRA', 'targetobject': 'SRP0...     124.0
# 207278  [{'relationtype': 'SRA', 'targetobject': 'SRP0...     124.0
# 214737                                                 []       6.0
# 216946                                                 []       3.0
# 217758  [{'relationtype': 'SRA', 'targetobject': 'SRP0...      12.0
# 221705                                                 []     246.0
# 221705                                                 []     246.0
#
#                                                pubmedids projects  \
# 1936                                                  []       []
# 2349                                        ['39937579']       []
# 2759                                                  []       []
# 4767                                                  []       []
# 6823                                                  []       []
# 16154                                       ['39251588']       []
# 46541                                       ['37291385']       []
# 51322                                       ['37024923']       []
# 62852                                       ['36074823']       []
# 74285                                       ['35697785']       []
# 82664                           ['35108058', '36333315']       []
# 82664                           ['35108058', '36333315']       []
# 113698                          ['32868762', '35045288']       []
# 113698                          ['32868762', '35045288']       []
# 115816                                                []       []
# 118628  ['32499648', '32442405', '36209152', '39366958']       []
# 118628  ['32499648', '32442405', '36209152', '39366958']       []
# 118628  ['32499648', '32442405', '36209152', '39366958']       []
# 118628  ['32499648', '32442405', '36209152', '39366958']       []
# 124924                                      ['32461551']       []
# 129003                                                []       []
# 130045                                      ['32832598']       []
# 139212                                      ['30609749']       []
# 145418                                      ['31109297']       []
# 153914                                      ['29170441']       []
# 156237                                      ['30291293']       []
# 164315                                      ['28622766']       []
# 164741                                      ['28355573']       []
# 168059                                      ['28541577']       []
# 185759                                      ['26893308']       []
# 186108                                      ['26430118']       []
# 186747                                      ['27135913']       []
# 187788                                      ['25871388']       []
# 188147                                                []       []
# 191222                                      ['25870145']       []
# 197567                          ['25215492', '27161320']       []
# 197567                          ['25215492', '27161320']       []
# 207278                          ['23934149', '32968278']       []
# 207278                          ['23934149', '32968278']       []
# 214737                                      ['22961667']       []
# 216946                                      ['22751098']       []
# 217758                                      ['22552098']       []
# 221705                          ['22080568', '23028479']       []
# 221705                          ['22080568', '23028479']       []
#
#                                                   ftplink geo2r    bioproject  \
# 1936    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE247nn...    no  PRJNA1037060
# 2349    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE195nn...    no   PRJNA802830
# 2759    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE252nn...    no  PRJNA1062771
# 4767    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE267nn...    no  PRJNA1113700
# 6823    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE283nn...    no  PRJNA1191977
# 16154   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE269nn...   yes  PRJNA1123684
# 46541   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE229nn...    no   PRJNA954299
# 51322   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE228nn...    no   PRJNA947496
# 62852   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE197nn...   yes   PRJNA809587
# 74285   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE165nn...    no   PRJNA697913
# 82664   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nn...    no   PRJNA717246
# 82664   ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nn...    no   PRJNA717246
# 113698  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA547712
# 113698  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA547712
# 115816  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE148nn...    no   PRJNA625041
# 118628  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA548917
# 118628  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA548917
# 118628  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA548917
# 118628  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE132nn...    no   PRJNA548917
# 124924  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE138nn...    no   PRJNA577068
# 129003  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE119nn...    no   PRJNA490830
# 130045  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE135nn...    no   PRJNA560492
# 139212  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE122nn...   yes   PRJNA503109
# 145418  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE119nn...   yes   PRJNA489713
# 153914  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE94nnn...    no   PRJNA369756
# 156237  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE106nn...   yes   PRJNA417935
# 164315  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE81nnn...    no   PRJNA321185
# 164741  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE87nnn...    no   PRJNA345147
# 168059  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE87nnn...   yes   PRJNA344393
# 185759  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE74nnn...    no   PRJNA299254
# 186108  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE72nnn...    no   PRJNA292861
# 186747  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE66nnn...    no   PRJNA277771
# 187788  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE60nnn...   yes   PRJNA257715
# 188147  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE71nnn...   yes   PRJNA291569
# 191222  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE59nnn...   yes   PRJNA254803
# 197567  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE53nnn...    no   PRJNA232779
# 197567  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE53nnn...    no   PRJNA232779
# 207278  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE36nnn...    no   PRJNA153427
# 207278  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE36nnn...    no   PRJNA153427
# 214737  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE37nnn...   yes   PRJNA162711
# 216946  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE38nnn...   yes   PRJNA167352
# 217758  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE36nnn...    no   PRJNA157105
# 221705  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE31nnn...   yes   PRJNA145977
# 221705  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE31nnn...   yes   PRJNA145977
#
#                                    pmcids                           dois
# 1936                                  nan                            nan
# 2349                          PMC11820125            10.7554/elife.98523
# 2759                                  nan                            nan
# 4767                                  nan                            nan
# 6823                                  nan                            nan
# 16154                         PMC11385228     10.1038/s41467-024-51831-7
# 46541                         PMC10307624     10.1038/s41590-023-01522-0
# 51322                         PMC10080794     10.1186/s13059-023-02918-9
# 62852                                None        10.1126/science.abo7923
# 74285                                None     10.1038/s41556-022-00928-6
# 82664               PMC8809684,PMC9636173         10.1126/sciadv.abj3967
# 82664               PMC8809684,PMC9636173     10.1038/s41467-022-34427-x
# 113698              PMC7459115,PMC8918062     10.1038/s41467-020-18231-z
# 113698              PMC7459115,PMC8918062   10.1016/j.celrep.2021.110251
# 115816                                nan                            nan
# 118628  PMC7292733,PMC9547883,PMC11452682      10.1038/s41586-020-2266-0
# 118628  PMC7292733,PMC9547883,PMC11452682     10.1016/j.cell.2020.04.034
# 118628  PMC7292733,PMC9547883,PMC11452682     10.1038/s41467-022-33584-3
# 118628  PMC7292733,PMC9547883,PMC11452682     10.1038/s41467-024-52762-z
# 124924                         PMC7253418     10.1038/s41467-020-16444-w
# 129003                                nan                            nan
# 130045                         PMC7439444         10.1126/sciadv.aba1972
# 139212                         PMC6356910        10.3390/cancers11010036
# 145418                         PMC6528255      10.1186/s12864-019-5775-1
# 153914                         PMC5701008     10.1038/s41467-017-01981-8
# 156237                         PMC6173712     10.1038/s41598-018-33190-8
# 164315                         PMC5473967      10.1186/s13059-017-1222-2
# 164741                         PMC5782816   10.1016/j.celrep.2017.03.004
# 168059                         PMC5570006             10.1093/nar/gkx469
# 185759                         PMC4770386          10.15252/msb.20156662
# 186108                               None        10.1126/science.aac7368
# 186747                         PMC4802414     10.1016/j.cels.2015.08.012
# 187788                         PMC4496364       10.18632/oncotarget.3389
# 188147                                nan                            nan
# 191222                         PMC4605607  10.1158/0008-5472.can-14-3167
# 197567              PMC4163055,PMC4911741     10.1016/j.cell.2014.08.012
# 197567              PMC4163055,PMC4911741           10.1128/mcb.00190-16
# 207278                         PMC7116563              10.1038/nsmb.2660
# 207278                         PMC7116563      10.1038/s41586-020-2759-x
# 214737                         PMC3477553   10.1158/2159-8290.cd-12-0103
# 216946                         PMC3408577                10.1038/ng.2330
# 217758                         PMC3347774            10.1038/nature11083
# 221705                         PMC3446964  10.1158/0008-5472.can-11-1403
# 221705                         PMC3446964   10.1371/journal.pone.0043923
#
# [44 rows x 23 columns]

# %%
# Create mapping of DOI to concatenated GSE accession codes
doi_to_gse = (
    df_FPs.groupby("dois")["accession"]
    .apply(lambda x: ",".join(set(x.astype(str))))  # Ensures unique values
    .to_dict()
)

doi_to_gse.pop("nan")  # Remove any NaN keys
doi_to_gse
# Out:
# {'10.1016/j.cell.2014.08.012': 'gse53743',
#  '10.1016/j.cell.2020.04.034': 'gse132730',
#  '10.1016/j.celrep.2017.03.004': 'gse87544',
#  '10.1016/j.celrep.2021.110251': 'gse132355',
#  '10.1016/j.cels.2015.08.012': 'gse66715',
#  '10.1038/nature11083': 'gse36892',
#  '10.1038/ng.2330': 'gse38121',
#  '10.1038/nsmb.2660': 'gse36552',
#  '10.1038/s41467-017-01981-8': 'gse94460',
#  '10.1038/s41467-020-16444-w': 'gse138760',
#  '10.1038/s41467-020-18231-z': 'gse132355',
#  '10.1038/s41467-022-33584-3': 'gse132730',
#  '10.1038/s41467-022-34427-x': 'gse169632',
#  '10.1038/s41467-024-51831-7': 'gse269782',
#  '10.1038/s41467-024-52762-z': 'gse132730',
#  '10.1038/s41556-022-00928-6': 'gse165782',
#  '10.1038/s41586-020-2266-0': 'gse132730',
#  '10.1038/s41586-020-2759-x': 'gse36552',
#  '10.1038/s41590-023-01522-0': 'gse229376',
#  '10.1038/s41598-018-33190-8': 'gse106765',
#  '10.1093/nar/gkx469': 'gse87328',
#  '10.1126/sciadv.aba1972': 'gse135893',
#  '10.1126/sciadv.abj3967': 'gse169632',
#  '10.1126/science.aac7368': 'gse72064',
#  '10.1126/science.abo7923': 'gse197265',
#  '10.1128/mcb.00190-16': 'gse53743',
#  '10.1158/0008-5472.can-11-1403': 'gse31210',
#  '10.1158/0008-5472.can-14-3167': 'gse59239',
#  '10.1158/2159-8290.cd-12-0103': 'gse37699',
#  '10.1186/s12864-019-5775-1': 'gse119615',
#  '10.1186/s13059-017-1222-2': 'gse81283',
#  '10.1186/s13059-023-02918-9': 'gse228201',
#  '10.1371/journal.pone.0043923': 'gse31210',
#  '10.15252/msb.20156662': 'gse74279',
#  '10.18632/oncotarget.3389': 'gse60189',
#  '10.3390/cancers11010036': 'gse122005',
#  '10.7554/elife.98523': 'gse195983'}

# %%
for i,row in df1.iterrows():
    doi = row["doi"].lower()
    if doi == "nan" or doi is None:
        continue
    elif doi in doi_to_gse.keys():
        print(f"DOI: {doi} -- GSE: {doi_to_gse[doi]}")
        # update value at dataset_uid by appending GSE
        dataset_uid = df1.loc[i, "dataset_uid"] + "," + doi_to_gse[doi]
        df1.at[i, "dataset_uid"] = dataset_uid
    else:
        continue
# Out:
# DOI: 10.1038/s41467-024-51831-7 -- GSE: gse269782

# %%
df1[["publication","dataset_uid","doi"]]
# Out:
#                                          publication  \
# 0    https://dx.doi.org/10.1001/JAMANEUROL.2024.4763
# 1          https://dx.doi.org/10.1002/CBIC.202400831
# 2          https://dx.doi.org/10.1002/CBIC.202400882
# 3          https://dx.doi.org/10.1002/PRCA.202300107
# 4          https://dx.doi.org/10.1002/anie.202420149
# ..                                               ...
# 234     https://www.ncbi.nlm.nih.gov/pubmed/39884247
# 235     https://www.ncbi.nlm.nih.gov/pubmed/39900909
# 236     https://www.ncbi.nlm.nih.gov/pubmed/39910101
# 237     https://www.ncbi.nlm.nih.gov/pubmed/39910614
# 238     https://www.ncbi.nlm.nih.gov/pubmed/39912552
#
#                        dataset_uid                           doi
# 0                        PXD056570  10.1001/jamaneurol.2024.4763
# 1                        PXD055649        10.1002/cbic.202400831
# 2                        PXD060372        10.1002/cbic.202400882
# 3                        PXD028078        10.1002/prca.202300107
# 4    PXD056865,PXD057925,PXD058045        10.1002/anie.202420149
# ..                             ...                           ...
# 234                      PXD054970                           nan
# 235                      PXD058955                           nan
# 236                      PXD060051                           nan
# 237                      PXD060193                           nan
# 238                      PXD051312                           nan
#
# [239 rows x 3 columns]

# %%
df1.to_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")

# %%
# df1["doi"]

# %%
# # Function to find matching GSE codes for a given publication
# def find_matching_gse(publication, doi_dict):
#     matched_gse_codes = set()  # Use a set to avoid duplicates
#     
#     if pd.notna(publication):  # Ensure publication is not NaN
#         pub_lower = publication.lower().strip()  # Normalize publication case
#         
#         for doi_group, gse_codes in doi_dict.items():
#             # Split the multiple DOIs stored in the key
#             individual_dois = [doi.strip().lower() for doi in doi_group.split(",")]
#             
#             # Check if any of the individual DOIs is a substring of the publication
#             if any(doi in pub_lower for doi in individual_dois):
#                 matched_gse_codes.update(gse_codes.split(","))  # Add each GSE ID separately
# 
#     return ",".join(sorted(matched_gse_codes)) if matched_gse_codes else None  # Ensure consistent ordering
# 
# # Apply the function to find matches and update dataset_uid
# df1["new_dataset_uids"] = df1["doi"].apply(lambda pub: find_matching_gse(pub, doi_to_gse))
# 
# # Concatenate new dataset IDs with existing ones (if any)
# df1["dataset_uid"] = df1.apply(
#     lambda row: f"{row['dataset_uid']},{row['new_dataset_uids']}" if pd.notna(row["new_dataset_uids"]) else row["dataset_uid"], axis=1
# )
# 
# # Remove unnecessary column and strip redundant commas
# df1.drop(columns=["new_dataset_uids"], inplace=True)
# df1["dataset_uid"] = df1["dataset_uid"].str.strip(",")

# %%
# df1[["publication","dataset_uid"]]

# %%
# df1.to_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")

# %%
# we have dataframe df1 with all our scraped Ground Truth data (raw_html, publication, dataset_uid, ...)
# we have dataframe df_FPs with all our (supposedly) false positives on Ground Truth (accession, pmcid, doi)
# with the previous steps in the GEO dataset creation notebook, we now have ground truth for these "False Positives"
# look for matches, then update ground truth with the new data

# for i, row in df1.iterrows():
#     publication = row["publication"].lower()
#     for fp in df_FPs["doi"]:
#         fp = fp.lower()
#         if fp is not None and (fp in publication or fp == publication):
#             print(f"Publication: {publication}")
#             print(f"DOI of ex-false positive: {fp}")
#             vals = df_FPs[df_FPs["doi"] == fp]
#             print(f"ex-False Positive id: {vals['accession'].values}")
#             addenda = ',' + df_FPs[df_FPs["doi"] == fp]["accession"].values
#             #df1.at[i, "dataset_uid"] += addenda
#             #print(df1.at[i, "dataset_uid"])
#             #print(addenda)
#         elif fp is None:
#             print(None)
