# %%
# import from the files in this directory
from dotenv import load_dotenv
from classifier import *
from data_fetcher import *
from parser import *
from orchestrator import *
from logger_setup import *
import os
import json
import pandas as pd
import numpy as np
import re
import time

# %%
config_path = 'config_experiment.json'  # Config with input file details
load_dotenv()
orchestrator = Orchestrator(config_path)
orchestrator.setup_data_fetcher()
# Out:
# orchestrator.py - line 20 - INFO - Data_Gatherer Orchestrator initialized. Extraction step Model: gemini-2.0-flash-exp
# orchestrator.py - line 45 - INFO - Data fetcher setup completed.
# <selenium.webdriver.firefox.webdriver.WebDriver (session="1d1b7a4b-8c75-42f6-83bc-0a7d9b851ac9")>

# %%
df = pd.read_csv('exp_input/raw_data.csv')

# %%
urls = df['publication'].tolist()
print(f"Number of URLs: {len(urls)}")
# Out:
# Number of URLs: 221

# %%
results = {}
for i,url in enumerate(urls):
    time.sleep(15)
    orchestrator.current_url = url
    orchestrator.logger.info(f"Processing URL {i+1}: {orchestrator.current_url}")
    orchestrator.publisher = orchestrator.data_fetcher.url_to_publisher_domain(url)
    #orchestrator.logger.info("Using XMLParser to parse data.")
    orchestrator.parser = XMLParser(orchestrator.XML_config, orchestrator.logger)
    raw_data = df.loc[df['publication'] == url, 'raw_html'].iloc[0]
    parsed_data = orchestrator.parser.parse_data(raw_data, orchestrator.publisher, orchestrator.current_url, raw_data_format="full_HTML")
    parsed_data['source_url'] = url
    orchestrator.logger.info(f"Parsed data extraction completed. Elements collected: {len(parsed_data)}")
    results[url] = parsed_data
# Out:
# 2172060690.py - line 5 - INFO - Processing URL 1: https://dx.doi.org/10.1002/1878-0261.13654
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 192964 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 124070 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-13838f88fd4e37bbb5447e3d4d65fad9944e1ca4e414c8f9e2b8775098bfd967
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD048538",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "GSE15460",
#     "repository_reference": "www.ncbi.nlm.nih.gov"
#   },
#   {
#     "dataset_id": "GSE66229",
#     "repository_reference": "www.ncbi.nlm.nih.gov"
#   },
#   {
#     "dataset_id": "GSE26899",
#     "repository_reference": "www.ncbi.nlm.nih.gov"
#   },
#   {
#     "dataset_id": "GSE15459",
#     "repository_reference": "www.ncbi.nlm.nih.gov"
#   },
#   {
#     "dataset_id": "PXD008840",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "n/a",
#     "repository_reference": "depmap.org"
#   },
#   {
#     "dataset_id": "n/a",
#     "repository_reference": "zenodo.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD048538', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD048538', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GSE15460', 'repository_reference': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GSE15460', 'data_repository': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GSE66229', 'repository_reference': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GSE66229', 'data_repository': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GSE26899', 'repository_reference': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GSE26899', 'data_repository': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GSE15459', 'repository_reference': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GSE15459', 'data_repository': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD008840', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD008840', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'n/a', 'repository_reference': 'depmap.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'n/a', 'data_repository': 'depmap.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'n/a', 'repository_reference': 'zenodo.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'n/a', 'data_repository': 'zenodo.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD048538', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'GSE15460', 'data_repository': 'www.ncbi.nlm.nih.gov'}, {'dataset_identifier': 'GSE66229', 'data_repository': 'www.ncbi.nlm.nih.gov'}, {'dataset_identifier': 'GSE26899', 'data_repository': 'www.ncbi.nlm.nih.gov'}, {'dataset_identifier': 'GSE15459', 'data_repository': 'www.ncbi.nlm.nih.gov'}, {'dataset_identifier': 'PXD008840', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'n/a', 'data_repository': 'depmap.org'}, {'dataset_identifier': 'n/a', 'data_repository': 'zenodo.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 8 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD048538
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: www.ncbi.nlm.nih.gov
# parser.py - line 1171 - INFO - Processing dataset 3 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 3 with repo: www.ncbi.nlm.nih.gov
# parser.py - line 1171 - INFO - Processing dataset 4 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 4 with repo: www.ncbi.nlm.nih.gov
# parser.py - line 1171 - INFO - Processing dataset 5 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 5 with repo: www.ncbi.nlm.nih.gov
# parser.py - line 1171 - INFO - Processing dataset 6 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 6 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD008840
# parser.py - line 1171 - INFO - Processing dataset 7 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1178 - INFO - Skipping dataset 7: no dataset_identifier for item
# parser.py - line 1171 - INFO - Processing dataset 8 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1178 - INFO - Skipping dataset 8: no dataset_identifier for item
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 8, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 8
# 2172060690.py - line 5 - INFO - Processing URL 2: https://dx.doi.org/10.1002/ADHM.202404465
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 169876 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 105364 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-c5ee88e2bbc89ca3e20cdd1851e77ab43c7b0c8e04f3d0e835e7985d443a771b
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD052728",
#     "repository_reference": "ProteomeXchange Consortium via the PRIDE partner repository"
#   },
#   {
#     "dataset_id": "https://github.com/Evolved-Bio/invitroMuscleDystrophyAnchoredCellSheet",
#     "repository_reference": "n/a"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD052728', 'repository_reference': 'ProteomeXchange Consortium via the PRIDE partner repository'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD052728', 'data_repository': 'ProteomeXchange Consortium via the PRIDE partner repository'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'https://github.com/Evolved-Bio/invitroMuscleDystrophyAnchoredCellSheet', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'https://github.com/Evolved-Bio/invitroMuscleDystrophyAnchoredCellSheet', 'data_repository': 'n/a'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD052728', 'data_repository': 'ProteomeXchange Consortium via the PRIDE partner repository'}, {'dataset_identifier': 'https://github.com/Evolved-Bio/invitroMuscleDystrophyAnchoredCellSheet', 'data_repository': 'n/a'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: ProteomeXchange Consortium via the PRIDE partner repository
# parser.py - line 1157 - ERROR - Error extracting domain from URL: ProteomeXchange Consortium via the PRIDE partner repository
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: Unknown_Publisher
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 3: https://dx.doi.org/10.1002/CBIC.202400831
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 160758 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 95352 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-d5245c439ce7dc548c1f8230264adcbe52bb8df69f9994ab06cbd41725c72472
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD055649",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD055649', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD055649', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD055649', 'data_repository': 'proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD055649
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 4: https://dx.doi.org/10.1002/PRCA.202300107
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 206303 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 141076 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-2c841132d36de27f441703beb41eb4a240c61018df5856266abc79b1cdc23d7c
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD028078",
#     "repository_reference": "http://www.ebi.ac.uk/pride/archive/"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD028078', 'repository_reference': 'http://www.ebi.ac.uk/pride/archive/'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD028078', 'data_repository': 'http://www.ebi.ac.uk/pride/archive/'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD028078', 'data_repository': 'http://www.ebi.ac.uk/pride/archive/'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: http://www.ebi.ac.uk/pride/archive/
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD028078
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 5: https://dx.doi.org/10.1002/anie.202420149
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 136419 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 70650 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-5c3ecd8e1677e4e38cbc3debebd215964009b5a73800ce663821fb6362297ca2
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD056865",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "PXD056865",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "PXD057925",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "PXD057925",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "PXD058045",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "PXD058045",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "8BI5",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "8BI6",
#     "repository_reference": "n/a"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD056865', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD056865', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD056865', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD056865', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD057925', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD057925', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD057925', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD057925', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD058045', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD058045', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD058045', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD058045', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': '8BI5', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': '8BI5', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': '8BI6', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': '8BI6', 'data_repository': 'n/a'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD056865', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD056865', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'PXD057925', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD057925', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'PXD058045', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD058045', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': '8BI5', 'data_repository': 'n/a'}, {'dataset_identifier': '8BI6', 'data_repository': 'n/a'}]
# parser.py - line 1167 - INFO - Fetching metadata for 8 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD056865
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD056865
# parser.py - line 1171 - INFO - Processing dataset 3 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 3 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD057925
# parser.py - line 1171 - INFO - Processing dataset 4 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 4 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD057925
# parser.py - line 1171 - INFO - Processing dataset 5 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 5 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD058045
# parser.py - line 1171 - INFO - Processing dataset 6 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 6 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD058045
# parser.py - line 1171 - INFO - Processing dataset 7 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 7 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 8 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 8 with repo: Unknown_Publisher
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 8, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 8
# 2172060690.py - line 5 - INFO - Processing URL 6: https://dx.doi.org/10.1002/cac2.12663
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 100946 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 38668 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-2d6ad6856d2417ac5dbd5ce15680c6c87d60bb8181e304778daf95323a2b043a
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD054301",
#     "repository_reference": "http://proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD054301', 'repository_reference': 'http://proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD054301', 'data_repository': 'http://proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD054301', 'data_repository': 'http://proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: http://proteomecentral.proteomexchange.org
# parser.py - line 1157 - ERROR - Error extracting domain from URL: http://proteomecentral.proteomexchange.org
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: Unknown_Publisher
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 7: https://dx.doi.org/10.1002/ctm2.70030
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 177544 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 109638 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-87036fcfc7512959c85670a573dc41bf0f7a42501b385023f6c19546ccef73e8
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD046679",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "https://doi.org/10.5061/dryad.h70rxwdmj",
#     "repository_reference": "doi.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD046679', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD046679', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'https://doi.org/10.5061/dryad.h70rxwdmj', 'repository_reference': 'doi.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'https://doi.org/10.5061/dryad.h70rxwdmj', 'data_repository': 'doi.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD046679', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'https://doi.org/10.5061/dryad.h70rxwdmj', 'data_repository': 'doi.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD046679
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: doi.org
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 8: https://dx.doi.org/10.1002/jev2.70026
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 183155 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 120706 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-f08a60ba75dde868b70761b23098c02ed15d329789d654a1316d8938ae7e5797
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD052799",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD052799', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD052799', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD052799', 'data_repository': 'proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD052799
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 9: https://dx.doi.org/10.1002/pmic.202400251
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 129509 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 69544 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-ce856e3778b9136d3e181975d653849abff6c3c4e922840355c12923ae659732
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD053678",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "10.17632/yyr73pf4pt.3",
#     "repository_reference": "n/a"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD053678', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD053678', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': '10.17632/yyr73pf4pt.3', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': '10.17632/yyr73pf4pt.3', 'data_repository': 'n/a'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD053678', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': '10.17632/yyr73pf4pt.3', 'data_repository': 'n/a'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD053678
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: Unknown_Publisher
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 10: https://dx.doi.org/10.1007/s00253-023-12559-4
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 269302 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 101826 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-49f0c14adc52a13e048c6d0694d3a04ad03a83b589f012886cb7205225d1aaa5
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD022824",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "PXD012982",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD022824', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD022824', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD012982', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD012982', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD022824', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD012982', 'data_repository': 'proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD022824
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD012982
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 11: https://dx.doi.org/10.1007/s00395-024-01085-7
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 280853 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 118666 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-88d1387c75a1f45a1ee8dd9c47a8269bf79016251d8773f816bdf1e59cf14044
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD050994",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   },
#   {
#     "dataset_id": "PXD050994",
#     "repository_reference": "www.proteomexchange.org"
#   },
#   {
#     "dataset_id": "n/a",
#     "repository_reference": "https://github.com/bshashikadze/pepquantify"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD050994', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD050994', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD050994', 'repository_reference': 'www.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD050994', 'data_repository': 'www.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'n/a', 'repository_reference': 'https://github.com/bshashikadze/pepquantify'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'n/a', 'data_repository': 'https://github.com/bshashikadze/pepquantify'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD050994', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD050994', 'data_repository': 'www.proteomexchange.org'}, {'dataset_identifier': 'n/a', 'data_repository': 'https://github.com/bshashikadze/pepquantify'}]
# parser.py - line 1167 - INFO - Fetching metadata for 3 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD050994
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: www.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for www.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD050994
# parser.py - line 1171 - INFO - Processing dataset 3 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1178 - INFO - Skipping dataset 3: no dataset_identifier for item
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 3, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 3
# 2172060690.py - line 5 - INFO - Processing URL 12: https://dx.doi.org/10.1016/J.ACA.2024.343550
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 211376 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 20538 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-2a5b1939be682fa1f63feb08e77c9aed6f7448f74dd54cfe218e80b21c810482
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD048982",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD048982', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD048982', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD048982', 'data_repository': 'proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD048982
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 13: https://dx.doi.org/10.1016/J.BBADVA.2025.100140
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 226657 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 71296 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-5c3d98f673d900d8c392251bc1d1a5b8aff101966b2578164c88a3c0e9d4cdea
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD056996",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "TCGA",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "GTEx",
#     "repository_reference": "n/a"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD056996', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD056996', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'TCGA', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'TCGA', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GTEx', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GTEx', 'data_repository': 'n/a'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD056996', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'TCGA', 'data_repository': 'n/a'}, {'dataset_identifier': 'GTEx', 'data_repository': 'n/a'}]
# parser.py - line 1167 - INFO - Fetching metadata for 3 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD056996
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 3 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# ...
#     "repository_reference": "www.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD054648', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD054648', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD054648', 'repository_reference': 'www.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD054648', 'data_repository': 'www.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD054648', 'data_repository': 'proteomecentral.proteomexchange.org'}, {'dataset_identifier': 'PXD054648', 'data_repository': 'www.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD054648
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: www.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for www.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD054648
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 219: https://dx.doi.org/10.7554/ELIFE.86931.2
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 297281 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 79911 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-6b0def090b2419d93e93496b5206306466330a12877c33d249aa3fdff4c02222
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD037489",
#     "repository_reference": "proteomecentral.proteomexchange.org"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD037489', 'repository_reference': 'proteomecentral.proteomexchange.org'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD037489', 'data_repository': 'proteomecentral.proteomexchange.org'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD037489', 'data_repository': 'proteomecentral.proteomexchange.org'}]
# parser.py - line 1167 - INFO - Fetching metadata for 1 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: proteomecentral.proteomexchange.org
# parser.py - line 1203 - INFO - Found config options for proteomecentral.proteomexchange.org
# parser.py - line 1207 - INFO - Dataset page: https://proteomecentral.proteomexchange.org/cgi/GetDataset?ID=PXD037489
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 1, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 1
# 2172060690.py - line 5 - INFO - Processing URL 220: https://dx.doi.org/10.7554/ELIFE.98523.2
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 285539 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 74019 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-69af3ba38c0bb78c9c9d5463afcd9165cd35000ed1288a507b78db107607df16
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "GSE195983",
#     "repository_reference": "www.ncbi.nlm.nih.gov"
#   },
#   {
#     "dataset_id": "PXD045157",
#     "repository_reference": "www.ebi.ac.uk"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'GSE195983', 'repository_reference': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'GSE195983', 'data_repository': 'www.ncbi.nlm.nih.gov'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD045157', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD045157', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'GSE195983', 'data_repository': 'www.ncbi.nlm.nih.gov'}, {'dataset_identifier': 'PXD045157', 'data_repository': 'www.ebi.ac.uk'}]
# parser.py - line 1167 - INFO - Fetching metadata for 2 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: www.ncbi.nlm.nih.gov
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD045157
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 2, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 2
# 2172060690.py - line 5 - INFO - Processing URL 221: https://dx.doi.org/10.7554/elife.78385
# data_fetcher.py - line 30 - INFO - Publisher: doi
# parser.py - line 25 - INFO - Parser initialized.
# parser.py - line 153 - INFO - Function call: parse_data(api_data(<class 'str'>), publisher, current_url_address, additional_data, full_HTML)
# parser.py - line 246 - INFO - Extracting links from full HTML content.
# parser.py - line 292 - INFO - Function_call: normalize_full_DOM(api_data). Length of raw api data: 347355 tokens
# parser.py - line 690 - INFO - Loading prompt: GEMINI_from_full_input_Examples_4
# parser.py - line 705 - INFO - Prompt messages total length: 206996 tokens
# parser.py - line 711 - INFO - Prompt ID: gemini-2.0-flash-exp-0-4461d66eb4888f768528ba0813efb7ee74284540eb377f8dea48958f06dca1b9
# parser.py - line 730 - INFO - Requesting datasets from content using model: gemini-2.0-flash-exp, temperature: 0, messages: messages
# parser.py - line 829 - INFO - Found 1 candidates in the response.
# parser.py - line 831 - INFO - Gemini response text: [
#   {
#     "dataset_id": "PXD032017",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "EMD-14502",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "EMD-14503",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "EMD-14505",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "EMD-14506",
#     "repository_reference": "n/a"
#   },
#   {
#     "dataset_id": "PXD032016",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "PXD032024",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "PXD032034",
#     "repository_reference": "www.ebi.ac.uk"
#   },
#   {
#     "dataset_id": "PXD018034",
#     "repository_reference": "www.ebi.ac.uk"
#   }
# ]
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD032017', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD032017', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'EMD-14502', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'EMD-14502', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'EMD-14503', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'EMD-14503', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'EMD-14505', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'EMD-14505', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'EMD-14506', 'repository_reference': 'n/a'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'EMD-14506', 'data_repository': 'n/a'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD032016', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD032016', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD032024', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD032024', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD032034', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD032034', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 846 - INFO - Processing dataset: {'dataset_id': 'PXD018034', 'repository_reference': 'www.ebi.ac.uk'}
# parser.py - line 861 - INFO - Dataset is a dictionary
# parser.py - line 884 - INFO - Extracted dataset: {'dataset_identifier': 'PXD018034', 'data_repository': 'www.ebi.ac.uk'}
# parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'PXD032017', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'EMD-14502', 'data_repository': 'n/a'}, {'dataset_identifier': 'EMD-14503', 'data_repository': 'n/a'}, {'dataset_identifier': 'EMD-14505', 'data_repository': 'n/a'}, {'dataset_identifier': 'EMD-14506', 'data_repository': 'n/a'}, {'dataset_identifier': 'PXD032016', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'PXD032024', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'PXD032034', 'data_repository': 'www.ebi.ac.uk'}, {'dataset_identifier': 'PXD018034', 'data_repository': 'www.ebi.ac.uk'}]
# parser.py - line 1167 - INFO - Fetching metadata for 9 datasets
# parser.py - line 1171 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 1 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD032017
# parser.py - line 1171 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 2 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 3 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 3 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 4 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 4 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 5 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1148 - INFO - Extracting repo domain from URL: n/a
# parser.py - line 1157 - ERROR - Error extracting domain from URL: n/a
# parser.py - line 1193 - INFO - Processing dataset 5 with repo: Unknown_Publisher
# parser.py - line 1171 - INFO - Processing dataset 6 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 6 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD032016
# parser.py - line 1171 - INFO - Processing dataset 7 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 7 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD032024
# parser.py - line 1171 - INFO - Processing dataset 8 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 8 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD032034
# parser.py - line 1171 - INFO - Processing dataset 9 with keys: dict_keys(['dataset_identifier', 'data_repository'])
# parser.py - line 1193 - INFO - Processing dataset 9 with repo: www.ebi.ac.uk
# parser.py - line 1203 - INFO - Found config options for www.ebi.ac.uk
# parser.py - line 1207 - INFO - Dataset page: https://www.ebi.ac.uk/pride/archive/projects/PXD018034
# parser.py - line 263 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 9, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage'], dtype='object')
# 2172060690.py - line 12 - INFO - Parsed data extraction completed. Elements collected: 9

# %%
combined_df = pd.DataFrame()
for url, data in results.items():
    combined_df = pd.concat([combined_df, data], ignore_index=True)
    
combined_df.to_csv(orchestrator.config['full_output_file'], index=False)

# %%
combined_df
# Out:
#     dataset_identifier                      data_repository  \
# 0            PXD048538  proteomecentral.proteomexchange.org
# 1             GSE15460                 www.ncbi.nlm.nih.gov
# 2             GSE66229                 www.ncbi.nlm.nih.gov
# 3             GSE26899                 www.ncbi.nlm.nih.gov
# 4             GSE15459                 www.ncbi.nlm.nih.gov
# ..                 ...                                  ...
# 723          EMD-14506                                  n/a
# 724          PXD032016                        www.ebi.ac.uk
# 725          PXD032024                        www.ebi.ac.uk
# 726          PXD032034                        www.ebi.ac.uk
# 727          PXD018034                        www.ebi.ac.uk
#
#                                        dataset_webpage  \
# 0    https://proteomecentral.proteomexchange.org/cg...
# 1                                                   na
# 2                                                   na
# 3                                                   na
# 4                                                   na
# ..                                                 ...
# 723                                                 na
# 724  https://www.ebi.ac.uk/pride/archive/projects/P...
# 725  https://www.ebi.ac.uk/pride/archive/projects/P...
# 726  https://www.ebi.ac.uk/pride/archive/projects/P...
# 727  https://www.ebi.ac.uk/pride/archive/projects/P...
#
#                                      source_url
# 0    https://dx.doi.org/10.1002/1878-0261.13654
# 1    https://dx.doi.org/10.1002/1878-0261.13654
# 2    https://dx.doi.org/10.1002/1878-0261.13654
# 3    https://dx.doi.org/10.1002/1878-0261.13654
# 4    https://dx.doi.org/10.1002/1878-0261.13654
# ..                                          ...
# 723      https://dx.doi.org/10.7554/elife.78385
# 724      https://dx.doi.org/10.7554/elife.78385
# 725      https://dx.doi.org/10.7554/elife.78385
# 726      https://dx.doi.org/10.7554/elife.78385
# 727      https://dx.doi.org/10.7554/elife.78385
#
# [728 rows x 4 columns]

# %%
recall_list = []
def calculate_performance_metrics(orchestrator, ground_truth_df: pd.DataFrame, eval_df: pd.DataFrame) -> dict:
    """
    Calculate performance metrics (precision, recall, F1-score) for dataset extraction,
    considering exact, partial, and alias matches. Includes verbose debugging output.
    """
    # Initialize counters for total scores
    total_precision = 0
    total_recall = 0
    
    num_sources = len(eval_df['source_url'].unique())

    orchestrator.logger.info(f"Number of unique source pages: {num_sources}")

    # Iterate through each unique source page
    for source_page in eval_df['source_url'].unique():
        orchestrator.logger.info(f"\nStarting performance evaluation for source page: {source_page}")

        # Extract ground truth datasets for this source page
        gt_data = ground_truth_df[ground_truth_df['publication'] == source_page]
        gt_datasets = set(gt_data['dataset_uid'].dropna().str.lower())
        gt_repositories = set(gt_data['repo_name'].dropna().str.lower())

        orchestrator.logger.info(f"Ground truth datasets: {gt_datasets}")
        # orchestrator.logger.info(f"Ground truth repositories: {gt_repositories}")

        # Extract evaluation datasets for this source page
        eval_data = eval_df[eval_df['source_url'] == source_page]
        eval_datasets = set(eval_data['dataset_identifier'].dropna().str.lower())
        # eval_webpages = set(eval_data['dataset_webpage'].dropna().str.lower())
        # eval_repositories = set(eval_data['data_repository'].dropna().str.lower())

        orchestrator.logger.info(f"Evaluation datasets: {eval_datasets}")
        # orchestrator.logger.info(f"Evaluation webpages: {eval_webpages}")
        # orchestrator.logger.info(f"Evaluation repositories: {eval_repositories}")

        # Handle cases where both ground truth and evaluation are empty
        if not gt_datasets and not eval_datasets:
            orchestrator.logger.info("No datasets in both ground truth and evaluation. Perfect precision and recall.")
            total_precision += 1
            total_recall += 1
            continue

        # Initialize match counters
        exact_matches = 0
        partial_matches = 0
        false_positives = 0
        false_negatives = 0

        # Track matches to avoid double counting
        matched_gt = set()
        matched_eval = set()

        # Check for exact matches first
        for eval_id in eval_datasets:
            if eval_id in gt_datasets:
                orchestrator.logger.info(f"Exact match found: {eval_id}")
                exact_matches += 1
                matched_gt.add(eval_id)
                matched_eval.add(eval_id)

        # Check for partial matches and aliases
        for eval_id in eval_datasets - matched_eval:
            for gt_id in gt_datasets - matched_gt:
                if eval_id in gt_id or gt_id in eval_id:  # Partial match or alias
                    orchestrator.logger.info(f"Partial or alias match found: eval_id={eval_id}, gt_id={gt_id}")
                    partial_matches += 1
                    matched_gt.add(gt_id)
                    matched_eval.add(eval_id)
                    break

        # Calculate False Positives (remaining unmatched eval datasets)
        FP = eval_datasets - matched_eval

        # Remove aliases from False Positives
        for eval_id in list(FP):
            for matched_id in matched_gt:
                if eval_id in matched_id or matched_id in eval_id:  # Alias detected
                    orchestrator.logger.info(f"Removing alias from false positives: eval_id={eval_id}, matched_id={matched_id}")
                    FP.discard(eval_id)
                    break

        false_positives = len(FP)
        orchestrator.logger.info(f"False positives: {FP}")

        # Calculate False Negatives (remaining unmatched ground truth datasets)
        FN = gt_datasets - matched_gt
        false_negatives = len(FN)
        orchestrator.logger.info(f"False negatives: {FN}")

        # Calculate precision and recall for this source page
        true_positives = exact_matches + partial_matches
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

        orchestrator.logger.info(f"Precision for {source_page}: {precision}")
        orchestrator.logger.info(f"Recall for {source_page}: {recall}")
        
        if recall == 0:
            recall_list.append(source_page)

        # Accumulate totals
        total_precision += precision
        total_recall += recall

    # Calculate overall metrics
    average_precision = total_precision / num_sources if num_sources > 0 else 0
    average_recall = total_recall / num_sources if num_sources > 0 else 0
    f1_score = 2 * (average_precision * average_recall) / (average_precision + average_recall) if (average_precision + average_recall) > 0 else 0

    return {
        "average_precision": average_precision,
        "average_recall": average_recall,
        "f1_score": f1_score
    }

# %%
calculate_performance_metrics(orchestrator, df, combined_df)
# Out:
# 4253583190.py - line 13 - INFO - Number of unique source pages: 219
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/1878-0261.13654
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd048538'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse15459', 'n/a', 'pxd048538', 'gse26899', 'gse66229', 'pxd008840', 'gse15460'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd048538
# 4253583190.py - line 84 - INFO - False positives: {'gse15459', 'n/a', 'gse26899', 'gse66229', 'pxd008840', 'gse15460'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/1878-0261.13654: 0.14285714285714285
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/1878-0261.13654: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/ADHM.202404465
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd052728'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'https://github.com/evolved-bio/invitromuscledystrophyanchoredcellsheet', 'pxd052728'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd052728
# 4253583190.py - line 84 - INFO - False positives: {'https://github.com/evolved-bio/invitromuscledystrophyanchoredcellsheet'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/ADHM.202404465: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/ADHM.202404465: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/CBIC.202400831
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055649'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd055649'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd055649
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/CBIC.202400831: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/CBIC.202400831: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/PRCA.202300107
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd028078'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd028078'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd028078
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/PRCA.202300107: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/PRCA.202300107: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/anie.202420149
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056865,pxd057925,pxd058045'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058045', '8bi6', '8bi5', 'pxd057925', 'pxd056865'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd058045, gt_id=pxd056865,pxd057925,pxd058045
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd057925, matched_id=pxd056865,pxd057925,pxd058045
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd056865, matched_id=pxd056865,pxd057925,pxd058045
# 4253583190.py - line 84 - INFO - False positives: {'8bi6', '8bi5'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/anie.202420149: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/anie.202420149: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/cac2.12663
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054301'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd054301'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054301
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/cac2.12663: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/cac2.12663: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/ctm2.70030
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd046679'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd046679', 'https://doi.org/10.5061/dryad.h70rxwdmj'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd046679
# 4253583190.py - line 84 - INFO - False positives: {'https://doi.org/10.5061/dryad.h70rxwdmj'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/ctm2.70030: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/ctm2.70030: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/jev2.70026
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd052799'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd052799'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd052799
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/jev2.70026: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/jev2.70026: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1002/pmic.202400251
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd053678'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd053678', '10.17632/yyr73pf4pt.3'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd053678
# 4253583190.py - line 84 - INFO - False positives: {'10.17632/yyr73pf4pt.3'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1002/pmic.202400251: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1002/pmic.202400251: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1007/s00253-023-12559-4
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd012982'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd012982', 'pxd022824'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd012982
# 4253583190.py - line 84 - INFO - False positives: {'pxd022824'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1007/s00253-023-12559-4: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1007/s00253-023-12559-4: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1007/s00395-024-01085-7
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd050994'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', 'pxd050994'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd050994
# 4253583190.py - line 84 - INFO - False positives: {'n/a'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1007/s00395-024-01085-7: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1007/s00395-024-01085-7: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.ACA.2024.343550
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd048982'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd048982'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd048982
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.ACA.2024.343550: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.ACA.2024.343550: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.BBADVA.2025.100140
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056996'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'tcga', 'pxd056996', 'gtex'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056996
# 4253583190.py - line 84 - INFO - False positives: {'tcga', 'gtex'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.BBADVA.2025.100140: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.BBADVA.2025.100140: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.CELREP.2024.115151
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058646'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse84881', 'gse140135', 'pxd058648', 'pxd058646', 'gse148625'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058646
# 4253583190.py - line 84 - INFO - False positives: {'pxd058648', 'gse140135', 'gse148625', 'gse84881'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.CELREP.2024.115151: 0.2
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.CELREP.2024.115151: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.CELREP.2024.115224
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd034411'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd034411', 'mtbls11979'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd034411
# 4253583190.py - line 84 - INFO - False positives: {'mtbls11979'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.CELREP.2024.115224: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.CELREP.2024.115224: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.CMET.2024.12.008
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd051609'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd051609', 'prjna1178314', 'pxd051587'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd051609
# 4253583190.py - line 84 - INFO - False positives: {'prjna1178314', 'pxd051587'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.CMET.2024.12.008: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.CMET.2024.12.008: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.EBIOM.2024.105508
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055932'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd055932'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd055932
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.EBIOM.2024.105508: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.EBIOM.2024.105508: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.HELIYON.2025.E41801
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054147'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse273052', 'pxd054147'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054147
# 4253583190.py - line 84 - INFO - False positives: {'gse273052'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.HELIYON.2025.E41801: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.HELIYON.2025.E41801: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.IJBIOMAC.2025.140432
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd052301'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd052301'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd052301
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.IJBIOMAC.2025.140432: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.IJBIOMAC.2025.140432: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.ISCI.2024.111654
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd053105'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'zgv3gpshpv.1', 'pxd053105'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd053105
# 4253583190.py - line 84 - INFO - False positives: {'zgv3gpshpv.1'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.ISCI.2024.111654: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.ISCI.2024.111654: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.ISCI.2025.111745
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058465'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058465', 'gse198191'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058465
# 4253583190.py - line 84 - INFO - False positives: {'gse198191'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.ISCI.2025.111745: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.ISCI.2025.111745: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.ISCI.2025.111890
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd050884'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'mtbls12185', 'pxd050884'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd050884
# 4253583190.py - line 84 - INFO - False positives: {'mtbls12185'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.ISCI.2025.111890: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.ISCI.2025.111890: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.ISCI.2025.111903
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd046997'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'phs000424.v10.p2', 'pxd046997', 'gse247291'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd046997
# 4253583190.py - line 84 - INFO - False positives: {'phs000424.v10.p2', 'gse247291'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.ISCI.2025.111903: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.ISCI.2025.111903: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.JACBTS.2024.11.006
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd051715'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd051715', '10.6019/pxd051715', '10.5281/zenodo.10993216'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd051715
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd051715, matched_id=pxd051715
# 4253583190.py - line 84 - INFO - False positives: {'10.5281/zenodo.10993216'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.JACBTS.2024.11.006: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.JACBTS.2024.11.006: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.JGG.2025.01.007
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056375'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'at1g20620', 'at1g19890', 'at5g43940', 'at4g35090', 'pxd056375'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056375
# 4253583190.py - line 84 - INFO - False positives: {'at5g43940', 'at4g35090', 'at1g20620', 'at1g19890'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.JGG.2025.01.007: 0.2
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.JGG.2025.01.007: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.MICRES.2024.128043
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058195'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058195', 'cp029003.1'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058195
# 4253583190.py - line 84 - INFO - False positives: {'cp029003.1'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.MICRES.2024.128043: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.MICRES.2024.128043: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.MOLCEL.2024.07.003
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd052945'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd052945', '6wm4', 'n/a', '6vq8', 'srp017778', 'srp059242', '6wm3', '6wm2', 'srp033517'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd052945
# 4253583190.py - line 84 - INFO - False positives: {'6wm4', 'n/a', '6vq8', 'srp017778', 'srp059242', '6wm3', '6wm2', 'srp033517'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.MOLCEL.2024.07.003: 0.1111111111111111
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.MOLCEL.2024.07.003: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.MOLCEL.2025.01.001
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd046381'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd051662', 'pxd046381', 'prjna1163675', 'prjna1031176'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd046381
# 4253583190.py - line 84 - INFO - False positives: {'pxd051662', 'prjna1163675', 'prjna1031176'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.MOLCEL.2025.01.001: 0.25
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.MOLCEL.2025.01.001: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.NBD.2024.106783
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055364'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse273221', 'pxd055364'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd055364
# 4253583190.py - line 84 - INFO - False positives: {'gse273221'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.NBD.2024.106783: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.NBD.2024.106783: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.OMTN.2024.102442
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd053115'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd053115'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd053115
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.OMTN.2024.102442: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.OMTN.2024.102442: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.PHRS.2024.107552
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055816'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.5281/zenodo.12772115', 'pxd055816', 'n/a'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd055816
# 4253583190.py - line 84 - INFO - False positives: {'10.5281/zenodo.12772115', 'n/a'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.PHRS.2024.107552: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.PHRS.2024.107552: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.PHRS.2025.107580
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd033592'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'drks00016641', 'pxd033592'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd033592
# 4253583190.py - line 84 - INFO - False positives: {'drks00016641'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.PHRS.2025.107580: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.PHRS.2025.107580: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/J.STEM.2024.09.013
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd047104'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a'}
# 4253583190.py - line 84 - INFO - False positives: {'n/a'}
# 4253583190.py - line 89 - INFO - False negatives: {'pxd047104'}
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/J.STEM.2024.09.013: 0.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/J.STEM.2024.09.013: 0.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.bbadis.2023.166906
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd030604'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd030604'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd030604
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.bbadis.2023.166906: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.bbadis.2023.166906: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.bioactmat.2024.08.037
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd050584'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd050584'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd050584
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.bioactmat.2024.08.037: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.bioactmat.2024.08.037: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.celrep.2023.113631
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd040862'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd040862', 'pxd040855', 'gse139018'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd040862
# 4253583190.py - line 84 - INFO - False positives: {'pxd040855', 'gse139018'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.celrep.2023.113631: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.celrep.2023.113631: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.celrep.2024.114977
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054763'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', 'mieandersen/sleep_ne_app_ps1', 'mannlabs/ckg', 'pxd054763'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054763
# 4253583190.py - line 84 - INFO - False positives: {'n/a', 'mieandersen/sleep_ne_app_ps1', 'mannlabs/ckg'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.celrep.2024.114977: 0.25
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.celrep.2024.114977: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.chembiol.2023.04.005
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd030178'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'7obt', '7ob5', '7ob8', '7obs', '7obh', '7obd', '7oby', '7obc', '7obl', 'pxd030178', '7obx', 'gse202350', '7obg', '7obk'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd030178
# 4253583190.py - line 84 - INFO - False positives: {'7obt', '7ob5', '7ob8', '7obs', '7obh', '7obd', '7oby', '7obc', '7obl', '7obx', 'gse202350', '7obg', '7obk'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.chembiol.2023.04.005: 0.07142857142857142
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.chembiol.2023.04.005: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.envint.2024.109243
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055134'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', 'pxd055134'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd055134
# 4253583190.py - line 84 - INFO - False positives: {'n/a'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.envint.2024.109243: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.envint.2024.109243: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.envint.2025.109306
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054970'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd054970', 'pr002076'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054970
# 4253583190.py - line 84 - INFO - False positives: {'pr002076'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.envint.2025.109306: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.envint.2025.109306: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.expneurol.2024.115128
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd046961'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd046961', 'e-mtab-13537'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd046961
# 4253583190.py - line 84 - INFO - False positives: {'e-mtab-13537'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.expneurol.2024.115128: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.expneurol.2024.115128: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.isci.2024.111467
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd044968'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd044968'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd044968
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.isci.2024.111467: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.isci.2024.111467: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.jare.2025.01.036
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd026274'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'prjna746094', 'msv000087817', 'pxd026274'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd026274
# 4253583190.py - line 84 - INFO - False positives: {'prjna746094', 'msv000087817'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.jare.2025.01.036: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.jare.2025.01.036: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.jbc.2025.108208
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056970'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd056970', 'pxd057514', 'prjeb79494', 'pxd057513', 'or479703', 'gse267957', 'pxd057511', 'gse267955'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056970
# 4253583190.py - line 84 - INFO - False positives: {'pxd057514', 'prjeb79494', 'pxd057513', 'or479703', 'gse267957', 'pxd057511', 'gse267955'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.jbc.2025.108208: 0.125
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.jbc.2025.108208: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.jgg.2024.12.010
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd052721'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd052721'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd052721
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.jgg.2024.12.010: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.jgg.2024.12.010: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.jsb.2024.108162
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd042943'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'emd-17430', 'emd-16868', 'pxd042943', 'empiar-10453'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd042943
# 4253583190.py - line 84 - INFO - False positives: {'emd-17430', 'emd-16868', 'empiar-10453'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.jsb.2024.108162: 0.25
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.jsb.2024.108162: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.lanmic.2024.06.002
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd046473'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd046473', 'genbank or621197–or621290', 'emd-42839', 'prjna1023018', '8uzc'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd046473
# 4253583190.py - line 84 - INFO - False positives: {'genbank or621197–or621290', 'prjna1023018', 'emd-42839', '8uzc'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.lanmic.2024.06.002: 0.2
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.lanmic.2024.06.002: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.mcpro.2024.100900
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054336'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd054336'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054336
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.mcpro.2024.100900: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.mcpro.2024.100900: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.redox.2024.103352
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd048535,pxd050410'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd048535', 'pxd050410'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd048535, gt_id=pxd048535,pxd050410
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd050410, matched_id=pxd048535,pxd050410
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.redox.2024.103352: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.redox.2024.103352: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1016/j.yexcr.2025.114408
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd049800'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd049800'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd049800
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1016/j.yexcr.2025.114408: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1016/j.yexcr.2025.114408: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1021/ACS.JPROTEOME.4C00698
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd043480'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', 'pxd043480'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd043480
# 4253583190.py - line 84 - INFO - False positives: {'n/a'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1021/ACS.JPROTEOME.4C00698: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1021/ACS.JPROTEOME.4C00698: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1021/acs.jproteome.4c00630
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054133'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd054133'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054133
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1021/acs.jproteome.4c00630: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1021/acs.jproteome.4c00630: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41419-024-07267-4
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058491'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058491'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058491
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41419-024-07267-4: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41419-024-07267-4: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41422-025-01078-8
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059980,pxd059981'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse87544', 'gse132730', 'gse132355', 'pxd059981', 'gse119960', 'pxd059980', 'gse148568'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd059981, gt_id=pxd059980,pxd059981
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd059980, matched_id=pxd059980,pxd059981
# 4253583190.py - line 84 - INFO - False positives: {'gse87544', 'gse132730', 'gse132355', 'gse119960', 'gse148568'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41422-025-01078-8: 0.16666666666666666
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41422-025-01078-8: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-55908-9
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd045211,pxd045265'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd045211', 'gse148058', 'gse201719', 'pxd045265', '10.5281/zenodo.14496237'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd045211, gt_id=pxd045211,pxd045265
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd045265, matched_id=pxd045211,pxd045265
# 4253583190.py - line 84 - INFO - False positives: {'gse148058', 'gse201719', '10.5281/zenodo.14496237'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-55908-9: 0.25
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-55908-9: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-55967-Y
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd055944,pxd055948'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'5p21', '1x1s', '4q21', '1x1r', 'pxd055944', 'pxd055948'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd055944, gt_id=pxd055944,pxd055948
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd055948, matched_id=pxd055944,pxd055948
# 4253583190.py - line 84 - INFO - False positives: {'5p21', '1x1s', '4q21', '1x1r'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-55967-Y: 0.2
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-55967-Y: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-56041-3
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056008'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd056008'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056008
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-56041-3: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-56041-3: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-56210-4
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd050918'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'https://doi.org/10.17632/4mfr9btjtt.1', 'pxd050918', 'https://doi.org/10.17632/2z97z3bcw6.1'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd050918
# 4253583190.py - line 84 - INFO - False positives: {'https://doi.org/10.17632/4mfr9btjtt.1', 'https://doi.org/10.17632/2z97z3bcw6.1'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-56210-4: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-56210-4: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-56387-8
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059817,pxd059868'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059868', 'pxd059817', '14197261'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd059817, gt_id=pxd059817,pxd059868
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd059868, matched_id=pxd059817,pxd059868
# 4253583190.py - line 84 - INFO - False positives: {'14197261'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-56387-8: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-56387-8: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41467-025-56720-1
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059466'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059466'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059466
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41467-025-56720-1: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41467-025-56720-1: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41541-025-01069-1
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd051490'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', 'pxd051490', 'nct05841095'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd051490
# 4253583190.py - line 84 - INFO - False positives: {'n/a', 'nct05841095'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41541-025-01069-1: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41541-025-01069-1: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41556-024-01604-7
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058353'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse62452', 'gse255740', 'gse279023', 'gse255533', 'gse255702', 'pxd058353', 'gse255703'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058353
# 4253583190.py - line 84 - INFO - False positives: {'gse62452', 'gse255740', 'gse279023', 'gse255533', 'gse255702', 'gse255703'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41556-024-01604-7: 0.14285714285714285
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41556-024-01604-7: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41557-024-01711-W
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd057262'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'https://doi.org/10.6084/m9.figshare.25782309', 'pxd057262'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd057262
# 4253583190.py - line 84 - INFO - False positives: {'https://doi.org/10.6084/m9.figshare.25782309'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41557-024-01711-W: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41557-024-01711-W: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41564-024-01808-5
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd020317'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'prjna979916', '10.5281/zenodo.11086255', 'pxd020317'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd020317
# 4253583190.py - line 84 - INFO - False positives: {'prjna979916', '10.5281/zenodo.11086255'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41564-024-01808-5: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41564-024-01808-5: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41564-024-01901-9
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd057832,pxd057885'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'hgnc', 'genome sequence archive (gsa)', 'pxd057832', 'protein data bank', 'the human protein atlas 23.0', 'n/a', 'reactome v.86', 'sequence read archive (sra)', 'hra006201', 'ucsc genome browser', 'pxd057885'}
# 4253583190.py - line 66 - INFO - Partial or alias match found: eval_id=pxd057832, gt_id=pxd057832,pxd057885
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=pxd057885, matched_id=pxd057832,pxd057885
# 4253583190.py - line 84 - INFO - False positives: {'hgnc', 'genome sequence archive (gsa)', 'protein data bank', 'the human protein atlas 23.0', 'n/a', 'reactome v.86', 'sequence read archive (sra)', 'hra006201', 'ucsc genome browser'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41564-024-01901-9: 0.1
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41564-024-01901-9: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41586-024-08493-8
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd047450'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'emd-18751', 'pxd047450', 'emd-18752', '8qyk', '8qy7', 'emd-18747', '8qyc', '8qyh', 'emd-18848', 'emd-18754', '8qyd', 'emd-18750', 'emd-18766', 'emd-18756', '8qyy', '8r68'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd047450
# 4253583190.py - line 84 - INFO - False positives: {'8qyd', 'emd-18750', 'emd-18756', 'emd-18751', 'emd-18752', '8qyk', '8qy7', 'emd-18747', '8qyc', '8qyh', 'emd-18848', 'emd-18754', '8r68', 'emd-18766', '8qyy'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.1038/S41586-024-08493-8: 0.0625
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.1038/S41586-024-08493-8: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.1038/S41588-024-02015-Y
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056439'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse180947', 'pxd056439', 'gse236370', 'gse264514'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056439
# 4253583190.py - line 84 - INFO - False positives: {'gse180947', 'gse236370', 'gse264514'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# ...
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD056057: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD056057: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD056511
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056511'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.1016/j.phrs.2024.107484', '10.6019/pxd056511', 'pxd056511'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056511
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd056511, matched_id=pxd056511
# 4253583190.py - line 84 - INFO - False positives: {'10.1016/j.phrs.2024.107484'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD056511: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD056511: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD056853
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056853'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd056853', '10.1128/msphere.00945-24', '10.6019/pxd056853'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056853
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd056853, matched_id=pxd056853
# 4253583190.py - line 84 - INFO - False positives: {'10.1128/msphere.00945-24'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD056853: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD056853: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD056866
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056866'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.1128/msphere.00945-24', '10.6019/pxd056866', 'pxd056866'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056866
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd056866, matched_id=pxd056866
# 4253583190.py - line 84 - INFO - False positives: {'10.1128/msphere.00945-24'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD056866: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD056866: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD056948
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd056948'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd056948', '10.6019/pxd056948'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd056948
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd056948, matched_id=pxd056948
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD056948: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD056948: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD057018
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd057018'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'n/a', '10.1128/msphere.00945-24', '10.6019/pxd057018', 'pxd057018'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd057018
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd057018, matched_id=pxd057018
# 4253583190.py - line 84 - INFO - False positives: {'n/a', '10.1128/msphere.00945-24'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD057018: 0.3333333333333333
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD057018: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD057861
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd057861'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.1186/s13024-025-00800-9', 'pxd057861', '10.6019/pxd057861'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd057861
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd057861, matched_id=pxd057861
# 4253583190.py - line 84 - INFO - False positives: {'10.1186/s13024-025-00800-9'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD057861: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD057861: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD057889
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd057889'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.6019/pxd057889', 'pxd057889'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd057889
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd057889, matched_id=pxd057889
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD057889: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD057889: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD058016
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058016'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058016'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058016
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD058016: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD058016: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD058419
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd058419'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd058419'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd058419
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD058419: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD058419: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059430
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059430'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059430'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059430
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059430: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059430: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059522
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059522'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059522'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059522
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059522: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059522: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059688
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059688'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059688', '10.3389/fimmu.2024.1512605', '10.6019/pxd059688'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059688
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd059688, matched_id=pxd059688
# 4253583190.py - line 84 - INFO - False positives: {'10.3389/fimmu.2024.1512605'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059688: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059688: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059738
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059738'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059738', '10.6019/pxd059738'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059738
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd059738, matched_id=pxd059738
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059738: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059738: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059766
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059766'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059766'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059766
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059766: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059766: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059785
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059785'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059785'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059785
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059785: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059785: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059791
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059791'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059791', '10.6019/pxd059791'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059791
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd059791, matched_id=pxd059791
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059791: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059791: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059803
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059803'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd059803', '10.6019/pxd059803'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059803
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd059803, matched_id=pxd059803
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059803: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059803: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.6019/PXD059932
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd059932'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'10.6019/pxd059932', 'pxd059932'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd059932
# 4253583190.py - line 79 - INFO - Removing alias from false positives: eval_id=10.6019/pxd059932, matched_id=pxd059932
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.6019/PXD059932: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.6019/PXD059932: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.7554/ELIFE.86194.2
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd054648'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd054648'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd054648
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.7554/ELIFE.86194.2: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.7554/ELIFE.86194.2: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.7554/ELIFE.86931.2
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd037489'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'pxd037489'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd037489
# 4253583190.py - line 84 - INFO - False positives: set()
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.7554/ELIFE.86931.2: 1.0
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.7554/ELIFE.86931.2: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.7554/ELIFE.98523.2
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd045157'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'gse195983', 'pxd045157'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd045157
# 4253583190.py - line 84 - INFO - False positives: {'gse195983'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.7554/ELIFE.98523.2: 0.5
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.7554/ELIFE.98523.2: 1.0
# 4253583190.py - line 17 - INFO -
# Starting performance evaluation for source page: https://dx.doi.org/10.7554/elife.78385
# 4253583190.py - line 24 - INFO - Ground truth datasets: {'pxd032017'}
# 4253583190.py - line 33 - INFO - Evaluation datasets: {'emd-14506', 'emd-14502', 'pxd032017', 'pxd032024', 'pxd032016', 'emd-14503', 'pxd018034', 'emd-14505', 'pxd032034'}
# 4253583190.py - line 57 - INFO - Exact match found: pxd032017
# 4253583190.py - line 84 - INFO - False positives: {'emd-14506', 'emd-14502', 'pxd032024', 'pxd032016', 'emd-14503', 'pxd018034', 'emd-14505', 'pxd032034'}
# 4253583190.py - line 89 - INFO - False negatives: set()
# 4253583190.py - line 96 - INFO - Precision for https://dx.doi.org/10.7554/elife.78385: 0.1111111111111111
# 4253583190.py - line 97 - INFO - Recall for https://dx.doi.org/10.7554/elife.78385: 1.0
# {'average_precision': 0.6402616346109496,
#  'average_recall': 0.9908675799086758,
#  'f1_score': 0.7778838006799631}
