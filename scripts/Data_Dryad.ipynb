# %% [markdown]
# # Dryad Dataset Downloader
#
# This notebook downloads datasets from the Dryad API and saves them to a parquet file using Polars for efficient processing.

# %%
import polars as pl
import requests
import json
import time
from typing import List, Dict, Any
from pathlib import Path

# %%
# Configuration
BASE_URL = "https://datadryad.org/api/v2/datasets"
OUTPUT_FILE = "scripts/output/gold/dryad_datasets.parquet"
BATCH_SIZE = 100  # Number of records per API request
DELAY_BETWEEN_REQUESTS = 0.5  # Seconds to wait between requests to be respectful

# %%
def make_dryad_request(url: str, params: Dict[str, Any] = None) -> Dict[str, Any]:
    """
    Make a request to the Dryad API with error handling and rate limiting.
    """
    try:
        response = requests.get(url, params=params, timeout=30)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error making request to {url}: {e}")
        return None

# %%
# Now that we've seen the actual structure, let's update our flattening function
# Based on exploration: extract ALL available fields from the API response

def flatten_dataset_actual(dataset: Dict[str, Any]) -> Dict[str, Any]:
    """
    Flatten dataset structure based on ACTUAL API response format.
    Extracts ALL available fields from the dataset.
    """
    flattened = {}
    
    # Basic fields (direct extraction)
    flattened['id'] = dataset.get('id')
    flattened['identifier'] = dataset.get('identifier')  # DOI-like identifier
    flattened['title'] = dataset.get('title')
    flattened['abstract'] = dataset.get('abstract')
    
    # Storage and size info
    flattened['storage_size'] = dataset.get('storageSize')
    
    # Publication info
    flattened['related_publication_issn'] = dataset.get('relatedPublicationISSN')

    # Usage Notes
    flattened['usageNotes'] = dataset.get('usageNotes')
    
    # Dates
    flattened['publication_date'] = dataset.get('publicationDate')
    flattened['last_modification_date'] = dataset.get('lastModificationDate')
    
    # Version and status info
    flattened['version_number'] = dataset.get('versionNumber')
    flattened['version_status'] = dataset.get('versionStatus')
    flattened['curation_status'] = dataset.get('curationStatus')
    flattened['version_changes'] = dataset.get('versionChanges')
    
    # Access and sharing
    flattened['visibility'] = dataset.get('visibility')
    flattened['sharing_link'] = dataset.get('sharingLink')
    flattened['license'] = dataset.get('license')
    
    # Links (extract useful link information)
    links = dataset.get('_links', {})
    if links:
        # Extract key links as separate fields
        flattened['self_link'] = links.get('self', {}).get('href') if links.get('self') else None
        flattened['download_link'] = links.get('stash:download', {}).get('href') if links.get('stash:download') else None
        flattened['files_link'] = links.get('stash:files', {}).get('href') if links.get('stash:files') else None
        flattened['versions_link'] = links.get('stash:versions', {}).get('href') if links.get('stash:versions') else None
        # Store all links as JSON string for reference
        flattened['all_links'] = json.dumps(links) if links else None
    else:
        flattened['self_link'] = None
        flattened['download_link'] = None
        flattened['files_link'] = None
        flattened['versions_link'] = None
        flattened['all_links'] = None
    
    # Authors - comprehensive extraction
    authors = dataset.get('authors', [])
    if authors:
        author_names = []
        author_emails = []
        author_affiliations = []
        author_ror_ids = []
        for author in authors:
            # Full name
            name_parts = []
            if author.get('firstName'):
                name_parts.append(author.get('firstName'))
            if author.get('lastName'):
                name_parts.append(author.get('lastName'))
            if name_parts:
                author_names.append(' '.join(name_parts))
            
            # Email
            if author.get('email'):
                author_emails.append(author.get('email'))
            
            # Affiliation
            if author.get('affiliation'):
                author_affiliations.append(author.get('affiliation'))
            
            # ROR IDs
            if author.get('affiliationROR'):
                author_ror_ids.append(author.get('affiliationROR'))
        
        flattened['authors'] = '; '.join(author_names) if author_names else None
        flattened['author_emails'] = '; '.join([email for email in author_emails if email]) if author_emails else None
        flattened['author_affiliations'] = '; '.join(set(author_affiliations)) if author_affiliations else None
        flattened['author_ror_ids'] = '; '.join(set(author_ror_ids)) if author_ror_ids else None
        flattened['author_count'] = len(authors)
        # Store full author data as JSON for reference
        flattened['authors_full'] = json.dumps(authors) if authors else None
    else:
        flattened['authors'] = None
        flattened['author_emails'] = None
        flattened['author_affiliations'] = None
        flattened['author_ror_ids'] = None
        flattened['author_count'] = 0
        flattened['authors_full'] = None
    
    # Keywords 
    keywords = dataset.get('keywords', [])
    flattened['keywords'] = '; '.join(keywords) if keywords else None
    flattened['keyword_count'] = len(keywords) if keywords else 0
    
    # Locations - comprehensive extraction
    locations = dataset.get('locations', [])
    if locations:
        location_info = []
        location_places = []
        location_coords = []
        for location in locations:
            if isinstance(location, dict):
                # Extract place names
                place = location.get('place', '')
                if place:
                    location_places.append(place)
                    location_info.append(place)
                
                # Extract coordinates
                if location.get('point'):
                    coords = location.get('point', {})
                    lat = coords.get('latitude')
                    lon = coords.get('longitude')
                    if lat and lon:
                        coord_str = f"({lat}, {lon})"
                        location_coords.append(coord_str)
                        location_info.append(coord_str)
            elif isinstance(location, str):
                location_info.append(location)
        
        flattened['locations'] = '; '.join(location_info) if location_info else None
        flattened['location_places'] = '; '.join(location_places) if location_places else None
        flattened['location_coordinates'] = '; '.join(location_coords) if location_coords else None
        flattened['location_count'] = len(locations)
        # Store full location data as JSON
        flattened['locations_full'] = json.dumps(locations) if locations else None
    else:
        flattened['locations'] = None
        flattened['location_places'] = None
        flattened['location_coordinates'] = None
        flattened['location_count'] = 0
        flattened['locations_full'] = None
    
    # Funders - comprehensive extraction
    funders = dataset.get('funders', [])
    if funders:
        funder_names = []
        funder_awards = []
        funder_info = []
        for funder in funders:
            if isinstance(funder, dict):
                funder_name = funder.get('funderName', '')
                award_number = funder.get('awardNumber', '')
                
                if funder_name:
                    funder_names.append(funder_name)
                
                if award_number:
                    funder_awards.append(award_number)
                
                if funder_name and award_number:
                    funder_info.append(f"{funder_name} ({award_number})")
                elif funder_name:
                    funder_info.append(funder_name)
            elif isinstance(funder, str):
                funder_info.append(funder)
                funder_names.append(funder)
        
        flattened['funders'] = '; '.join(funder_info) if funder_info else None
        flattened['funder_names'] = '; '.join(set(funder_names)) if funder_names else None
        flattened['funder_awards'] = '; '.join(funder_awards) if funder_awards else None
        flattened['funder_count'] = len(funders)
        # Store full funder data as JSON
        flattened['funders_full'] = json.dumps(funders) if funders else None
    else:
        flattened['funders'] = None
        flattened['funder_names'] = None
        flattened['funder_awards'] = None
        flattened['funder_count'] = 0
        flattened['funders_full'] = None
    
    # Related works - comprehensive extraction
    related_works = dataset.get('relatedWorks', [])
    if related_works:
        related_info = []
        relation_types = []
        identifiers = []
        for work in related_works:
            if isinstance(work, dict):
                work_type = work.get('relationshipType', '')
                identifier = work.get('identifier', '')
                
                if work_type:
                    relation_types.append(work_type)
                
                if identifier:
                    identifiers.append(identifier)
                
                if work_type and identifier:
                    related_info.append(f"{work_type}: {identifier}")
                elif identifier:
                    related_info.append(identifier)
        
        flattened['related_works'] = '; '.join(related_info) if related_info else None
        flattened['relation_types'] = '; '.join(set(relation_types)) if relation_types else None
        flattened['related_identifiers'] = '; '.join(identifiers) if identifiers else None
        flattened['related_works_count'] = len(related_works)
        # Store full related works data as JSON
        flattened['related_works_full'] = json.dumps(related_works) if related_works else None
    else:
        flattened['related_works'] = None
        flattened['relation_types'] = None
        flattened['related_identifiers'] = None
        flattened['related_works_count'] = 0
        flattened['related_works_full'] = None
    
    # Metrics - comprehensive extraction
    metrics = dataset.get('metrics', {})
    if metrics:
        flattened['downloads'] = metrics.get('downloads')
        flattened['views'] = metrics.get('views')
        # Extract any other metrics that might be available
        for key, value in metrics.items():
            if key not in ['downloads', 'views']:
                flattened[f'metric_{key}'] = value
        # Store full metrics as JSON
        flattened['metrics_full'] = json.dumps(metrics) if metrics else None
    else:
        flattened['downloads'] = None
        flattened['views'] = None
        flattened['metrics_full'] = None
    
    return flattened

# %%
def download_dryad_datasets() -> pl.DataFrame:
    """
    Download all datasets from Dryad API using the refined flattening function.
    Returns a Polars DataFrame with comprehensive field extraction.
    Fault-tolerant with checkpoint saving and resume capability.
    """
    # Checkpoint file to save progress
    checkpoint_file = "scripts/output/checkpoint_dryad_progress.json"
    checkpoint_data_file = "scripts/output/checkpoint_dryad_data.parquet"
    
    # Try to load existing progress
    all_datasets = []
    start_page = 1
    total_datasets = 0
    
    try:
        if Path(checkpoint_file).exists():
            print("📂 Found existing checkpoint, resuming download...")
            with open(checkpoint_file, 'r') as f:
                checkpoint = json.load(f)
                start_page = checkpoint.get('next_page', 1)
                total_datasets = checkpoint.get('total_processed', 0)
            
            if Path(checkpoint_data_file).exists():
                existing_df = pl.read_parquet(checkpoint_data_file)
                all_datasets = existing_df.to_dicts()
                print(f"🔄 Resuming from page {start_page}, already have {total_datasets:,} datasets")
            else:
                print(f"🔄 Resuming from page {start_page} (no previous data found)")
    except Exception as e:
        print(f"⚠️  Could not load checkpoint: {e}, starting fresh")
        start_page = 1
        total_datasets = 0
        all_datasets = []
    
    print(f"🚀 Starting download from Dryad API: {BASE_URL}")
    print(f"📊 Batch size: {BATCH_SIZE} | Rate limit: {DELAY_BETWEEN_REQUESTS}s between requests")
    
    page = start_page
    last_checkpoint_size = len(all_datasets)
    
    try:
        while True:
            print(f"\n📥 Fetching page {page}...")
            
            # Parameters for pagination
            params = {
                'page': page,
                'per_page': BATCH_SIZE
            }
            
            # Make API request with retries
            retry_count = 0
            max_retries = 3
            response_data = None
            
            while retry_count < max_retries and response_data is None:
                response_data = make_dryad_request(BASE_URL, params)
                if response_data is None:
                    retry_count += 1
                    if retry_count < max_retries:
                        wait_time = 2 ** retry_count  # Exponential backoff
                        print(f"⏳ Retry {retry_count}/{max_retries} in {wait_time}s...")
                        time.sleep(wait_time)
            
            if response_data is None:
                print(f"❌ Failed to fetch page {page} after {max_retries} retries")
                break
            
            # Extract datasets from response
            datasets = response_data.get('_embedded', {}).get('stash:datasets', [])
            
            if not datasets:
                print(f"✅ No more datasets found on page {page}. Download complete!")
                break
            
            # Process and flatten each dataset using the REFINED function
            page_processed = 0
            page_errors = 0
            for i, dataset in enumerate(datasets):
                try:
                    flattened_dataset = flatten_dataset_actual(dataset)
                    all_datasets.append(flattened_dataset)
                    page_processed += 1
                except Exception as e:
                    page_errors += 1
                    print(f"⚠️  Error processing dataset {i+1} on page {page}: {e}")
                    continue
            
            total_datasets += page_processed
            print(f"✅ Processed {page_processed}/{len(datasets)} datasets from page {page}")
            if page_errors > 0:
                print(f"⚠️  {page_errors} errors on this page")
            print(f"📈 Total processed so far: {total_datasets:,}")
            
            # Save checkpoint every 10 pages or if we have 1000+ new records
            if (page % 10 == 0) or (len(all_datasets) - last_checkpoint_size >= 1000):
                try:
                    print(f"💾 Saving checkpoint at page {page}...")
                    
                    # Create directories if needed
                    Path(checkpoint_file).parent.mkdir(parents=True, exist_ok=True)
                    
                    # Save checkpoint metadata
                    checkpoint_info = {
                        'next_page': page + 1,
                        'total_processed': total_datasets,
                        'last_checkpoint': str(time.time()),
                        'datasets_count': len(all_datasets)
                    }
                    
                    with open(checkpoint_file, 'w') as f:
                        json.dump(checkpoint_info, f, indent=2)
                    
                    # Save data checkpoint (handle schema issues gracefully)
                    if all_datasets:
                        try:
                            checkpoint_df = pl.DataFrame(all_datasets, infer_schema_length=None)
                            checkpoint_df.write_parquet(checkpoint_data_file, compression="snappy")
                            print(f"✅ Checkpoint saved: {len(all_datasets):,} records")
                            last_checkpoint_size = len(all_datasets)
                        except Exception as schema_error:
                            print(f"⚠️  Schema error in checkpoint, trying string conversion...")
                            # Fallback: save as strings
                            string_datasets = []
                            for dataset in all_datasets:
                                string_dataset = {k: str(v) if v is not None else None for k, v in dataset.items()}
                                string_datasets.append(string_dataset)
                            checkpoint_df = pl.DataFrame(string_datasets)
                            checkpoint_df.write_parquet(checkpoint_data_file, compression="snappy")
                            print(f"✅ Checkpoint saved as strings: {len(all_datasets):,} records")
                            last_checkpoint_size = len(all_datasets)
                        
                except Exception as checkpoint_error:
                    print(f"⚠️  Could not save checkpoint: {checkpoint_error}")
                    # Continue anyway - don't fail the whole download
            
            # Check if we've reached the last page
            page_info = response_data.get('page', {})
            current_page = page_info.get('number', page)
            total_pages = page_info.get('totalPages')
            
            if total_pages:
                print(f"📄 Progress: {current_page}/{total_pages} pages ({current_page/total_pages*100:.1f}%)")
                if current_page >= total_pages:
                    print(f"🎉 Reached last page ({total_pages}). Download complete!")
                    break
            
            # Rate limiting
            time.sleep(DELAY_BETWEEN_REQUESTS)
            page += 1
            
    except KeyboardInterrupt:
        print(f"\n🛑 Download interrupted by user at page {page}")
        print(f"📊 Progress saved: {len(all_datasets):,} datasets collected")
        # Save final checkpoint before exiting
        try:
            checkpoint_info = {
                'next_page': page,
                'total_processed': len(all_datasets),
                'interrupted': True,
                'last_checkpoint': str(time.time())
            }
            with open(checkpoint_file, 'w') as f:
                json.dump(checkpoint_info, f, indent=2)
            print(f"💾 Progress saved to resume later")
        except:
            pass
    
    except Exception as e:
        print(f"\n❌ Unexpected error: {e}")
        print(f"📊 Progress so far: {len(all_datasets):,} datasets")
        # Save emergency checkpoint
        try:
            checkpoint_info = {
                'next_page': page,
                'total_processed': len(all_datasets),
                'error': str(e),
                'last_checkpoint': str(time.time())
            }
            with open(checkpoint_file, 'w') as f:
                json.dump(checkpoint_info, f, indent=2)
        except:
            pass
    
    # Final summary
    print(f"\n🎯 Download Summary:")
    print(f"   Total datasets processed: {len(all_datasets):,}")
    print(f"   Pages fetched: {page - start_page + 1}")
    
    # Convert to Polars DataFrame with robust error handling
    if all_datasets:
        try:
            print("🔧 Creating final DataFrame...")
            df = pl.DataFrame(all_datasets, infer_schema_length=None)
            print(f"   DataFrame shape: {df.shape}")
            print(f"   Columns extracted: {len(df.columns)}")
            
            # Clean up checkpoint files on success
            try:
                if Path(checkpoint_file).exists():
                    Path(checkpoint_file).unlink()
                if Path(checkpoint_data_file).exists():
                    Path(checkpoint_data_file).unlink()
                print("🧹 Cleaned up checkpoint files")
            except:
                pass
            
            return df
            
        except Exception as e:
            print(f"⚠️  Error creating final DataFrame: {e}")
            print("🔧 Using string conversion fallback...")
            
            try:
                # Convert all to strings as fallback
                string_datasets = []
                for dataset in all_datasets:
                    string_dataset = {k: str(v) if v is not None else None for k, v in dataset.items()}
                    string_datasets.append(string_dataset)
                
                df = pl.DataFrame(string_datasets)
                print(f"✅ Fallback DataFrame created: {df.shape}")
                
                # Try to optimize numeric columns
                numeric_cols = ['id', 'storage_size', 'version_number', 'author_count', 
                               'keyword_count', 'location_count', 'funder_count', 
                               'related_works_count', 'downloads', 'views']
                
                for col in numeric_cols:
                    if col in df.columns:
                        try:
                            df = df.with_columns(pl.col(col).cast(pl.Int64, strict=False))
                        except:
                            pass
                
                return df
                
            except Exception as e2:
                print(f"❌ All DataFrame creation methods failed: {e2}")
                print(f"💾 Data is still saved in checkpoint file: {checkpoint_data_file}")
                return pl.DataFrame()
    else:
        print("❌ No datasets processed successfully!")
        return pl.DataFrame()

# %% [markdown]
# ## Download Dryad Datasets
#
# Execute the download process to fetch all datasets from the Dryad API:

# %%
# Execute the download
dryad_df = download_dryad_datasets()

if not dryad_df.is_empty():
    print(f"\n🔍 Quick preview of downloaded data:")
    print(f"Columns: {list(dryad_df.columns[:10])}{'...' if len(dryad_df.columns) > 10 else ''}")
    
    # Show sample data
    preview_cols = ['id', 'title', 'authors', 'publication_date', 'keywords']
    available_cols = [col for col in preview_cols if col in dryad_df.columns]
    if available_cols:
        print(f"\n📋 Sample records:")
        sample_df = dryad_df.head(3).select(available_cols)
        print(sample_df)
    
    # Quick stats
    print(f"\n📊 Quick statistics:")
    stats = {
        'Total records': len(dryad_df),
        'Non-null titles': dryad_df.filter(pl.col('title').is_not_null()).shape[0] if 'title' in dryad_df.columns else 'N/A',
        'Non-null abstracts': dryad_df.filter(pl.col('abstract').is_not_null()).shape[0] if 'abstract' in dryad_df.columns else 'N/A',
        'Non-null authors': dryad_df.filter(pl.col('authors').is_not_null()).shape[0] if 'authors' in dryad_df.columns else 'N/A'
    }
    
    for key, value in stats.items():
        print(f"   {key}: {value}")
    
else:
    print("❌ No data downloaded. Check API connectivity and parameters.")
# Out:
# 🚀 Starting download from Dryad API: https://datadryad.org/api/v2/datasets
# 📊 Batch size: 100 | Rate limit: 0.5s between requests
#
# 📥 Fetching page 1...
# ✅ Processed 100/100 datasets from page 1
# 📈 Total processed so far: 100
# ✅ Processed 100/100 datasets from page 1
# 📈 Total processed so far: 100
#
# 📥 Fetching page 2...
#
# 📥 Fetching page 2...
# ✅ Processed 100/100 datasets from page 2
# 📈 Total processed so far: 200
# ✅ Processed 100/100 datasets from page 2
# 📈 Total processed so far: 200
#
# 📥 Fetching page 3...
#
# 📥 Fetching page 3...
# ✅ Processed 100/100 datasets from page 3
# 📈 Total processed so far: 300
# ✅ Processed 100/100 datasets from page 3
# 📈 Total processed so far: 300
#
# 📥 Fetching page 4...
#
# 📥 Fetching page 4...
# ✅ Processed 100/100 datasets from page 4
# 📈 Total processed so far: 400
# ✅ Processed 100/100 datasets from page 4
# 📈 Total processed so far: 400
#
# 📥 Fetching page 5...
#
# 📥 Fetching page 5...
# ✅ Processed 100/100 datasets from page 5
# 📈 Total processed so far: 500
# ✅ Processed 100/100 datasets from page 5
# 📈 Total processed so far: 500
#
# 📥 Fetching page 6...
#
# 📥 Fetching page 6...
# ✅ Processed 100/100 datasets from page 6
# 📈 Total processed so far: 600
# ✅ Processed 100/100 datasets from page 6
# 📈 Total processed so far: 600
#
# 📥 Fetching page 7...
#
# 📥 Fetching page 7...
# ✅ Processed 100/100 datasets from page 7
# 📈 Total processed so far: 700
# ✅ Processed 100/100 datasets from page 7
# 📈 Total processed so far: 700
#
# 📥 Fetching page 8...
#
# 📥 Fetching page 8...
# ✅ Processed 100/100 datasets from page 8
# 📈 Total processed so far: 800
# ✅ Processed 100/100 datasets from page 8
# 📈 Total processed so far: 800
#
# 📥 Fetching page 9...
#
# 📥 Fetching page 9...
# ✅ Processed 100/100 datasets from page 9
# 📈 Total processed so far: 900
# ✅ Processed 100/100 datasets from page 9
# 📈 Total processed so far: 900
#
# 📥 Fetching page 10...
#
# 📥 Fetching page 10...
# ✅ Processed 100/100 datasets from page 10
# 📈 Total processed so far: 1,000
# 💾 Saving checkpoint at page 10...
# ✅ Checkpoint saved: 1,000 records
# ✅ Processed 100/100 datasets from page 10
# 📈 Total processed so far: 1,000
# 💾 Saving checkpoint at page 10...
# ✅ Checkpoint saved: 1,000 records
#
# 📥 Fetching page 11...
#
# 📥 Fetching page 11...
# ✅ Processed 100/100 datasets from page 11
# 📈 Total processed so far: 1,100
# ✅ Processed 100/100 datasets from page 11
# 📈 Total processed so far: 1,100
#
# 📥 Fetching page 12...
#
# 📥 Fetching page 12...
# ✅ Processed 100/100 datasets from page 12
# 📈 Total processed so far: 1,200
# ✅ Processed 100/100 datasets from page 12
# 📈 Total processed so far: 1,200
#
# 📥 Fetching page 13...
#
# 📥 Fetching page 13...
# ✅ Processed 100/100 datasets from page 13
# 📈 Total processed so far: 1,300
# ✅ Processed 100/100 datasets from page 13
# 📈 Total processed so far: 1,300
#
# 📥 Fetching page 14...
#
# 📥 Fetching page 14...
# ✅ Processed 100/100 datasets from page 14
# 📈 Total processed so far: 1,400
# ✅ Processed 100/100 datasets from page 14
# 📈 Total processed so far: 1,400
#
# 📥 Fetching page 15...
#
# 📥 Fetching page 15...
# ✅ Processed 100/100 datasets from page 15
# 📈 Total processed so far: 1,500
# ✅ Processed 100/100 datasets from page 15
# 📈 Total processed so far: 1,500
#
# 📥 Fetching page 16...
#
# 📥 Fetching page 16...
# ✅ Processed 100/100 datasets from page 16
# 📈 Total processed so far: 1,600
# ✅ Processed 100/100 datasets from page 16
# 📈 Total processed so far: 1,600
#
# 📥 Fetching page 17...
#
# 📥 Fetching page 17...
# ✅ Processed 100/100 datasets from page 17
# 📈 Total processed so far: 1,700
# ✅ Processed 100/100 datasets from page 17
# 📈 Total processed so far: 1,700
#
# 📥 Fetching page 18...
#
# 📥 Fetching page 18...
# ✅ Processed 100/100 datasets from page 18
# 📈 Total processed so far: 1,800
# ✅ Processed 100/100 datasets from page 18
# 📈 Total processed so far: 1,800
#
# 📥 Fetching page 19...
#
# 📥 Fetching page 19...
# ✅ Processed 100/100 datasets from page 19
# 📈 Total processed so far: 1,900
# ✅ Processed 100/100 datasets from page 19
# 📈 Total processed so far: 1,900
#
# 📥 Fetching page 20...
#
# 📥 Fetching page 20...
# ✅ Processed 100/100 datasets from page 20
# 📈 Total processed so far: 2,000
# 💾 Saving checkpoint at page 20...
# ✅ Checkpoint saved: 2,000 records
# ✅ Processed 100/100 datasets from page 20
# 📈 Total processed so far: 2,000
# 💾 Saving checkpoint at page 20...
# ✅ Checkpoint saved: 2,000 records
#
# 📥 Fetching page 21...
#
# 📥 Fetching page 21...
# ✅ Processed 100/100 datasets from page 21
# 📈 Total processed so far: 2,100
# ✅ Processed 100/100 datasets from page 21
# 📈 Total processed so far: 2,100
#
# 📥 Fetching page 22...
#
# 📥 Fetching page 22...
# ✅ Processed 100/100 datasets from page 22
# 📈 Total processed so far: 2,200
# ✅ Processed 100/100 datasets from page 22
# 📈 Total processed so far: 2,200
#
# 📥 Fetching page 23...
#
# 📥 Fetching page 23...
# ✅ Processed 100/100 datasets from page 23
# 📈 Total processed so far: 2,300
# ✅ Processed 100/100 datasets from page 23
# 📈 Total processed so far: 2,300
#
# 📥 Fetching page 24...
#
# 📥 Fetching page 24...
# ✅ Processed 100/100 datasets from page 24
# 📈 Total processed so far: 2,400
# ✅ Processed 100/100 datasets from page 24
# 📈 Total processed so far: 2,400
#
# 📥 Fetching page 25...
#
# 📥 Fetching page 25...
# ✅ Processed 100/100 datasets from page 25
# 📈 Total processed so far: 2,500
# ✅ Processed 100/100 datasets from page 25
# 📈 Total processed so far: 2,500
#
# 📥 Fetching page 26...
#
# 📥 Fetching page 26...
# ✅ Processed 100/100 datasets from page 26
# 📈 Total processed so far: 2,600
# ✅ Processed 100/100 datasets from page 26
# 📈 Total processed so far: 2,600
#
# 📥 Fetching page 27...
#
# 📥 Fetching page 27...
# ✅ Processed 100/100 datasets from page 27
# 📈 Total processed so far: 2,700
# ✅ Processed 100/100 datasets from page 27
# 📈 Total processed so far: 2,700
#
# 📥 Fetching page 28...
#
# 📥 Fetching page 28...
# ✅ Processed 100/100 datasets from page 28
# 📈 Total processed so far: 2,800
# ✅ Processed 100/100 datasets from page 28
# 📈 Total processed so far: 2,800
#
# 📥 Fetching page 29...
#
# 📥 Fetching page 29...
# ✅ Processed 100/100 datasets from page 29
# 📈 Total processed so far: 2,900
# ✅ Processed 100/100 datasets from page 29
# 📈 Total processed so far: 2,900
#
# 📥 Fetching page 30...
#
# 📥 Fetching page 30...
# ✅ Processed 100/100 datasets from page 30
# 📈 Total processed so far: 3,000
# 💾 Saving checkpoint at page 30...
# ✅ Checkpoint saved: 3,000 records
# ✅ Processed 100/100 datasets from page 30
# 📈 Total processed so far: 3,000
# 💾 Saving checkpoint at page 30...
# ✅ Checkpoint saved: 3,000 records
#
# 📥 Fetching page 31...
#
# 📥 Fetching page 31...
# ✅ Processed 100/100 datasets from page 31
# 📈 Total processed so far: 3,100
# ✅ Processed 100/100 datasets from page 31
# 📈 Total processed so far: 3,100
#
# 📥 Fetching page 32...
#
# 📥 Fetching page 32...
# ✅ Processed 100/100 datasets from page 32
# 📈 Total processed so far: 3,200
# ✅ Processed 100/100 datasets from page 32
# 📈 Total processed so far: 3,200
#
# 📥 Fetching page 33...
#
# 📥 Fetching page 33...
# ✅ Processed 100/100 datasets from page 33
# 📈 Total processed so far: 3,300
# ✅ Processed 100/100 datasets from page 33
# 📈 Total processed so far: 3,300
#
# 📥 Fetching page 34...
#
# 📥 Fetching page 34...
# ✅ Processed 100/100 datasets from page 34
# 📈 Total processed so far: 3,400
# ✅ Processed 100/100 datasets from page 34
# 📈 Total processed so far: 3,400
#
# 📥 Fetching page 35...
#
# 📥 Fetching page 35...
# ✅ Processed 100/100 datasets from page 35
# 📈 Total processed so far: 3,500
# ✅ Processed 100/100 datasets from page 35
# 📈 Total processed so far: 3,500
#
# 📥 Fetching page 36...
#
# 📥 Fetching page 36...
# ✅ Processed 100/100 datasets from page 36
# 📈 Total processed so far: 3,600
# ✅ Processed 100/100 datasets from page 36
# 📈 Total processed so far: 3,600
#
# 📥 Fetching page 37...
#
# 📥 Fetching page 37...
# ✅ Processed 100/100 datasets from page 37
# 📈 Total processed so far: 3,700
# ✅ Processed 100/100 datasets from page 37
# 📈 Total processed so far: 3,700
#
# 📥 Fetching page 38...
#
# 📥 Fetching page 38...
# ✅ Processed 100/100 datasets from page 38
# 📈 Total processed so far: 3,800
# ✅ Processed 100/100 datasets from page 38
# 📈 Total processed so far: 3,800
#
# 📥 Fetching page 39...
#
# 📥 Fetching page 39...
# ✅ Processed 100/100 datasets from page 39
# 📈 Total processed so far: 3,900
# ✅ Processed 100/100 datasets from page 39
# 📈 Total processed so far: 3,900
#
# 📥 Fetching page 40...
#
# 📥 Fetching page 40...
# ✅ Processed 100/100 datasets from page 40
# 📈 Total processed so far: 4,000
# 💾 Saving checkpoint at page 40...
# ✅ Checkpoint saved: 4,000 records
# ✅ Processed 100/100 datasets from page 40
# 📈 Total processed so far: 4,000
# 💾 Saving checkpoint at page 40...
# ✅ Checkpoint saved: 4,000 records
#
# 📥 Fetching page 41...
#
# 📥 Fetching page 41...
# ✅ Processed 100/100 datasets from page 41
# 📈 Total processed so far: 4,100
# ✅ Processed 100/100 datasets from page 41
# 📈 Total processed so far: 4,100
#
# 📥 Fetching page 42...
#
# 📥 Fetching page 42...
# ✅ Processed 100/100 datasets from page 42
# 📈 Total processed so far: 4,200
# ✅ Processed 100/100 datasets from page 42
# 📈 Total processed so far: 4,200
#
# 📥 Fetching page 43...
#
# 📥 Fetching page 43...
# ✅ Processed 100/100 datasets from page 43
# 📈 Total processed so far: 4,300
# ✅ Processed 100/100 datasets from page 43
# 📈 Total processed so far: 4,300
#
# 📥 Fetching page 44...
#
# 📥 Fetching page 44...
# ✅ Processed 100/100 datasets from page 44
# 📈 Total processed so far: 4,400
# ✅ Processed 100/100 datasets from page 44
# 📈 Total processed so far: 4,400
#
# 📥 Fetching page 45...
#
# 📥 Fetching page 45...
# ✅ Processed 100/100 datasets from page 45
# 📈 Total processed so far: 4,500
# ✅ Processed 100/100 datasets from page 45
# 📈 Total processed so far: 4,500
#
# 📥 Fetching page 46...
#
# 📥 Fetching page 46...
# ✅ Processed 100/100 datasets from page 46
# 📈 Total processed so far: 4,600
# ✅ Processed 100/100 datasets from page 46
# 📈 Total processed so far: 4,600
#
# 📥 Fetching page 47...
#
# 📥 Fetching page 47...
# ✅ Processed 100/100 datasets from page 47
# 📈 Total processed so far: 4,700
# ✅ Processed 100/100 datasets from page 47
# 📈 Total processed so far: 4,700
#
# 📥 Fetching page 48...
#
# 📥 Fetching page 48...
# ✅ Processed 100/100 datasets from page 48
# 📈 Total processed so far: 4,800
# ✅ Processed 100/100 datasets from page 48
# 📈 Total processed so far: 4,800
#
# 📥 Fetching page 49...
#
# 📥 Fetching page 49...
# ✅ Processed 100/100 datasets from page 49
# 📈 Total processed so far: 4,900
# ✅ Processed 100/100 datasets from page 49
# 📈 Total processed so far: 4,900
#
# 📥 Fetching page 50...
#
# 📥 Fetching page 50...
# ✅ Processed 100/100 datasets from page 50
# 📈 Total processed so far: 5,000
# 💾 Saving checkpoint at page 50...
# ✅ Checkpoint saved: 5,000 records
# ✅ Processed 100/100 datasets from page 50
# 📈 Total processed so far: 5,000
# 💾 Saving checkpoint at page 50...
# ✅ Checkpoint saved: 5,000 records
#
# 📥 Fetching page 51...
#
# 📥 Fetching page 51...
# ✅ Processed 100/100 datasets from page 51
# 📈 Total processed so far: 5,100
# ✅ Processed 100/100 datasets from page 51
# 📈 Total processed so far: 5,100
#
# 📥 Fetching page 52...
#
# 📥 Fetching page 52...
# ✅ Processed 100/100 datasets from page 52
# 📈 Total processed so far: 5,200
# ✅ Processed 100/100 datasets from page 52
# 📈 Total processed so far: 5,200
#
# 📥 Fetching page 53...
#
# 📥 Fetching page 53...
# ✅ Processed 100/100 datasets from page 53
# 📈 Total processed so far: 5,300
# ✅ Processed 100/100 datasets from page 53
# 📈 Total processed so far: 5,300
#
# 📥 Fetching page 54...
#
# 📥 Fetching page 54...
# ✅ Processed 100/100 datasets from page 54
# 📈 Total processed so far: 5,400
# ✅ Processed 100/100 datasets from page 54
# 📈 Total processed so far: 5,400
#
# 📥 Fetching page 55...
#
# 📥 Fetching page 55...
# ✅ Processed 100/100 datasets from page 55
# 📈 Total processed so far: 5,500
# ✅ Processed 100/100 datasets from page 55
# 📈 Total processed so far: 5,500
#
# 📥 Fetching page 56...
#
# 📥 Fetching page 56...
# ✅ Processed 100/100 datasets from page 56
# 📈 Total processed so far: 5,600
# ✅ Processed 100/100 datasets from page 56
# 📈 Total processed so far: 5,600
#
# 📥 Fetching page 57...
#
# 📥 Fetching page 57...
# ✅ Processed 100/100 datasets from page 57
# 📈 Total processed so far: 5,700
# ✅ Processed 100/100 datasets from page 57
# 📈 Total processed so far: 5,700
#
# 📥 Fetching page 58...
#
# 📥 Fetching page 58...
# ✅ Processed 100/100 datasets from page 58
# 📈 Total processed so far: 5,800
# ✅ Processed 100/100 datasets from page 58
# 📈 Total processed so far: 5,800
#
# 📥 Fetching page 59...
#
# 📥 Fetching page 59...
# ✅ Processed 100/100 datasets from page 59
# 📈 Total processed so far: 5,900
# ✅ Processed 100/100 datasets from page 59
# 📈 Total processed so far: 5,900
#
# 📥 Fetching page 60...
#
# 📥 Fetching page 60...
# ✅ Processed 100/100 datasets from page 60
# 📈 Total processed so far: 6,000
# 💾 Saving checkpoint at page 60...
# ✅ Checkpoint saved: 6,000 records
# ✅ Processed 100/100 datasets from page 60
# 📈 Total processed so far: 6,000
# 💾 Saving checkpoint at page 60...
# ✅ Checkpoint saved: 6,000 records
#
# 📥 Fetching page 61...
#
# 📥 Fetching page 61...
# ✅ Processed 100/100 datasets from page 61
# 📈 Total processed so far: 6,100
# ✅ Processed 100/100 datasets from page 61
# 📈 Total processed so far: 6,100
#
# 📥 Fetching page 62...
#
# 📥 Fetching page 62...
# ✅ Processed 100/100 datasets from page 62
# 📈 Total processed so far: 6,200
# ✅ Processed 100/100 datasets from page 62
# 📈 Total processed so far: 6,200
#
# 📥 Fetching page 63...
#
# 📥 Fetching page 63...
# ✅ Processed 100/100 datasets from page 63
# 📈 Total processed so far: 6,300
# ✅ Processed 100/100 datasets from page 63
# 📈 Total processed so far: 6,300
#
# 📥 Fetching page 64...
#
# 📥 Fetching page 64...
# ✅ Processed 100/100 datasets from page 64
# 📈 Total processed so far: 6,400
# ✅ Processed 100/100 datasets from page 64
# 📈 Total processed so far: 6,400
#
# 📥 Fetching page 65...
#
# 📥 Fetching page 65...
# ✅ Processed 100/100 datasets from page 65
# 📈 Total processed so far: 6,500
# ✅ Processed 100/100 datasets from page 65
# 📈 Total processed so far: 6,500
#
# 📥 Fetching page 66...
#
# 📥 Fetching page 66...
# ✅ Processed 100/100 datasets from page 66
# 📈 Total processed so far: 6,600
# ✅ Processed 100/100 datasets from page 66
# 📈 Total processed so far: 6,600
# 💾 Saving checkpoint at page 80...
# ✅ Processed 100/100 datasets from page 80
# 📈 Total processed so far: 8,000
# 💾 Saving checkpoint at page 80...
# ✅ Checkpoint saved: 8,000 records
# ✅ Checkpoint saved: 8,000 records
#
# 📥 Fetching page 81...
#
# 📥 Fetching page 81...
# ✅ Processed 100/100 datasets from page 81
# 📈 Total processed so far: 8,100
# ✅ Processed 100/100 datasets from page 81
# 📈 Total processed so far: 8,100
#
# 📥 Fetching page 82...
#
# 📥 Fetching page 82...
# ✅ Processed 100/100 datasets from page 82
# 📈 Total processed so far: 8,200
# ✅ Processed 100/100 datasets from page 82
# 📈 Total processed so far: 8,200
#
# 📥 Fetching page 83...
#
# 📥 Fetching page 83...
# ✅ Processed 100/100 datasets from page 83
# 📈 Total processed so far: 8,300
# ✅ Processed 100/100 datasets from page 83
# 📈 Total processed so far: 8,300
#
# 📥 Fetching page 84...
#
# 📥 Fetching page 84...
# ✅ Processed 100/100 datasets from page 84
# 📈 Total processed so far: 8,400
# ✅ Processed 100/100 datasets from page 84
# 📈 Total processed so far: 8,400
#
# 📥 Fetching page 85...
#
# 📥 Fetching page 85...
# ✅ Processed 100/100 datasets from page 85
# 📈 Total processed so far: 8,500
# ✅ Processed 100/100 datasets from page 85
# 📈 Total processed so far: 8,500
#
# 📥 Fetching page 86...
#
# 📥 Fetching page 86...
# ✅ Processed 100/100 datasets from page 86
# 📈 Total processed so far: 8,600
# ✅ Processed 100/100 datasets from page 86
# 📈 Total processed so far: 8,600
#
# 📥 Fetching page 87...
#
# 📥 Fetching page 87...
# ✅ Processed 100/100 datasets from page 87
# 📈 Total processed so far: 8,700
# ✅ Processed 100/100 datasets from page 87
# 📈 Total processed so far: 8,700
#
# 📥 Fetching page 88...
#
# 📥 Fetching page 88...
# ✅ Processed 100/100 datasets from page 88
# 📈 Total processed so far: 8,800
# ✅ Processed 100/100 datasets from page 88
# 📈 Total processed so far: 8,800
#
# 📥 Fetching page 89...
#
# 📥 Fetching page 89...
# ✅ Processed 100/100 datasets from page 89
# 📈 Total processed so far: 8,900
# ✅ Processed 100/100 datasets from page 89
# 📈 Total processed so far: 8,900
#
# 📥 Fetching page 90...
#
# 📥 Fetching page 90...
# ✅ Processed 100/100 datasets from page 90
# 📈 Total processed so far: 9,000
# 💾 Saving checkpoint at page 90...
# ✅ Processed 100/100 datasets from page 90
# 📈 Total processed so far: 9,000
# 💾 Saving checkpoint at page 90...
# ✅ Checkpoint saved: 9,000 records
# ✅ Checkpoint saved: 9,000 records
#
# 📥 Fetching page 91...
#
# 📥 Fetching page 91...
# ✅ Processed 100/100 datasets from page 91
# 📈 Total processed so far: 9,100
# ✅ Processed 100/100 datasets from page 91
# 📈 Total processed so far: 9,100
#
# 📥 Fetching page 92...
#
# 📥 Fetching page 92...
# ✅ Processed 100/100 datasets from page 92
# 📈 Total processed so far: 9,200
# ✅ Processed 100/100 datasets from page 92
# 📈 Total processed so far: 9,200
#
# 📥 Fetching page 93...
#
# 📥 Fetching page 93...
# ✅ Processed 100/100 datasets from page 93
# 📈 Total processed so far: 9,300
# ✅ Processed 100/100 datasets from page 93
# 📈 Total processed so far: 9,300
#
# 📥 Fetching page 94...
#
# 📥 Fetching page 94...
# ✅ Processed 100/100 datasets from page 94
# 📈 Total processed so far: 9,400
# ✅ Processed 100/100 datasets from page 94
# 📈 Total processed so far: 9,400
#
# 📥 Fetching page 95...
#
# 📥 Fetching page 95...
# ✅ Processed 100/100 datasets from page 95
# 📈 Total processed so far: 9,500
# ✅ Processed 100/100 datasets from page 95
# 📈 Total processed so far: 9,500
#
# 📥 Fetching page 96...
#
# 📥 Fetching page 96...
# ✅ Processed 100/100 datasets from page 96
# 📈 Total processed so far: 9,600
# ✅ Processed 100/100 datasets from page 96
# 📈 Total processed so far: 9,600
#
# 📥 Fetching page 97...
#
# 📥 Fetching page 97...
# ✅ Processed 100/100 datasets from page 97
# 📈 Total processed so far: 9,700
# ✅ Processed 100/100 datasets from page 97
# 📈 Total processed so far: 9,700
#
# 📥 Fetching page 98...
#
# 📥 Fetching page 98...
# ✅ Processed 100/100 datasets from page 98
# 📈 Total processed so far: 9,800
# ✅ Processed 100/100 datasets from page 98
# 📈 Total processed so far: 9,800
#
# 📥 Fetching page 99...
#
# 📥 Fetching page 99...
# ✅ Processed 100/100 datasets from page 99
# 📈 Total processed so far: 9,900
# ✅ Processed 100/100 datasets from page 99
# 📈 Total processed so far: 9,900
#
# 📥 Fetching page 100...
#
# 📥 Fetching page 100...
# ✅ Processed 100/100 datasets from page 100
# 📈 Total processed so far: 10,000
# 💾 Saving checkpoint at page 100...
# ✅ Processed 100/100 datasets from page 100
# 📈 Total processed so far: 10,000
# 💾 Saving checkpoint at page 100...
# ✅ Checkpoint saved: 10,000 records
# ✅ Checkpoint saved: 10,000 records
#
# 📥 Fetching page 101...
#
# 📥 Fetching page 101...
# ✅ Processed 100/100 datasets from page 101
# 📈 Total processed so far: 10,100
# ✅ Processed 100/100 datasets from page 101
# 📈 Total processed so far: 10,100
#
# 📥 Fetching page 102...
#
# 📥 Fetching page 102...
# ✅ Processed 100/100 datasets from page 102
# 📈 Total processed so far: 10,200
# ✅ Processed 100/100 datasets from page 102
# 📈 Total processed so far: 10,200
#
# 📥 Fetching page 103...
#
# 📥 Fetching page 103...
# ✅ Processed 100/100 datasets from page 103
# 📈 Total processed so far: 10,300
# ✅ Processed 100/100 datasets from page 103
# 📈 Total processed so far: 10,300
#
# 📥 Fetching page 104...
#
# 📥 Fetching page 104...
# ✅ Processed 100/100 datasets from page 104
# 📈 Total processed so far: 10,400
# ✅ Processed 100/100 datasets from page 104
# 📈 Total processed so far: 10,400
#
# 📥 Fetching page 105...
#
# 📥 Fetching page 105...
# ✅ Processed 100/100 datasets from page 105
# 📈 Total processed so far: 10,500
# ✅ Processed 100/100 datasets from page 105
# 📈 Total processed so far: 10,500
#
# 📥 Fetching page 106...
#
# 📥 Fetching page 106...
# ✅ Processed 100/100 datasets from page 106
# 📈 Total processed so far: 10,600
# ✅ Processed 100/100 datasets from page 106
# 📈 Total processed so far: 10,600
#
# 📥 Fetching page 107...
# ✅ Processed 100/100 datasets from page 120
# 📈 Total processed so far: 12,000
# 💾 Saving checkpoint at page 120...
# ✅ Checkpoint saved: 12,000 records
# ✅ Checkpoint saved: 12,000 records
#
# 📥 Fetching page 121...
#
# 📥 Fetching page 121...
# ✅ Processed 100/100 datasets from page 121
# 📈 Total processed so far: 12,100
# ✅ Processed 100/100 datasets from page 121
# 📈 Total processed so far: 12,100
#
# 📥 Fetching page 122...
#
# 📥 Fetching page 122...
# ✅ Processed 100/100 datasets from page 122
# 📈 Total processed so far: 12,200
# ✅ Processed 100/100 datasets from page 122
# 📈 Total processed so far: 12,200
#
# 📥 Fetching page 123...
#
# 📥 Fetching page 123...
# ✅ Processed 100/100 datasets from page 123
# 📈 Total processed so far: 12,300
# ✅ Processed 100/100 datasets from page 123
# 📈 Total processed so far: 12,300
#
# 📥 Fetching page 124...
#
# 📥 Fetching page 124...
# ✅ Processed 100/100 datasets from page 124
# 📈 Total processed so far: 12,400
# ✅ Processed 100/100 datasets from page 124
# 📈 Total processed so far: 12,400
#
# 📥 Fetching page 125...
#
# 📥 Fetching page 125...
# ✅ Processed 100/100 datasets from page 125
# 📈 Total processed so far: 12,500
# ✅ Processed 100/100 datasets from page 125
# 📈 Total processed so far: 12,500
#
# 📥 Fetching page 126...
#
# 📥 Fetching page 126...
# ✅ Processed 100/100 datasets from page 126
# 📈 Total processed so far: 12,600
# ✅ Processed 100/100 datasets from page 126
# 📈 Total processed so far: 12,600
#
# 📥 Fetching page 127...
#
# 📥 Fetching page 127...
# ✅ Processed 100/100 datasets from page 127
# 📈 Total processed so far: 12,700
# ✅ Processed 100/100 datasets from page 127
# 📈 Total processed so far: 12,700
#
# 📥 Fetching page 128...
#
# 📥 Fetching page 128...
# ✅ Processed 100/100 datasets from page 128
# 📈 Total processed so far: 12,800
# ✅ Processed 100/100 datasets from page 128
# 📈 Total processed so far: 12,800
#
# 📥 Fetching page 129...
#
# 📥 Fetching page 129...
# ✅ Processed 100/100 datasets from page 129
# 📈 Total processed so far: 12,900
# ✅ Processed 100/100 datasets from page 129
# 📈 Total processed so far: 12,900
#
# 📥 Fetching page 130...
#
# 📥 Fetching page 130...
# ✅ Processed 100/100 datasets from page 130
# 📈 Total processed so far: 13,000
# 💾 Saving checkpoint at page 130...
# ✅ Processed 100/100 datasets from page 130
# 📈 Total processed so far: 13,000
# 💾 Saving checkpoint at page 130...
# ✅ Checkpoint saved: 13,000 records
# ✅ Checkpoint saved: 13,000 records
#
# 📥 Fetching page 131...
#
# 📥 Fetching page 131...
# ✅ Processed 100/100 datasets from page 131
# 📈 Total processed so far: 13,100
# ✅ Processed 100/100 datasets from page 131
# 📈 Total processed so far: 13,100
#
# 📥 Fetching page 132...
#
# 📥 Fetching page 132...
# ✅ Processed 100/100 datasets from page 132
# 📈 Total processed so far: 13,200
# ✅ Processed 100/100 datasets from page 132
# 📈 Total processed so far: 13,200
#
# 📥 Fetching page 133...
#
# 📥 Fetching page 133...
# ✅ Processed 100/100 datasets from page 133
# 📈 Total processed so far: 13,300
# 💾 Saving checkpoint at page 200...
# ✅ Checkpoint saved: 20,000 records
# ✅ Checkpoint saved: 20,000 records
#
# 📥 Fetching page 201...
#
# 📥 Fetching page 201...
# ✅ Processed 100/100 datasets from page 201
# 📈 Total processed so far: 20,100
# ✅ Processed 100/100 datasets from page 201
# 📈 Total processed so far: 20,100
#
# 📥 Fetching page 202...
#
# 📥 Fetching page 202...
# ✅ Processed 100/100 datasets from page 202
# 📈 Total processed so far: 20,200
# ✅ Processed 100/100 datasets from page 202
# 📈 Total processed so far: 20,200
#
# 📥 Fetching page 203...
#
# 📥 Fetching page 203...
# ✅ Processed 100/100 datasets from page 203
# 📈 Total processed so far: 20,300
# ✅ Processed 100/100 datasets from page 203
# 📈 Total processed so far: 20,300
#
# 📥 Fetching page 204...
#
# 📥 Fetching page 204...
# ✅ Processed 100/100 datasets from page 204
# 📈 Total processed so far: 20,400
# ✅ Processed 100/100 datasets from page 204
# 📈 Total processed so far: 20,400
#
# 📥 Fetching page 205...
#
# 📥 Fetching page 205...
# ✅ Processed 100/100 datasets from page 205
# 📈 Total processed so far: 20,500
# ✅ Processed 100/100 datasets from page 205
# 📈 Total processed so far: 20,500
#
# 📥 Fetching page 206...
#
# 📥 Fetching page 206...
# ✅ Processed 100/100 datasets from page 206
# 📈 Total processed so far: 20,600
# ✅ Processed 100/100 datasets from page 206
# 📈 Total processed so far: 20,600
#
# 📥 Fetching page 207...
#
# 📥 Fetching page 207...
# ✅ Processed 100/100 datasets from page 207
# 📈 Total processed so far: 20,700
# ✅ Processed 100/100 datasets from page 207
# 📈 Total processed so far: 20,700
#
# 📥 Fetching page 208...
#
# 📥 Fetching page 208...
# ✅ Processed 100/100 datasets from page 208
# 📈 Total processed so far: 20,800
# ✅ Processed 100/100 datasets from page 208
# 📈 Total processed so far: 20,800
#
# 📥 Fetching page 209...
#
# 📥 Fetching page 209...
# ✅ Processed 100/100 datasets from page 209
# 📈 Total processed so far: 20,900
# ✅ Processed 100/100 datasets from page 209
# 📈 Total processed so far: 20,900
#
# 📥 Fetching page 210...
#
# 📥 Fetching page 210...
# ✅ Processed 100/100 datasets from page 210
# 📈 Total processed so far: 21,000
# 💾 Saving checkpoint at page 210...
# ✅ Processed 100/100 datasets from page 210
# 📈 Total processed so far: 21,000
# 💾 Saving checkpoint at page 210...
# ✅ Checkpoint saved: 21,000 records
# ✅ Checkpoint saved: 21,000 records
#
# 📥 Fetching page 211...
#
# 📥 Fetching page 211...
# ✅ Processed 100/100 datasets from page 211
# 📈 Total processed so far: 21,100
# ✅ Processed 100/100 datasets from page 211
# 📈 Total processed so far: 21,100
#
# 📥 Fetching page 212...
#
# 📥 Fetching page 212...
# ✅ Processed 100/100 datasets from page 212
# 📈 Total processed so far: 21,200
# ✅ Processed 100/100 datasets from page 212
# 📈 Total processed so far: 21,200
#
# 📥 Fetching page 213...
#
# 📥 Fetching page 213...
# ✅ Processed 100/100 datasets from page 213
# 📈 Total processed so far: 21,300
# ✅ Processed 100/100 datasets from page 213
# 📈 Total processed so far: 21,300
#
# 📈 Total processed so far: 63,700
# ✅ Processed 100/100 datasets from page 637
# 📈 Total processed so far: 63,700
#
# 📥 Fetching page 638...
#
# 📥 Fetching page 638...
# ✅ Processed 100/100 datasets from page 638
# 📈 Total processed so far: 63,800
# ✅ Processed 100/100 datasets from page 638
# 📈 Total processed so far: 63,800
#
# 📥 Fetching page 639...
#
# 📥 Fetching page 639...
# ✅ Processed 100/100 datasets from page 639
# 📈 Total processed so far: 63,900
# ✅ Processed 100/100 datasets from page 639
# 📈 Total processed so far: 63,900
#
# 📥 Fetching page 640...
#
# 📥 Fetching page 640...
# ✅ Processed 100/100 datasets from page 640
# 📈 Total processed so far: 64,000
# 💾 Saving checkpoint at page 640...
# ✅ Processed 100/100 datasets from page 640
# 📈 Total processed so far: 64,000
# 💾 Saving checkpoint at page 640...
# ✅ Checkpoint saved: 64,000 records
# ✅ Checkpoint saved: 64,000 records
#
# 📥 Fetching page 641...
#
# 📥 Fetching page 641...
# ✅ Processed 100/100 datasets from page 641
# 📈 Total processed so far: 64,100
# ✅ Processed 100/100 datasets from page 641
# 📈 Total processed so far: 64,100
#
# 📥 Fetching page 642...
#
# 📥 Fetching page 642...
# ✅ Processed 100/100 datasets from page 642
# 📈 Total processed so far: 64,200
# ✅ Processed 100/100 datasets from page 642
# 📈 Total processed so far: 64,200
#
# 📥 Fetching page 643...
#
# 📥 Fetching page 643...
# ✅ Processed 100/100 datasets from page 643
# 📈 Total processed so far: 64,300
# ✅ Processed 100/100 datasets from page 643
# 📈 Total processed so far: 64,300
#
# 📥 Fetching page 644...
#
# 📥 Fetching page 644...
# ✅ Processed 100/100 datasets from page 644
# 📈 Total processed so far: 64,400
# ✅ Processed 100/100 datasets from page 644
# 📈 Total processed so far: 64,400
#
# 📥 Fetching page 645...
#
# 📥 Fetching page 645...
# ✅ Processed 100/100 datasets from page 645
# 📈 Total processed so far: 64,500
# ✅ Processed 100/100 datasets from page 645
# 📈 Total processed so far: 64,500
#
# 📥 Fetching page 646...
#
# 📥 Fetching page 646...
# ✅ Processed 100/100 datasets from page 646
# 📈 Total processed so far: 64,600
# ✅ Processed 100/100 datasets from page 646
# 📈 Total processed so far: 64,600
#
# 📥 Fetching page 647...
#
# 📥 Fetching page 647...
# ✅ Processed 100/100 datasets from page 647
# 📈 Total processed so far: 64,700
# ✅ Processed 100/100 datasets from page 647
# 📈 Total processed so far: 64,700
#
# 📥 Fetching page 648...
#
# 📥 Fetching page 648...
# ✅ Processed 100/100 datasets from page 648
# 📈 Total processed so far: 64,800
# ✅ Processed 100/100 datasets from page 648
# 📈 Total processed so far: 64,800
#
# 📥 Fetching page 649...
#
# 📥 Fetching page 649...
# ✅ Processed 100/100 datasets from page 649
# 📈 Total processed so far: 64,900
# ✅ Processed 100/100 datasets from page 649
# 📈 Total processed so far: 64,900
#
# 📥 Fetching page 650...
#
# 📥 Fetching page 650...
# ✅ Processed 100/100 datasets from page 650
# 📈 Total processed so far: 65,000
# 💾 Saving checkpoint at page 650...
# ✅ Processed 100/100 datasets from page 650
# 📈 Total processed so far: 65,000
# 💾 Saving checkpoint at page 650...
# ✅ Checkpoint saved: 65,000 records
# ✅ Checkpoint saved: 65,000 records
#
# 📥 Fetching page 651...
#
# 📥 Fetching page 651...
# ✅ Processed 100/100 datasets from page 651
# 📈 Total processed so far: 65,100
# ✅ Processed 100/100 datasets from page 651
# 📈 Total processed so far: 65,100
#
# 📥 Fetching page 652...
#
# 📥 Fetching page 652...
# ✅ Processed 100/100 datasets from page 652
# 📈 Total processed so far: 65,200
# ✅ Processed 100/100 datasets from page 652
# 📈 Total processed so far: 65,200
#
# 📥 Fetching page 653...
#
# 📥 Fetching page 653...
# ✅ Processed 100/100 datasets from page 653
# 📈 Total processed so far: 65,300
# ✅ Processed 100/100 datasets from page 653
# 📈 Total processed so far: 65,300
#
# 📥 Fetching page 654...
#
# 📥 Fetching page 654...
# ✅ Processed 100/100 datasets from page 654
# 📈 Total processed so far: 65,400
# ✅ Processed 100/100 datasets from page 654
# 📈 Total processed so far: 65,400
#
# 📥 Fetching page 655...
#
# 📥 Fetching page 655...
# ✅ Processed 100/100 datasets from page 655
# 📈 Total processed so far: 65,500
# ✅ Processed 100/100 datasets from page 655
# 📈 Total processed so far: 65,500
#
# 📥 Fetching page 656...
#
# 📥 Fetching page 656...
# ✅ Processed 100/100 datasets from page 656
# 📈 Total processed so far: 65,600
# ✅ Processed 100/100 datasets from page 656
# 📈 Total processed so far: 65,600
#
# 📥 Fetching page 657...
#
# 📥 Fetching page 657...
# ✅ Processed 100/100 datasets from page 657
# 📈 Total processed so far: 65,700
# ✅ Processed 100/100 datasets from page 657
# 📈 Total processed so far: 65,700
#
# 📥 Fetching page 658...
#
# 📥 Fetching page 658...
# ✅ Processed 100/100 datasets from page 658
# 📈 Total processed so far: 65,800
# ✅ Processed 100/100 datasets from page 658
# 📈 Total processed so far: 65,800
#
# 📥 Fetching page 659...
#
# 📥 Fetching page 659...
# ✅ Processed 100/100 datasets from page 659
# 📈 Total processed so far: 65,900
# ✅ Processed 100/100 datasets from page 659
# 📈 Total processed so far: 65,900
#
# 📥 Fetching page 660...
#
# 📥 Fetching page 660...
# ✅ Processed 100/100 datasets from page 660
# 📈 Total processed so far: 66,000
# 💾 Saving checkpoint at page 660...
# ✅ Processed 100/100 datasets from page 660
# 📈 Total processed so far: 66,000
# 💾 Saving checkpoint at page 660...
# ✅ Checkpoint saved: 66,000 records
# ✅ Checkpoint saved: 66,000 records
#
# 📥 Fetching page 661...
#
# 📥 Fetching page 661...
# ✅ Processed 100/100 datasets from page 661
# 📈 Total processed so far: 66,100
# ✅ Processed 100/100 datasets from page 661
# 📈 Total processed so far: 66,100
#
# 📥 Fetching page 662...
#
# 📥 Fetching page 662...
# ✅ Processed 100/100 datasets from page 662
# 📈 Total processed so far: 66,200
# ✅ Processed 100/100 datasets from page 662
# 📈 Total processed so far: 66,200
#
# 📥 Fetching page 663...
#
# 📥 Fetching page 663...
# ✅ Processed 100/100 datasets from page 663
# 📈 Total processed so far: 66,300
# ✅ Processed 100/100 datasets from page 663
# 📈 Total processed so far: 66,300
#
# 📥 Fetching page 664...
#
# 📥 Fetching page 664...
# ✅ Processed 100/100 datasets from page 664
# 📈 Total processed so far: 66,400
# ✅ Processed 100/100 datasets from page 664
# 📈 Total processed so far: 66,400
#
# 📥 Fetching page 665...
#
# 📥 Fetching page 665...
# ✅ Processed 100/100 datasets from page 665
# 📈 Total processed so far: 66,500
# ✅ Processed 100/100 datasets from page 665
# 📈 Total processed so far: 66,500
#
# 📥 Fetching page 666...
#
# 📥 Fetching page 666...
# ✅ Processed 100/100 datasets from page 666
# 📈 Total processed so far: 66,600
# ✅ Processed 100/100 datasets from page 666
# 📈 Total processed so far: 66,600
#
# 📥 Fetching page 667...
#
# 📥 Fetching page 667...
# ✅ Processed 100/100 datasets from page 667
# 📈 Total processed so far: 66,700
# ✅ Processed 100/100 datasets from page 667
# 📈 Total processed so far: 66,700
#
# 📥 Fetching page 668...
#
# 📥 Fetching page 668...
# ✅ Processed 30/30 datasets from page 668
# 📈 Total processed so far: 66,730
# ✅ Processed 30/30 datasets from page 668
# 📈 Total processed so far: 66,730
#
# 📥 Fetching page 669...
#
# 📥 Fetching page 669...
# ✅ No more datasets found on page 669. Download complete!
#
# 🎯 Download Summary:
#    Total datasets processed: 66,730
#    Pages fetched: 669
# 🔧 Creating final DataFrame...
# ✅ No more datasets found on page 669. Download complete!
#
# 🎯 Download Summary:
#    Total datasets processed: 66,730
#    Pages fetched: 669
# 🔧 Creating final DataFrame...
#    DataFrame shape: (66730, 48)
#    Columns extracted: 48
# 🧹 Cleaned up checkpoint files
#
# 🔍 Quick preview of downloaded data:
# Columns: ['id', 'identifier', 'title', 'abstract', 'storage_size', 'related_publication_issn', 'usageNotes', 'publication_date', 'last_modification_date', 'version_number']...
#
# 📋 Sample records:
# shape: (3, 5)
# ┌─────┬────────────────────────┬────────────────────────┬──────────────────┬───────────────────────┐
# │ id  ┆ title                  ┆ authors                ┆ publication_date ┆ keywords              │
# │ --- ┆ ---                    ┆ ---                    ┆ ---              ┆ ---                   │
# │ i64 ┆ str                    ┆ str                    ┆ str              ┆ str                   │
# ╞═════╪════════════════════════╪════════════════════════╪══════════════════╪═══════════════════════╡
# │ 93  ┆ Distinct predatory     ┆ Borja Figueirido;      ┆ 2021-06-15       ┆ cranial biomechanics; │
# │     ┆ behaviors i…           ┆ Stephan Laut…          ┆                  ┆ Paleobio…             │
# │ 94  ┆ Data from:             ┆ Michael G.             ┆ 2018-04-03       ┆ Next-generation       │
# │     ┆ Phylogenomic insigh…   ┆ Branstetter; Bryan …   ┆                  ┆ sequencing; so…       │
# │ 95  ┆ Data from: Complex     ┆ Alejandro Berrio;      ┆ 2017-11-07       ┆ Gene regulation;      │
# │     ┆ selection o…           ┆ Rafael F. Gu…          ┆                  ┆ Sexual Fideli…        │
# └─────┴────────────────────────┴────────────────────────┴──────────────────┴───────────────────────┘
#
# 📊 Quick statistics:
#    Total records: 66730
#    Non-null titles: 66730
#    Non-null abstracts: 66718
#    Non-null authors: 66730
#    DataFrame shape: (66730, 48)
#    Columns extracted: 48
# 🧹 Cleaned up checkpoint files
#
# 🔍 Quick preview of downloaded data:
# Columns: ['id', 'identifier', 'title', 'abstract', 'storage_size', 'related_publication_issn', 'usageNotes', 'publication_date', 'last_modification_date', 'version_number']...
#
# 📋 Sample records:
# shape: (3, 5)
# ┌─────┬────────────────────────┬────────────────────────┬──────────────────┬───────────────────────┐
# │ id  ┆ title                  ┆ authors                ┆ publication_date ┆ keywords              │
# │ --- ┆ ---                    ┆ ---                    ┆ ---              ┆ ---                   │
# │ i64 ┆ str                    ┆ str                    ┆ str              ┆ str                   │
# ╞═════╪════════════════════════╪════════════════════════╪══════════════════╪═══════════════════════╡
# │ 93  ┆ Distinct predatory     ┆ Borja Figueirido;      ┆ 2021-06-15       ┆ cranial biomechanics; │
# │     ┆ behaviors i…           ┆ Stephan Laut…          ┆                  ┆ Paleobio…             │
# │ 94  ┆ Data from:             ┆ Michael G.             ┆ 2018-04-03       ┆ Next-generation       │
# │     ┆ Phylogenomic insigh…   ┆ Branstetter; Bryan …   ┆                  ┆ sequencing; so…       │
# │ 95  ┆ Data from: Complex     ┆ Alejandro Berrio;      ┆ 2017-11-07       ┆ Gene regulation;      │
# │     ┆ selection o…           ┆ Rafael F. Gu…          ┆                  ┆ Sexual Fideli…        │
# └─────┴────────────────────────┴────────────────────────┴──────────────────┴───────────────────────┘
#
# 📊 Quick statistics:
#    Total records: 66730
#    Non-null titles: 66730
#    Non-null abstracts: 66718
#    Non-null authors: 66730

# %% [markdown]
# ## Save to Parquet File
#
# Save the downloaded datasets to a parquet file for efficient storage and future use:

# %%
# Save datasets to parquet file
if not dryad_df.is_empty():
    output_path = Path(OUTPUT_FILE)
    output_path.parent.mkdir(parents=True, exist_ok=True)  # Ensure directory exists
    
    print(f"\n💾 Saving {len(dryad_df):,} datasets to parquet...")
    print(f"   Output path: {output_path.absolute()}")
    
    # Save with compression for optimal storage
    dryad_df.write_parquet(OUTPUT_FILE, compression="snappy")
    
    # Verify and report
    if output_path.exists():
        file_size = output_path.stat().st_size
        print(f"✅ Successfully saved!")
        print(f"   File size: {file_size / (1024*1024):.2f} MB")
        print(f"   Records: {len(dryad_df):,}")
        print(f"   Columns: {len(dryad_df.columns)}")
    else:
        print("❌ Failed to save file")
else:
    print("❌ No data available to save")
# Out:
# 💾 Saving 66,730 datasets to parquet...
#    Output path: /Users/pietro/Desktop/VIDA-NYU/data-gatherer/scripts/output/gold/dryad_datasets.parquet
# ✅ Successfully saved!
#    File size: 122.96 MB
#    Records: 66,730
#    Columns: 48
# ✅ Successfully saved!
#    File size: 122.96 MB
#    Records: 66,730
#    Columns: 48

# %% [markdown]
# ## Data Analysis
#
# Let's do some basic analysis of the downloaded datasets:

# %%
# Comprehensive analysis of the Dryad datasets
if not dryad_df.is_empty():
    print("🔬 DRYAD DATASETS ANALYSIS")
    print("=" * 50)
    print(f"📊 Dataset Overview:")
    print(f"   Total datasets: {len(dryad_df):,}")
    print(f"   Total columns: {len(dryad_df.columns)}")
    
    # Status distributions
    if 'curation_status' in dryad_df.columns:
        print(f"\n📋 Curation Status Distribution:")
        status_counts = dryad_df.group_by("curation_status").agg(pl.count().alias("count")).sort("count", descending=True)
        for row in status_counts.iter_rows():
            print(f"   {row[0]}: {row[1]:,}")
    
    # Publication trends
    if 'publication_date' in dryad_df.columns:
        print(f"\n📅 Recent Publication Years (Top 10):")
        yearly_stats = (dryad_df
                       .with_columns(
                           pl.col("publication_date").str.slice(0, 4).cast(pl.Int32, strict=False).alias("year")
                       )
                       .filter(pl.col("year").is_not_null())
                       .group_by("year")
                       .agg(pl.count().alias("count"))
                       .sort("year", descending=True)
                       .head(10))
        for row in yearly_stats.iter_rows():
            print(f"   {row[0]}: {row[1]:,} datasets")
    
    # Storage insights
    if 'storage_size' in dryad_df.columns:
        print(f"\n💽 Storage Statistics:")
        size_stats = dryad_df.select([
            (pl.col("storage_size").sum() / (1024**3)).alias("total_gb"),
            (pl.col("storage_size").mean() / (1024**2)).alias("avg_mb"),
            (pl.col("storage_size").median() / (1024**2)).alias("median_mb"),
            pl.col("storage_size").count().alias("datasets_with_size")
        ]).row(0)
        
        print(f"   Total storage: {size_stats[0]:.2f} GB")
        print(f"   Average size: {size_stats[1]:.2f} MB")
        print(f"   Median size: {size_stats[2]:.2f} MB")
        print(f"   Datasets with size info: {size_stats[3]:,}")
    
    # Top institutions
    if 'author_affiliations' in dryad_df.columns:
        print(f"\n🏛️  Top 10 Author Affiliations:")
        affiliations = (dryad_df
                       .filter(pl.col("author_affiliations").is_not_null())
                       .select(pl.col("author_affiliations").str.split(";").alias("affiliation_list"))
                       .explode("affiliation_list")
                       .with_columns(pl.col("affiliation_list").str.strip_chars().alias("affiliation"))
                       .group_by("affiliation")
                       .agg(pl.count().alias("count"))
                       .sort("count", descending=True)
                       .head(10))
        
        for row in affiliations.iter_rows():
            print(f"   {row[0]}: {row[1]:,}")
    
    # Popular keywords
    if 'keywords' in dryad_df.columns:
        print(f"\n🏷️  Top 10 Keywords:")
        keywords = (dryad_df
                   .filter(pl.col("keywords").is_not_null())
                   .select(pl.col("keywords").str.split(";").alias("keyword_list"))
                   .explode("keyword_list")
                   .with_columns(pl.col("keyword_list").str.strip_chars().alias("keyword"))
                   .group_by("keyword")
                   .agg(pl.count().alias("count"))
                   .sort("count", descending=True)
                   .head(10))
        
        for row in keywords.iter_rows():
            print(f"   {row[0]}: {row[1]:,}")
    
    # License distribution
    if 'license' in dryad_df.columns:
        print(f"\n⚖️  License Distribution:")
        licenses = dryad_df.group_by("license").agg(pl.count().alias("count")).sort("count", descending=True)
        for row in licenses.iter_rows():
            print(f"   {row[0]}: {row[1]:,}")
    
    print(f"\n✅ Analysis complete!")
        
else:
    print("❌ No data available for analysis")
# Out:
# 🔬 DRYAD DATASETS ANALYSIS
# ==================================================
# 📊 Dataset Overview:
#    Total datasets: 66,730
#    Total columns: 48
#
# 📋 Curation Status Distribution:
#    Published: 66,725
#    Embargoed: 4
#    Action required: 1
#
# 📅 Recent Publication Years (Top 10):
#    2999: 1 datasets
#    2027: 1 datasets
#    2026: 1 datasets
#    2025: 4,702 datasets
#    2024: 6,002 datasets
#    2023: 5,656 datasets
#    2022: 6,852 datasets
#    2021: 7,064 datasets
#    2020: 6,185 datasets
#    2019: 6,710 datasets
#
# 💽 Storage Statistics:
#    Total storage: 164800.89 GB
#    Average size: 2529.55 MB
#    Median size: 0.45 MB
#    Datasets with size info: 66,714
#
# 🏛️  Top 10 Author Affiliations:
#    University of California, Davis: 1,286
#    University of California, Berkeley: 1,061
#    University of British Columbia: 887
#    University of Oxford: 886
#    Cornell University: 877
#    Centre National de la Recherche Scientifique: 864
#    University of Florida: 836
#    Chinese Academy of Sciences: 800
#    University of Washington: 792
#    Michigan State University: 719
#
# 🏷️  Top 10 Keywords:
#    Holocene: 2,415
#    Climate change: 788
#    Ecology: 486
#    Anthropocene: 373
#    Biodiversity: 342
#    Coevolution: 335
#    Life History Evolution: 281
#    trade-offs: 259
#    Inbreeding: 254
#    Mate choice: 251
#
# ⚖️  License Distribution:
#    https://spdx.org/licenses/CC0-1.0.html: 66,730
#
# ✅ Analysis complete!
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_49116/2975163870.py:12: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   status_counts = dryad_df.group_by("curation_status").agg(pl.count().alias("count")).sort("count", descending=True)
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_49116/2975163870.py:25: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("count"))
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_49116/2975163870.py:55: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("count"))
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_49116/2975163870.py:71: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("count"))
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_49116/2975163870.py:81: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   licenses = dryad_df.group_by("license").agg(pl.count().alias("count")).sort("count", descending=True)

# %%
dryad_df.columns
# Out:
# ['id',
#  'identifier',
#  'title',
#  'abstract',
#  'storage_size',
#  'related_publication_issn',
#  'usageNotes',
#  'publication_date',
#  'last_modification_date',
#  'version_number',
#  'version_status',
#  'curation_status',
#  'version_changes',
#  'visibility',
#  'sharing_link',
#  'license',
#  'self_link',
#  'download_link',
#  'files_link',
#  'versions_link',
#  'all_links',
#  'authors',
#  'author_emails',
#  'author_affiliations',
#  'author_ror_ids',
#  'author_count',
#  'authors_full',
#  'keywords',
#  'keyword_count',
#  'locations',
#  'location_places',
#  'location_coordinates',
#  'location_count',
#  'locations_full',
#  'funders',
#  'funder_names',
#  'funder_awards',
#  'funder_count',
#  'funders_full',
#  'related_works',
#  'relation_types',
#  'related_identifiers',
#  'related_works_count',
#  'related_works_full',
#  'downloads',
#  'views',
#  'metric_citations',
#  'metrics_full']

# %%
dryad_df[['id', 'title', 'abstract', 'related_publication_issn', 'usageNotes']].head(10)
# Out:
# shape: (10, 5)
# ┌─────┬───────────────────────┬──────────────────────┬──────────────────────┬──────────────────────┐
# │ id  ┆ title                 ┆ abstract             ┆ related_publication_ ┆ usageNotes           │
# │ --- ┆ ---                   ┆ ---                  ┆ issn                 ┆ ---                  │
# │ i64 ┆ str                   ┆ str                  ┆ ---                  ┆ str                  │
# │     ┆                       ┆                      ┆ str                  ┆                      │
# ╞═════╪═══════════════════════╪══════════════════════╪══════════════════════╪══════════════════════╡
# │ 93  ┆ Distinct predatory    ┆ <p>Over the          ┆ 0960-9822            ┆ null                 │
# │     ┆ behaviors i…          ┆ Cenozoic, large ca…  ┆                      ┆                      │
# │ 94  ┆ Data from:            ┆ The stinging wasps   ┆ 0960-9822            ┆ <div class="o-metada │
# │     ┆ Phylogenomic insigh…  ┆ (Hymenopter…         ┆                      ┆ ta__file-u…          │
# │ 95  ┆ Data from: Complex    ┆ Adaptive variation   ┆ 0962-1083            ┆ <div class="o-metada │
# │     ┆ selection o…          ┆ in social b…         ┆                      ┆ ta__file-u…          │
# │ 96  ┆ Data from: The        ┆ Understanding the    ┆ 0003-0147            ┆ <div class="o-metada │
# │     ┆ evolution of ma…      ┆ causes of la…        ┆                      ┆ ta__file-u…          │
# │ 97  ┆ Data from: Gene       ┆ [No abstract filled] ┆ 1439-4227            ┆ <div class="o-metada │
# │     ┆ discovery in G…       ┆                      ┆                      ┆ ta__file-u…          │
# │ 98  ┆ Data from:            ┆ To advance           ┆ 1755-0998            ┆ <div class="o-metada │
# │     ┆ "Comparative genomi…  ┆ comparative genomic… ┆                      ┆ ta__file-u…          │
# │ 99  ┆ Data from:            ┆ Aim: Climate warming ┆ 1365-2699            ┆ <div class="o-metada │
# │     ┆ Demographic modelli…  ┆ is causin…           ┆                      ┆ ta__file-u…          │
# │ 100 ┆ Data from: A          ┆ Background: Teak, a  ┆ 2047-217X            ┆ <div class="o-metada │
# │     ┆ chromosomal-scale…    ┆ member of …          ┆                      ┆ ta__file-u…          │
# │ 101 ┆ Data from: The        ┆ Several parameters   ┆ 2054-5703            ┆ <div class="o-metada │
# │     ┆ chinchilla as a…      ┆ are importa…         ┆                      ┆ ta__file-u…          │
# │ 102 ┆ Data from: Community  ┆ Groups of            ┆ 1558-5646            ┆ <div class="o-metada │
# │     ┆ trees: id…            ┆ codistributed        ┆                      ┆ ta__file-u…          │
# │     ┆                       ┆ specie…              ┆                      ┆                      │
# └─────┴───────────────────────┴──────────────────────┴──────────────────────┴──────────────────────┘

# %% [markdown]
# ## Load Previously Downloaded Data
#
# For future analysis, you can load the saved parquet file:

# %%
# Load previously saved data
# loaded_df = pl.read_parquet(OUTPUT_FILE)
# print(f"📂 Loaded {len(loaded_df):,} datasets from {OUTPUT_FILE}")
# print(f"🔍 Preview:\n{loaded_df.head()}")

print("💡 Uncomment the lines above to load previously saved data")
# Out:
# 💡 Uncomment the lines above to load previously saved data
