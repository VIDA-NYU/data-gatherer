# %%
import os
from data_gatherer.data_gatherer import DataGatherer
import pandas as pd

# %%
df = pd.read_csv("exp_input/SAGE_groundtruth.csv")
input_file = "exp_input/SAGE_input.txt"

# %%
model_name = "gpt-4o-mini"  # "gemini-2.0-flash" or "gpt-4o-mini"
prompt = "GPT_FDR_FewShot_Syn"  # "GPT_from_full_input_Examples" or "retrieve_datasets_simple_JSON"
FDR = True
semantic_retrieval = False
section_filter= None

# %%
# write list to a text file
with open(input_file, 'r') as f:
    pmcids = f.read().splitlines()

print("Number of PMCIDs:", len(pmcids))
# Out:
# Number of PMCIDs: 100

# %%
dg = DataGatherer(llm_name=model_name, log_level='INFO', process_entire_document=FDR) #, driver_path='../../Firefox/geckodriver', save_dynamic_prompts=True
# Out:
# data_gatherer.py - line 266 - INFO - Setting up data fetcher...
# data_fetcher.py - line 24 - WARNING - DataFetcher raw_HTML_data_filepath set no None
# data_gatherer.py - line 296 - INFO - Data fetcher setup completed.
# data_gatherer.py - line 107 - INFO - DataGatherer orchestrator initialized. Extraction Model: gpt-4o-mini

# %%
# These are the problematic urls for information extraction for GEMINI
#urls = ["https://pmc.ncbi.nlm.nih.gov/articles/PMC9314356", "https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527/", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11929800/", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11032436/", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10802452/", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8565335/","https://pmc.ncbi.nlm.nih.gov/articles/PMC7778917/"]
# v1 = "https://pmc.ncbi.nlm.nih.gov/articles/PMC7029360/"
# v2 = "https://pmc.ncbi.nlm.nih.gov/articles/PMC8006362"
#urls = ["https://pmc.ncbi.nlm.nih.gov/articles/PMC9710693/"]

# These are the problematic urls for information extraction for GPT - (2025 Aug 29) GPT gets stuck for some reason after 50 calls or so...
#urls = ["https://pmc.ncbi.nlm.nih.gov/articles/PMC11240079", "https://pmc.ncbi.nlm.nih.gov/articles/PMC5752539","https://pmc.ncbi.nlm.nih.gov/articles/PMC7032692", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10547713", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8102856", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8055881", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8226229", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10769298", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11659981", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8082263", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8565335", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9094742", "https://pmc.ncbi.nlm.nih.gov/articles/PMC7029360", "https://pmc.ncbi.nlm.nih.gov/articles/PMC6289083", "https://pmc.ncbi.nlm.nih.gov/articles/PMC7658217", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9780309","https://pmc.ncbi.nlm.nih.gov/articles/PMC3788619", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8859891", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10680627", "https://pmc.ncbi.nlm.nih.gov/articles/PMC6323985", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8131595", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11420198", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9915613", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10238095", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10802452" , "https://pmc.ncbi.nlm.nih.gov/articles/PMC11032436", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10329279", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10836119",  "https://pmc.ncbi.nlm.nih.gov/articles/PMC9280291", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11661334", "https://pmc.ncbi.nlm.nih.gov/articles/PMC5161470", "https://pmc.ncbi.nlm.nih.gov/articles/PMC4339277"]

#out = dg.process_articles(urls, semantic_retrieval=semantic_retrieval, section_filter=section_filter, prompt_name=prompt)

#out
#out['https://pmc.ncbi.nlm.nih.gov/articles/PMC9710693']

# %%
input_file = "exp_input/SAGE_input.txt"
combined_df = dg.run(input_file=input_file, semantic_retrieval=semantic_retrieval, section_filter=section_filter, prompt_name=prompt)
# Out:
# data_gatherer.py - line 639 - INFO - Loaded 100 URLs from file.
# data_gatherer.py - line 554 - INFO - 0th function call: self.process_url(https://pmc.ncbi.nlm.nih.gov/articles/PMC11792374)
# data_gatherer.py - line 358 - INFO - Processing URL: https://pmc.ncbi.nlm.nih.gov/articles/PMC11792374
# data_fetcher.py - line 166 - INFO - raw_HTML_data_filepath: None
# data_fetcher.py - line 173 - INFO - Initializing EntrezFetcher(('requests', 'self.config'))
# data_fetcher.py - line 24 - WARNING - DataFetcher raw_HTML_data_filepath set no None
# data_gatherer.py - line 365 - INFO - Type of data_fetcher EntrezFetcher
# data_fetcher.py - line 534 - INFO - Fetching data from request: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=PMC11792374&retmode=xml
# xml_retriever.py - line 446 - INFO - ----Checking for data_availability_sections section in raw data.
# xml_retriever.py - line 457 - INFO - ----Found section: <notes xmlns:mml="http://www.w3.org/1998/Math/MathML" xmlns:ali="http://www.niso.org/schemas/ali/1.0...
# xml_retriever.py - line 461 - WARNING - No links found in the section.
# xml_retriever.py - line 446 - INFO - ----Checking for supplementary_data_sections section in raw data.
# xml_retriever.py - line 457 - INFO - ----Found section: <sec xmlns:mml="http://www.w3.org/1998/Math/MathML" xmlns:ali="http://www.niso.org/schemas/ali/1.0/"...
# xml_retriever.py - line 62 - INFO - XML data contains all required sections.
# data_gatherer.py - line 406 - INFO - XML data is complete for https://pmc.ncbi.nlm.nih.gov/articles/PMC11792374.
# data_gatherer.py - line 410 - INFO - Raw XML data fetched from https://pmc.ncbi.nlm.nih.gov/articles/PMC11792374 is ready for parsing.
# data_gatherer.py - line 424 - INFO - Skipping raw HTML/XML saving.
# data_gatherer.py - line 430 - INFO - Using XMLParser to parse data.
# base_parser.py - line 177 - INFO - LLMParser initialized.
# xml_parser.py - line 23 - INFO - Initializing xmlRetriever
# xml_parser.py - line 141 - INFO - Function call: parse_data(api_data(<class 'lxml.etree._Element'>), PMC, https://pmc.ncbi.nlm.nih.gov/articles/PMC11792374, additional_data, XML)
# xml_parser.py - line 443 - INFO - Function_call: extract_href_from_supplementary_material(api_xml, current_url_address)
# base_parser.py - line 263 - INFO - Function_call: load_patterns_for_tgt_section(supplementary_material_sections)
# base_parser.py - line 264 - INFO - Consider migrating this function to the BaseRetriever class.
# xml_parser.py - line 454 - INFO - Found 10 supplementary material sections .//supplementary-material. cont: [<Element supplementary-material at 0x1aff46900>, <Element supplementary-material at 0x1aff58940>, <Element supplementary-material at 0x1aff58d80>, <Element supplementary-material at 0x1aff58d00>, <Element supplementary-material at 0x1aff58dc0>, <Element supplementary-material at 0x1aff58d40>, <Element supplementary-material at 0x1aff58f80>, <Element supplementary-material at 0x1aff58f00>, <Element supplementary-material at 0x1aff58fc0>, <Element supplementary-material at 0x1aff59000>]
# xml_parser.py - line 462 - INFO - Processing section: {'ptr': './/supplementary-material', 'cont': [<Element supplementary-material at 0x1aff46900>, <Element supplementary-material at 0x1aff58940>, <Element supplementary-material at 0x1aff58d80>, <Element supplementary-material at 0x1aff58d00>, <Element supplementary-material at 0x1aff58dc0>, <Element supplementary-material at 0x1aff58d40>, <Element supplementary-material at 0x1aff58f80>, <Element supplementary-material at 0x1aff58f00>, <Element supplementary-material at 0x1aff58fc0>, <Element supplementary-material at 0x1aff59000>]}
# xml_parser.py - line 548 - INFO - Function_call: extract_supplementary_material_refs(api_xml, supplementary_material_links)
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM1: ABCA1 expression also correlated with SASP scores in the same human brain samples (Supplementary Fig. 1 [this file] A). Sn-RNA sequencing analysis also indicated that mTOR activation scores were positively associated with ABCA1 expression in astrocytes, excitatory and inhibitory neurons, microglia, oligodendrocytes, and oligodendrocyte progenitor cells (Supplementary Fig. 1 [this file] B). AD characteristics, such as Braak stage, NFT burden, and neuritic plaque burden, were also positively correlated with mTOR activation in excitatory neurons (Supplementary Fig. 1 [this file] B), where APOE4 was associated with increased mTOR expression in excitatory neurons, oligodendrocytes, and pericytes (Supplementary Fig. 1 [this file] B).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM2: Using SenTraGor (STG, a reagent for detection of lipofuscin) [ 50 [rid=CR50] ] staining in postmortem human brain slices (mid-frontal lobe region) from ROS, we observed higher STG intensity in GFAP-positive astrocytes in AD participants compared to NCI participants with the APOE3/4 genotype (Fig. 2 [rid=Fig2] A, the STG/GFAP staining test is shown in Supplementary Fig. 2 [this file] A), corroborating the increased astrocyte senescence markers in AD observed in the transcriptomic data.
# Given that ABCA1 is predominantly localized in cell membranes [ 51 [rid=CR51] ], cytosolic proteins were removed (Fig. 2 [rid=Fig2] B, Supplementary Fig. 2 [this file] B). Total membrane ABCA1 levels were higher in APOE3/3 and APOE3/4 carriers with AD dementia than in APOE3/3 and APOE3/4 carriers in the NCI group (Fig. 2 [rid=Fig2] B; full blots are shown in Supplementary Fig. 2 [this file] C).
# In human postmortem middle frontal lobe tissues, caveolin-1 protein levels were higher in both APOE3/3 and APOE3/4 carriers with AD dementia than in the NCI group, although there was no difference between the APOE3/3 and APOE3/4 genotypes in either group (Fig. 3 [rid=Fig3] M; full blots are shown in Supplementary Fig. 2 [this file] C).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM3: ABCA1 was more abundant in lysosome-enriched fractions in the AD group than in the NCI group within the APOE3/4 genotype but not in the APOE3/3 genotype (Fig. 2 [rid=Fig2] C, full blots are shown in Supplementary Fig. 3 [this file] ), supporting that more ABCA1 was trapped in lysosomes in APOE4 AD.
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM4: To explore the underlying mechanism, we treated ABCA1-GFP overexpressing HeLa cells with recombinant ApoE3 (rE3) or ApoE4 (rE4). rE4 treatment resulted in lower total ABCA1 protein levels than rE3 treatment, indicating greater ABCA1 degradation (Supplementary Fig. 4 [this file] A). ABCA1-binding complexes were enriched for proteomic analysis (Fig. 3 [rid=Fig3] A and Supplementary Fig. 4 [this file] B). Proteomic analysis revealed 768 shared proteins between rE3 and rE4 treatments, with 314 proteins unique to rE4 (Supplementary Fig. 4 [this file] C). Nine of these proteins (Supplementary Table 4) showed higher expression in the rE4 treatment group than in the rE3 group (Supplementary Fig. 4 [this file] D). Reducing caveolin-1, but not, AP2B1 expression by siRNA increased plasma membrane ABCA1 levels in mouse primary astrocytes (Fig. 3 [rid=Fig3] F, Supplementary Fig. 4 [this file] E), supporting that caveolae-mediated endocytosis regulated ABCA1 degradation. Surprisingly, reducing caveolin-1 expression significantly decreased ABCA1-mediated cholesterol efflux (Fig. 3 [rid=Fig3] G) despite an increase in total ABCA1 protein levels (Supplementary Fig. 4 [this file] F). Furthermore, overexpression of caveolin-1 in astrocytes enhanced cholesterol efflux (Supplementary Fig. 4 [this file] G).
# Cholesterol loading, by adding LDL, led to increased caveolin-1 expression (Fig. 3 [rid=Fig3] H and I) and showed a dose-dependent increase in baby hamster kidney (BHK) cells (Supplementary Fig. 4 [this file] H).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM5: Mouse cortices were fractionated using TBSX and guanidine HCl to isolate soluble membrane and insoluble aggregated proteins (Supplementary Fig. 5 [this file] A).
# To identify the main cell type in which ABCA1 and caveolin-1 interact, we isolated microglia, astrocytes and axon-enriched fraction from the brains of adult mice (Supplementary Fig. 5 [this file] B). Astrocytes were enriched in the CD11b fraction (Supplementary Fig. 5 [this file] C). ABCA1 was mainly expressed in astrocytes and axon-enriched fractions, and lower ABCA1 expression was detected in microglial cells (Supplementary Fig. 5 [this file] D). Caveolin-1 was mainly expressed in astrocytes and microglia but not in axon-enriched fractions (Supplementary Fig. 5 [this file] E).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM6: In agreement, ABCA1 brain knockout mice showed higher p21 intensity in the brain than ABCA1 WT mice (Fig. 4 [rid=Fig4] G, p21 staining test is shown in Supplementary Fig. 6 [this file] A). To indirectly assess lysosomal ABCA1 localization in APOE4-TR brains, tissue slides were double stained with LAMP1 and ABCA1 (Supplementary Fig. 6 [this file] B).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM7: Body weight was not affected by HPCD treatment (Supplementary Fig. 7 [this file] A). Total cholesterol levels in the brain (Fig. 5 [rid=Fig5] B) or plasma (Supplementary Fig. 7 [this file] B) were also no different between HPCD and PBS groups. Lysosomal ABCA1 levels were lower in the HPCD treatment group, as verified by lysosome isolation and immunostaining (Fig. 5 [rid=Fig5] G and H; validation of lysosome isolation is shown in Supplementary Fig. 7 [this file] C). Treatment with HPCD was associated with more efficient cholesterol efflux, as evidenced by increased trends of small HDL particle formation in cerebrospinal fluid (CSF) and plasma, although these changes did not reach statistical significance due to the small sample size (Supplementary Fig. 7 [this file] D-F).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM8: HPCD also diminished the activated astrocytes and microglia (Fig. 6 [rid=Fig6] E), and several inflammatory cytokines (Supplementary Fig. 8 [this file] A), but increased synaptophysin, PSD95, and vGLuT1 levels (Supplementary Fig. 8 [this file] B and 8 [this file] C).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM9: To validate these findings in human cells, we cultured human induced pluripotent stem cell (hiPSC)-derived astrocytes with APOE4/4 genotype (Supplementary Fig. 9 [this file] A). When these human iPSc-derived astrocytes were treated with methyl-β-cyclodextrin (MβCD) after LDL loading, cellular cholesterol accumulation (Supplementary Fig. 9 [this file] B) and IL-1β and CCL2 mRNA levels were decreased (Supplementary Fig. 9 [this file] C).
#
# xml_parser.py - line 564 - INFO - Extracted context_descr for xref MOESM10: Clinical and pathological characteristics of the samples are detailed in Supplementarys Table ( 1 [this file] ) and Table ( 2 [this file] ).
# Detailed information regarding all samples is provided in Supplementary Table 1 [this file] .
# Detailed information about the samples is provided in Supplementary Table 2 [this file] .
# Detailed information on these samples is presented in Supplementary Table 3 [this file] .
# The antibodies used are listed in Supplementary Table 5 [this file] .
# The primers were listed in Supplementary Table 6 [this file] .
# Cellular senescence pathway enrichment scores for each sample were calculated using single-sample Gene Set Enrichment Analysis (ssGSEA) (the cellular senescence genes are listed in Supplementary Table 7 [this file] ).
#
# xml_parser.py - line 243 - INFO - Extracting links from full XML content.
# base_parser.py - line 409 - INFO - Function_call: extract_datasets_info_from_content(...)
# prompt_manager.py - line 33 - INFO - Loading prompt: GPT_FDR_FewShot_Syn from user_prompt_dir: None, subdir:
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 1282 - INFO - Number of tokens: 79161
# base_parser.py - line 417 - INFO - Content length: 311300
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 428 - INFO - Prompt messages total length: 79883 tokens
# base_parser.py - line 434 - INFO - Prompt ID: gpt-4o-mini-0-b796f997a46e1f3f7b578274d833fcf76597e65ba8cb60314a0bab4333b94439
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 453 - INFO - Requesting datasets from content using model: gpt-4o-mini, temperature: 0, messages length: 79883 tokens
# base_parser.py - line 480 - INFO - GPT response: {"datasets":[{"dataset_identifier":"syn8456637","repository_reference":"https://www.synapse.org/#!Synapse:syn8456637"},{"dataset_identifier":"syn2580853","repository_reference":"https://www.synapse.org/#!Synapse:syn2580853"},{"dataset_identifier":"n/a","repository_reference":"n/a"}]}
# base_parser.py - line 484 - INFO - Response is <class 'dict'>: {'datasets': [{'dataset_identifier': 'syn8456637', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn8456637'}, {'dataset_identifier': 'syn2580853', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn2580853'}, {'dataset_identifier': 'n/a', 'repository_reference': 'n/a'}]}
# base_parser.py - line 693 - INFO - Deduplicating response with 3 items
# base_parser.py - line 711 - INFO - Adding unique item: syn8456637
# base_parser.py - line 711 - INFO - Adding unique item: syn2580853
# base_parser.py - line 711 - INFO - Adding unique item: n/a
# base_parser.py - line 487 - INFO - Response is <class 'list'>: [{'dataset_identifier': 'syn8456637', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn8456637', 'dataset_id': 'syn8456637'}, {'dataset_identifier': 'syn2580853', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn2580853', 'dataset_id': 'syn2580853'}, {'dataset_identifier': 'n/a', 'repository_reference': 'n/a', 'dataset_id': 'n/a'}]
# base_parser.py - line 585 - INFO - Processing dataset: {'dataset_identifier': 'syn8456637', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn8456637', 'dataset_id': 'syn8456637'}
# base_parser.py - line 600 - INFO - Dataset is a dictionary
# base_parser.py - line 641 - INFO - Using id_pattern to extract ID: .*(syn\d{7,12}).*
# base_parser.py - line 645 - INFO - Extracted ID: syn8456637
# base_parser.py - line 649 - INFO - Schema validation vals: syn8456637, synapse.org, https://www.synapse.org/#!Synapse:syn8456637
# base_parser.py - line 654 - INFO - Dataset ID found via pattern matching: syn8456637
# base_parser.py - line 662 - INFO - Data repository found via pattern matching: synapse.org
# base_parser.py - line 620 - INFO - Extracted dataset: {'dataset_identifier': 'syn8456637', 'data_repository': 'synapse.org', 'dataset_webpage': 'n/a'}
# base_parser.py - line 585 - INFO - Processing dataset: {'dataset_identifier': 'syn2580853', 'repository_reference': 'https://www.synapse.org/#!Synapse:syn2580853', 'dataset_id': 'syn2580853'}
# base_parser.py - line 600 - INFO - Dataset is a dictionary
# base_parser.py - line 641 - INFO - Using id_pattern to extract ID: .*(syn\d{7,12}).*
# base_parser.py - line 645 - INFO - Extracted ID: syn2580853
# base_parser.py - line 649 - INFO - Schema validation vals: syn2580853, synapse.org, https://www.synapse.org/#!Synapse:syn2580853
# base_parser.py - line 654 - INFO - Dataset ID found via pattern matching: syn2580853
# base_parser.py - line 662 - INFO - Data repository found via pattern matching: synapse.org
# base_parser.py - line 620 - INFO - Extracted dataset: {'dataset_identifier': 'syn2580853', 'data_repository': 'synapse.org', 'dataset_webpage': 'n/a'}
# base_parser.py - line 585 - INFO - Processing dataset: {'dataset_identifier': 'n/a', 'repository_reference': 'n/a', 'dataset_id': 'n/a'}
# base_parser.py - line 600 - INFO - Dataset is a dictionary
# base_parser.py - line 649 - INFO - Schema validation vals: None, None, None
# base_parser.py - line 1011 - INFO - Validating accession ID: n/a
# base_parser.py - line 1016 - INFO - Accession ID n/a is invalid
# base_parser.py - line 1103 - INFO - Resolving data repository for candidate: n/a, identifier: n/a
# base_parser.py - line 964 - INFO - Extracting repo domain from URL: n/a
# base_parser.py - line 1160 - INFO - data_repository not resolved, using domain
# base_parser.py - line 677 - INFO - Data repository is 'n/a', skipping dataset
# base_parser.py - line 605 - INFO - Skipping dataset due to missing ID or repository: {'dataset_identifier': 'n/a', 'repository_reference': 'n/a', 'dataset_id': 'n/a'}
# xml_parser.py - line 256 - INFO - Augmented dataset links: [{'dataset_identifier': 'syn8456637', 'data_repository': 'synapse.org', 'dataset_webpage': 'n/a'}, {'dataset_identifier': 'syn2580853', 'data_repository': 'synapse.org', 'dataset_webpage': 'n/a'}]
# base_parser.py - line 1181 - INFO - Fetching metadata for 2 datasets
# base_parser.py - line 1189 - INFO - Processing dataset 1 with keys: dict_keys(['dataset_identifier', 'data_repository', 'dataset_webpage'])
# base_parser.py - line 1200 - INFO - Raw accession ID: syn8456637
# base_parser.py - line 1103 - INFO - Resolving data repository for candidate: synapse.org, identifier: syn8456637
# base_parser.py - line 1151 - INFO - Checking id_pattern PDC[0-9]+ match with identifier syn8456637 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern 10\.\d{4,9}/ match with identifier syn8456637 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern \bGSE\d+|GSM\d+|GPL\d+|GDS\d+\b match with identifier syn8456637 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern phs[0-9]+\.\w+\d+\.\w+\d+ match with identifier syn8456637 for synapse.org
# base_parser.py - line 1132 - INFO - Exact - case insensitive - match found for repo: synapse.org
# base_parser.py - line 1085 - INFO - Resolving accession ID for syn8456637 in synapse.org
# base_parser.py - line 1214 - INFO - Processing dataset 1 with repo: synapse.org and accession_id: syn8456637
# base_parser.py - line 1240 - INFO - Dataset page: https://www.synapse.org/[#!]*Synapse:syn8456637
# base_parser.py - line 1247 - INFO - Adding access mode for dataset 1: Complex download or application to access
# base_parser.py - line 1189 - INFO - Processing dataset 2 with keys: dict_keys(['dataset_identifier', 'data_repository', 'dataset_webpage'])
# base_parser.py - line 1200 - INFO - Raw accession ID: syn2580853
# base_parser.py - line 1103 - INFO - Resolving data repository for candidate: synapse.org, identifier: syn2580853
# base_parser.py - line 1151 - INFO - Checking id_pattern PDC[0-9]+ match with identifier syn2580853 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern 10\.\d{4,9}/ match with identifier syn2580853 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern \bGSE\d+|GSM\d+|GPL\d+|GDS\d+\b match with identifier syn2580853 for synapse.org
# base_parser.py - line 1151 - INFO - Checking id_pattern phs[0-9]+\.\w+\d+\.\w+\d+ match with identifier syn2580853 for synapse.org
# base_parser.py - line 1132 - INFO - Exact - case insensitive - match found for repo: synapse.org
# base_parser.py - line 1085 - INFO - Resolving accession ID for syn2580853 in synapse.org
# base_parser.py - line 1214 - INFO - Processing dataset 2 with repo: synapse.org and accession_id: syn2580853
# base_parser.py - line 1240 - INFO - Dataset page: https://www.synapse.org/[#!]*Synapse:syn2580853
# base_parser.py - line 1247 - INFO - Adding access mode for dataset 2: Complex download or application to access
# base_parser.py - line 1258 - INFO - Updated datasets len: 2
# xml_parser.py - line 265 - INFO - Dataset Links type: <class 'pandas.core.frame.DataFrame'> of len 12, with cols: Index(['dataset_identifier', 'data_repository', 'dataset_webpage',
#        'access_mode', 'link', 'source_url', 'download_link', 'title',
#        'content_type', 'id', 'caption', 'description', 'source_section',
#        'retrieval_pattern', 'context_description'],
#       dtype='object')
# data_gatherer.py - line 471 - INFO - Raw Data parsing completed.
# data_gatherer.py - line 477 - INFO - XML element classification not needed. Using parsed_data.
# data_gatherer.py - line 574 - INFO -
# Progress: 1/100 (1.00%) | Elapsed: 00:00:06 | ETA: 00:10:19
#
# data_gatherer.py - line 554 - INFO - 1th function call: self.process_url(https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527)
# data_gatherer.py - line 358 - INFO - Processing URL: https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527
# data_fetcher.py - line 166 - INFO - raw_HTML_data_filepath: None
# data_fetcher.py - line 173 - INFO - Initializing EntrezFetcher(('requests', 'self.config'))
# data_fetcher.py - line 24 - WARNING - DataFetcher raw_HTML_data_filepath set no None
# data_gatherer.py - line 365 - INFO - Type of data_fetcher EntrezFetcher
# data_fetcher.py - line 534 - INFO - Fetching data from request: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id=PMC4318527&retmode=xml
# xml_retriever.py - line 446 - INFO - ----Checking for data_availability_sections section in raw data.
# xml_retriever.py - line 59 - INFO - Missing section in XML: data_availability_sections
# data_gatherer.py - line 394 - INFO - Fallback to HTML data fetcher for https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527.
# data_fetcher.py - line 166 - INFO - raw_HTML_data_filepath: None
# data_fetcher.py - line 185 - INFO - WebScraper instance: False
# data_fetcher.py - line 186 - INFO - EntrezFetcher instance: True
# data_fetcher.py - line 187 - INFO - scraper_tool attribute: False
# data_fetcher.py - line 189 - INFO - Initializing new selenium driver None, Firefox, True.
# selenium_setup.py - line 11 - INFO - Creating WebDriver for browser: Firefox, with driver located at driver_path: None
# selenium_setup.py - line 41 - INFO - No driver path provided, using GeckoDriverManager to auto-install Firefox driver.
# selenium_setup.py - line 43 - INFO - Using GeckoDriverManager to auto-install Firefox driver <selenium.webdriver.firefox.service.Service object at 0x1ab7439d0>.
# data_fetcher.py - line 24 - WARNING - DataFetcher raw_HTML_data_filepath set no None
# data_fetcher.py - line 376 - WARNING - Publication name not found in the page title.
# data_fetcher.py - line 311 - INFO - No cookie pattern 1 found in HTML
# data_gatherer.py - line 410 - INFO - Raw HTML data fetched from https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527 is ready for parsing.
# data_gatherer.py - line 424 - INFO - Skipping raw HTML/XML saving.
# data_gatherer.py - line 453 - INFO - Using HTMLParser to parse data.
# base_parser.py - line 177 - INFO - LLMParser initialized.
# html_parser.py - line 81 - INFO - Initializing htmlRetriever
# html_parser.py - line 349 - INFO - Function call: parse_data(html_str, PMC, https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527, additional_data, HTML)
# html_parser.py - line 445 - INFO - Function_call: extract_href_from_supplementary_material(tree, https://pmc.ncbi.nlm.nih.gov/articles/PMC4318527)
# html_parser.py - line 547 - INFO - Extracted 23 unique supplementary material links from HTML.
# html_parser.py - line 557 - INFO - Function_call: extract_supplementary_material_refs(raw_html, supplementary_material_links)
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#clp_a'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for clp_a:
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#clp_a'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for clp_a:
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 5 <a> elements with href='#Tab1'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 1173) for Tab1: Indeed, as the use of computational methods in biomedical research becomes widespread, the need for appropriate benchmarking projects, especially those involving community participation, is substantially growing (Table 1 [href=this file] ).
# Challenge-based benchmarking efforts, such as CASP [ 8 [href=#CR8] – 10 [href=#CR10] ], CAFA [ 11 [href=#CR11] ] and DREAM [ 12 [href=#CR12] , 13 [href=#CR13] ], among others (Table 1 [href=this file] ), offer a robust framework for algorithm evaluation.
# Several non-cancer-focused challenge-based benchmarking efforts are on-going, including the Assemblathon benchmarking of sequence assembly algorithms [ 23 [href=#CR23] ] and the CLARITY Challenge for standardizing clinical genome sequencing analysis and reporting [ 24 [href=#CR24] ] (Table 1 [href=this file] ).
# For example, the ICGC-TCGA DREAM SMC Challenge [ 28 [href=#CR28] ] (Table 1 [href=this file] ) involved transmitting over 10 TB of data to every contestant, so that each had a copy of the 15 tumor-normal whole-genome pairs.
# Several groups are developing the expertise to facilitate this process, including CASP, DREAM, CAFA and others (Table 1 [href=this file] ).
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#Bib1_sec2'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for Bib1_sec2:
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#Bib1_sec2'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for Bib1_sec2:
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#Bib1_sec2'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for Bib1_sec2:
# html_parser.py - line 568 - INFO - Found 0 <a> elements with href='#Bib1_sec2'.
# html_parser.py - line 576 - INFO - Extracted context description (len: 0) for Bib1_sec2:
# html_parser.py - line 367 - INFO - Extracting links from full HTML content.
# base_parser.py - line 409 - INFO - Function_call: extract_datasets_info_from_content(...)
# prompt_manager.py - line 33 - INFO - Loading prompt: GPT_FDR_FewShot_Syn from user_prompt_dir: None, subdir:
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 1282 - INFO - Number of tokens: 39828
# base_parser.py - line 417 - INFO - Content length: 138300
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 428 - INFO - Prompt messages total length: 40550 tokens
# base_parser.py - line 434 - INFO - Prompt ID: gpt-4o-mini-0-5a92660a4b138d90811961053a409a8f306dd60aaf60cb4d5f9dc63c1c323ce7
# base_parser.py - line 1299 - INFO - Expected string but got list. Converting list to string.
# base_parser.py - line 453 - INFO - Requesting datasets from content using model: gpt-4o-mini, temperature: 0, messages length: 40550 tokens
# base_parser.py - line 480 - INFO - GPT response: {
#   "datasets": [
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "n/a"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://assemblathon.org/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://biofunctionprediction.org/node/8"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://genomeinterpretation.org/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://www.ebi.ac.uk/msd-srv/capri/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://predictioncenter.org/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://www.chalearn.org/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://www.childrenshospital.org/research-and-innovation/research-initiatives/clarity-challenge"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "https://www.synapse.org/#!Challenges:DREAM"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "http://flowcap.flowsite.org/"
#     },
#     {
#       "dataset_identifier": "n/a",
#       "repository_reference": "https://www.synapse.org/#!Synapse:syn312572"
#     },
#     {
# ...
#     570     elapsed = time.time() - start_time  # Time elapsed since start
#
# File ~/Desktop/VIDA-NYU/data-gatherer/data_gatherer/data_gatherer.py:438, in DataGatherer.process_url(self, url, save_staging_table, article_file_dir, use_portkey_for_gemini, driver_path, browser, headless, prompt_name, semantic_retrieval, section_filter)
#     431 self.parser = XMLParser(self.open_data_repos_ontology, self.logger,
#     432                         llm_name=self.llm,
#     433                         full_document_read=self.full_document_read,
#     434                         use_portkey_for_gemini=use_portkey_for_gemini,
#     435                         save_dynamic_prompts=self.save_dynamic_prompts)
#     437 if additional_data is None:
# --> 438     parsed_data = self.parser.parse_data(raw_data, self.publisher, self.current_url,
#     439                                          prompt_name=prompt_name, semantic_retrieval=semantic_retrieval,
#     440                                          section_filter=section_filter)
#     442 else:
#     443     self.logger.info(f"Processing additional data. # of items: {len(additional_data)}")
#
# File ~/Desktop/VIDA-NYU/data-gatherer/data_gatherer/parser/xml_parser.py:250, in XMLParser.parse_data(self, api_data, publisher, current_url_address, additional_data, raw_data_format, article_file_dir, process_DAS_links_separately, section_filter, prompt_name, use_portkey_for_gemini, semantic_retrieval)
#     247 self.logger.debug(f"Preprocessed data: {preprocessed_data}")
#     249 # Extract dataset links from the entire text
# --> 250 augmented_dataset_links = self.extract_datasets_info_from_content(preprocessed_data,
#     251                                                               self.open_data_repos_ontology['repos'],
#     252                                                               model=self.llm_name,
#     253                                                               temperature=0,
#     254                                                               prompt_name=prompt_name)
#     256 self.logger.info(f"Augmented dataset links: {augmented_dataset_links}")
#     258 dataset_links_w_target_pages = self.get_dataset_page(augmented_dataset_links)
#
# File ~/Desktop/VIDA-NYU/data-gatherer/data_gatherer/parser/base_parser.py:470, in LLMParser.extract_datasets_info_from_content(self, content, repos, model, temperature, prompt_name, full_document_read)
#     468 response = None
#     469 if self.full_document_read:
# --> 470     response = self.client.chat.completions.create(
#     471         model=model,
#     472         messages=messages,
#     473         temperature=temperature,
#     474         response_format=dataset_response_schema_gpt
#     475     )
#     476 else:
#     477     response = self.client.chat.completions.create(model=model, messages=messages,
#     478                                                    temperature=temperature)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)    911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_base_client.py:964, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     961 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     963 if remaining_retries > 0:
# --> 964     return self._retry_request(
#     965         input_options,
#     966         cast_to,
#     967         retries_taken=retries_taken,
#     968         stream=stream,
#     969         stream_cls=stream_cls,
#     970         response_headers=None,
#     971     )
#     973 log.debug("Raising timeout error")
#     974 raise APITimeoutError(request=request) from err
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)    230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~/opt/miniconda3/envs/Summer24/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
combined_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 combined_df
#
# NameError: name 'combined_df' is not defined

# %%
ground_truth = pd.read_parquet("exp_input/dataset_citation_records_Table.parquet")

# %%
ground_truth.head()

# %%
def evaluate_performance(predict_df, ground_truth, orchestrator, false_positives_file):
    """ Evaluates dataset extraction performance using precision, recall, and F1-score. """

    recall_list, false_positives_output = [], []
    total_precision, total_recall, num_sources = 0, 0, 0

    for source_page in predict_df['source_url'].unique():
        pub_id = source_page.split('/')[-1].lower()
        
        orchestrator.logger.info(f"Evaluating pub_id: {pub_id}")
        gt_data = ground_truth[ground_truth['pmcid'].str.lower() == pub_id.lower()]  # extract ground truth

        gt_datasets = set()
        for dataset_string in gt_data['identifier'].dropna().str.lower():
            gt_datasets.update(dataset_string.split(','))  # Convert CSV string into set of IDs

        orchestrator.logger.info(f"# of elements in gt_data: {len(gt_data)}. Element IDs: {gt_datasets}")

        num_sources += 1

        # Extract evaluation datasets for this source page
        eval_data = predict_df[predict_df['source_url'] == source_page]
        eval_datasets = set(eval_data['dataset_identifier'].dropna().str.lower())
        # Remove invalid entries
        eval_datasets.discard('n/a')
        eval_datasets.discard('')

        orchestrator.logger.info(f"Evaluation datasets: {eval_datasets}")

        # Handle cases where both ground truth and evaluation are empty
        if not gt_datasets and not eval_datasets:
            orchestrator.logger.info("No datasets in both ground truth and evaluation. Perfect precision and recall.")
            total_precision += 1
            total_recall += 1
            continue

        # Match Extraction Logic
        matched_gt, matched_eval = set(), set()

        # Exact Matches
        exact_matches = gt_datasets & eval_datasets  # Intersection of ground truth and extracted datasets
        matched_gt.update(exact_matches)
        matched_eval.update(exact_matches)

        # Partial Matches (Aliased Identifiers)
        for eval_id in eval_datasets - matched_eval:
            for gt_id in gt_datasets - matched_gt:
                if eval_id in gt_id or gt_id in eval_id:  # Partial match or alias
                    orchestrator.logger.info(f"Partial or alias match found: eval_id={eval_id}, gt_id={gt_id}")
                    matched_gt.add(gt_id)
                    matched_eval.add(eval_id)
                    break  # Stop once matched

        # **False Positives (Unmatched extracted datasets)**
        FP = eval_datasets - matched_eval
        false_positives_output.extend(FP)

        # **False Negatives (Unmatched ground truth datasets)**
        FN = gt_datasets - matched_gt

        # **Precision and Recall Calculation**
        true_positives = len(matched_gt)
        false_positives = len(FP)
        false_negatives = len(FN)

        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

        orchestrator.logger.info(f"Precision for {source_page}: {precision}")
        orchestrator.logger.info(f"Recall for {source_page}: {recall}")

        if recall == 0:
            recall_list.append(source_page)

        # Accumulate totals
        total_precision += precision
        total_recall += recall

    # **Compute Overall Metrics**
    average_precision = total_precision / num_sources if num_sources > 0 else 0
    average_recall = total_recall / num_sources if num_sources > 0 else 0
    f1_score = (
        2 * (average_precision * average_recall) / (average_precision + average_recall)
        if (average_precision + average_recall) > 0
        else 0
    )

    orchestrator.logger.info(f"\nPerformance evaluation completed for {num_sources} source pages.")

    # **Save false positives**
    with open(false_positives_file, 'w') as f:
        for item in false_positives_output:
            f.write("%s\n" % item)

    return {
        "average_precision": average_precision,
        "average_recall": average_recall,
        "f1_score": f1_score
    }

# %%
#results = evaluate_performance(out, ground_truth, dg, "output/false_positives.txt")

# %%
results = evaluate_performance(combined_df, ground_truth, dg, "output/false_positives.txt")

# %%
results

# %%
"https://pmc.ncbi.nlm.nih.gov/articles/PMC11240079", "https://pmc.ncbi.nlm.nih.gov/articles/PMC5752539","https://pmc.ncbi.nlm.nih.gov/articles/PMC7032692", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10547713", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8102856", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8055881", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8226229", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10769298", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11659981", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8082263", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8565335", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9094742", "https://pmc.ncbi.nlm.nih.gov/articles/PMC7029360", "https://pmc.ncbi.nlm.nih.gov/articles/PMC6289083", "https://pmc.ncbi.nlm.nih.gov/articles/PMC7658217", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9780309","https://pmc.ncbi.nlm.nih.gov/articles/PMC3788619", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8859891", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10680627", "https://pmc.ncbi.nlm.nih.gov/articles/PMC6323985", "https://pmc.ncbi.nlm.nih.gov/articles/PMC8131595", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11420198", "https://pmc.ncbi.nlm.nih.gov/articles/PMC9915613", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10238095", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10802452" , "https://pmc.ncbi.nlm.nih.gov/articles/PMC11032436", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10329279", "https://pmc.ncbi.nlm.nih.gov/articles/PMC10836119",  "https://pmc.ncbi.nlm.nih.gov/articles/PMC9280291", "https://pmc.ncbi.nlm.nih.gov/articles/PMC11661334", "https://pmc.ncbi.nlm.nih.gov/articles/PMC5161470", "https://pmc.ncbi.nlm.nih.gov/articles/PMC4339277"

# %%
combined_df.to_csv("output/SAGE_GPT_FDR_FewShot_Synapse_output.csv", index=False)
