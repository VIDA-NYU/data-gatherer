# %%
import re
import requests
from xml.etree import ElementTree
import json
import pandas as pd
import time
from data_gatherer.data_fetcher import *
from data_gatherer.parser import *
from data_gatherer.orchestrator import *
from dotenv import load_dotenv
import ast  # To safely evaluate string representation of a list
import bdikit as bdi
import requests
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9230c111-a2f9-441a-a178-1f1832ce6d58'>
#   <div id="deff9566-d1a1-477f-98c6-04fb117f6f57" data-root-id="9230c111-a2f9-441a-a178-1f1832ce6d58" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"df0bedb7-fcb2-4ce2-81e9-c956e904203f":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"9230c111-a2f9-441a-a178-1f1832ce6d58"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"68978953-d11d-486d-a774-c9f6654aa1ff","attributes":{"plot_id":"9230c111-a2f9-441a-a178-1f1832ce6d58","comm_id":"36ef8f479d2b4b9dabb55d24f387501c","client_comm_id":"24117ab6be6e42d3a22dd7bf23005ead"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"df0bedb7-fcb2-4ce2-81e9-c956e904203f","roots":{"9230c111-a2f9-441a-a178-1f1832ce6d58":"deff9566-d1a1-477f-98c6-04fb117f6f57"},"root_ids":["9230c111-a2f9-441a-a178-1f1832ce6d58"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
output_file = "exp_input/PRIDE_GSE_id_HTML_data.csv"
input_file = "exp_input/PX_id_HTML_v4.parquet"

# %%
esearch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
params = {
    "db": "gds",  # Search in GEO database
    "term": '"gse"[Entry Type]',  # Only fetch GEO Series (GSE)
    "retmax": "1000000",  # Maximum records to retrieve (adjust as needed)
    "retmode": "xml"
}

# Request dataset IDs from NCBI
response = requests.get(esearch_url, params=params)
root = ElementTree.fromstring(response.content)

# Extract dataset IDs
gse_ids = [id_elem.text for id_elem in root.findall(".//Id")]

print(f"Total datasets found: {len(gse_ids)}")
print("Sample GSE IDs:", gse_ids[:10])  # Show first 10 results
# Out:
# Total datasets found: 254549
# Sample GSE IDs: ['200298457', '200298456', '200298343', '200298187', '200298184', '200298155', '200298096', '200298092', '200295914', '200295194']

# %%
def fetch_GEO_data(IDs,request_url,start,stop):
    params = {
        "db": "gds",
        "id": ",".join(IDs[start:stop]),  # Query for first 10 datasets
        "retmode": "json"
    }

    response = requests.get(request_url, params=params)
    
    try:
        data = response.json()
    except:
        raise ValueError("Failed to parse JSON response! Please check the response content.")
    
    return data

# %%
pd.DataFrame(fetch_GEO_data(gse_ids,"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi",0,2))

# %%
# load the data from local file
print("Loading local data...")
try:
    df0 = pd.read_csv("exp_input/GEO_data_v1.csv")
    df0 = df0.drop(columns=["Unnamed: 0"])
    # drop null columns
    df0 = df0.dropna(axis=1, how='all')
    print(f"Shape: {df0.shape}")
    print(f"Columns: {df0.columns}")
except:
    df0 = None
    print("No local data found.")

# %%
# update dataset with new data whose id is not in the local dataset
if df0 is not None:
    all_ids = set(gse_ids)
    old_ids = set(list(df0["uid"].apply(str)))
    missing_ids = all_ids - old_ids
    
    print(f"Total missing datasets found: {len(missing_ids)}")
    
    data = {}
    step = 1
    
    for i, id in enumerate(missing_ids):
        if i % (len(missing_ids)//10) == 0 and i > 0:
            print(f"Iter {i}")
        try:
            new_data = fetch_GEO_data(list(missing_ids),"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi", i, i+step)
            # print(f"Data: {type(new_data)}")
            # print(f"Data: {new_data.keys()}")
            if "result" not in new_data:
                print(f"new_data: {new_data}")
            for uid, details in new_data['result'].items():
                if uid == "uids":  # Ignore metadata key
                    continue
                data[uid] = details
        except Exception as e:
            raise ValueError(f"Failed to fetch data for {id}! Error: {e}")
        
        time.sleep(0.33)  # Be nice to the server

else:
    data = {}
    i = 0
    mxm = 300
    while True:
        print(i)
        if i > len(gse_ids):
            break
        try:
            new_data = fetch_GEO_data(gse_ids,"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi",i,mxm)
            #print(f"Data: {new_data}")
            for uid, details in new_data["result"].items():
                if uid == "uids":  # Ignore metadata key
                    continue
                data[uid] = details
        except:
            print(f"Error at {i}, {mxm}")
            
        i += 300
        mxm += 300
        time.sleep(0.1)

# %%
df = pd.DataFrame(data).T
df = df.dropna(axis=1, how='all')
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns}")

# %%
# union of both dataframes
df = pd.concat([df0,df])
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns}")

# %%
df.to_csv("exp_input/GEO_data.csv")

# %%
df = pd.read_csv("exp_input/GEO_data.csv")
df.columns
# Out:
# /var/folders/br/873byd752sb72sf4n7yfykxw0000gn/T/ipykernel_17341/3956320188.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("exp_input/GEO_data.csv")
# Index(['Unnamed: 0', 'uid', 'accession', 'gds', 'title', 'summary', 'gpl',
#        'gse', 'taxon', 'entrytype', 'gdstype', 'pdat', 'suppfile', 'samples',
#        'relations', 'extrelations', 'n_samples', 'pubmedids', 'projects',
#        'ftplink', 'geo2r', 'bioproject', 'ptechtype', 'valtype', 'ssinfo',
#        'subsetinfo', 'seriestitle', 'platformtitle', 'platformtaxa',
#        'samplestaxa'],
#       dtype='object')

# %%
pmids = []
for i, row in df.iterrows():
    lst = ast.literal_eval(row['pubmedids'])
    if len(lst) > 0:
        pmids.extend(lst)
    else:
        continue

pmids = list(set(pmids))

print(f"Total PMIDs found: {len(pmids)}")
# Out:
# Total PMIDs found: 127239

# %%
def PMID_to_url(pmid):
    base_url = "https://www.ncbi.nlm.nih.gov/pubmed/"
    return base_url + str(pmid)

def PMID_to_doi(pmid):
    base = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"
    params = {"tool": "mytool", "email": "myemail@example.com", "ids": pmid, "format": "json"}    
    
    response = requests.get(base, params=params)
    
    if response.status_code == 200:
        data = response.json()
        records = data.get("records", [])
        if records and "doi" in records[0]:
            return records[0]["pmid"]
        else:
            return None  # No PMID found
    else:
        return None  # Request failed
    
def batch_PMID_to_doi(pmids, batch_size=100):
    base_url = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"
    results = {}

    for i in range(0, len(pmids), batch_size):
        progress = i / len(pmids) * 100
        print(f"Processing batch {i}-{i+batch_size} ({progress:.2f}%)")
        batch = pmids[i:i+batch_size]  # Get a batch of PMIDs
        params = {"tool": "mytool", "email": "myemail@example.com", "ids": ",".join(batch), "format": "json"}
        
        response = requests.get(base_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            records = data.get("records", [])

            for record in records:
                pmid = record.get("pmid")
                doi = record.get("doi", None)  # Get DOI if available
                
                if pmid and pmid not in results:
                    results[pmid] = doi  # Store in dictionary
        
        else:
            print(f"API request failed for batch {i}-{i+batch_size}: {response.status_code}")
        
        time.sleep(0.5)  # Prevent hitting API rate limits (adjust as needed)

    return results

# PMCID_to_PMID("pmc9945972")

# %%
pmid_doi_mapping = batch_PMID_to_doi(pmids)
# Out:
# Processing batch 0-100 (0.00%)
# Processing batch 100-200 (0.08%)
# Processing batch 200-300 (0.16%)
# Processing batch 300-400 (0.24%)
# Processing batch 400-500 (0.31%)
# Processing batch 500-600 (0.39%)
# Processing batch 600-700 (0.47%)
# Processing batch 700-800 (0.55%)
# Processing batch 800-900 (0.63%)
# Processing batch 900-1000 (0.71%)
# Processing batch 1000-1100 (0.79%)
# Processing batch 1100-1200 (0.86%)
# Processing batch 1200-1300 (0.94%)
# Processing batch 1300-1400 (1.02%)
# Processing batch 1400-1500 (1.10%)
# Processing batch 1500-1600 (1.18%)
# Processing batch 1600-1700 (1.26%)
# Processing batch 1700-1800 (1.34%)
# Processing batch 1800-1900 (1.41%)
# Processing batch 1900-2000 (1.49%)
# Processing batch 2000-2100 (1.57%)
# Processing batch 2100-2200 (1.65%)
# Processing batch 2200-2300 (1.73%)
# Processing batch 2300-2400 (1.81%)
# Processing batch 2400-2500 (1.89%)
# Processing batch 2500-2600 (1.96%)
# Processing batch 2600-2700 (2.04%)
# Processing batch 2700-2800 (2.12%)
# Processing batch 2800-2900 (2.20%)
# Processing batch 2900-3000 (2.28%)
# Processing batch 3000-3100 (2.36%)
# Processing batch 3100-3200 (2.44%)
# Processing batch 3200-3300 (2.51%)
# Processing batch 3300-3400 (2.59%)
# Processing batch 3400-3500 (2.67%)
# Processing batch 3500-3600 (2.75%)
# Processing batch 3600-3700 (2.83%)
# Processing batch 3700-3800 (2.91%)
# Processing batch 3800-3900 (2.99%)
# Processing batch 3900-4000 (3.07%)
# Processing batch 4000-4100 (3.14%)
# Processing batch 4100-4200 (3.22%)
# Processing batch 4200-4300 (3.30%)
# Processing batch 4300-4400 (3.38%)
# Processing batch 4400-4500 (3.46%)
# Processing batch 4500-4600 (3.54%)
# Processing batch 4600-4700 (3.62%)
# Processing batch 4700-4800 (3.69%)
# Processing batch 4800-4900 (3.77%)
# Processing batch 4900-5000 (3.85%)
# Processing batch 5000-5100 (3.93%)
# Processing batch 5100-5200 (4.01%)
# Processing batch 5200-5300 (4.09%)
# Processing batch 5300-5400 (4.17%)
# Processing batch 5400-5500 (4.24%)
# Processing batch 5500-5600 (4.32%)
# Processing batch 5600-5700 (4.40%)
# Processing batch 5700-5800 (4.48%)
# Processing batch 5800-5900 (4.56%)
# Processing batch 5900-6000 (4.64%)
# Processing batch 6000-6100 (4.72%)
# Processing batch 6100-6200 (4.79%)
# Processing batch 6200-6300 (4.87%)
# Processing batch 6300-6400 (4.95%)
# Processing batch 6400-6500 (5.03%)
# Processing batch 6500-6600 (5.11%)
# Processing batch 6600-6700 (5.19%)
# Processing batch 6700-6800 (5.27%)
# Processing batch 6800-6900 (5.34%)
# Processing batch 6900-7000 (5.42%)
# Processing batch 7000-7100 (5.50%)
# Processing batch 7100-7200 (5.58%)
# Processing batch 7200-7300 (5.66%)
# Processing batch 7300-7400 (5.74%)
# Processing batch 7400-7500 (5.82%)
# Processing batch 7500-7600 (5.89%)
# Processing batch 7600-7700 (5.97%)
# Processing batch 7700-7800 (6.05%)
# Processing batch 7800-7900 (6.13%)
# Processing batch 7900-8000 (6.21%)
# Processing batch 8000-8100 (6.29%)
# Processing batch 8100-8200 (6.37%)
# Processing batch 8200-8300 (6.44%)
# Processing batch 8300-8400 (6.52%)
# Processing batch 8400-8500 (6.60%)
# Processing batch 8500-8600 (6.68%)
# Processing batch 8600-8700 (6.76%)
# Processing batch 8700-8800 (6.84%)
# Processing batch 8800-8900 (6.92%)
# Processing batch 8900-9000 (6.99%)
# Processing batch 9000-9100 (7.07%)
# Processing batch 9100-9200 (7.15%)
# Processing batch 9200-9300 (7.23%)
# Processing batch 9300-9400 (7.31%)
# Processing batch 9400-9500 (7.39%)
# Processing batch 9500-9600 (7.47%)
# Processing batch 9600-9700 (7.54%)
# Processing batch 9700-9800 (7.62%)
# Processing batch 9800-9900 (7.70%)
# Processing batch 9900-10000 (7.78%)
# Processing batch 10000-10100 (7.86%)
# Processing batch 10100-10200 (7.94%)
# Processing batch 10200-10300 (8.02%)
# Processing batch 10300-10400 (8.10%)
# Processing batch 10400-10500 (8.17%)
# Processing batch 10500-10600 (8.25%)
# Processing batch 10600-10700 (8.33%)
# Processing batch 10700-10800 (8.41%)
# Processing batch 10800-10900 (8.49%)
# Processing batch 10900-11000 (8.57%)
# Processing batch 11000-11100 (8.65%)
# Processing batch 11100-11200 (8.72%)
# Processing batch 11200-11300 (8.80%)
# Processing batch 11300-11400 (8.88%)
# Processing batch 11400-11500 (8.96%)
# Processing batch 11500-11600 (9.04%)
# Processing batch 11600-11700 (9.12%)
# Processing batch 11700-11800 (9.20%)
# Processing batch 11800-11900 (9.27%)
# Processing batch 11900-12000 (9.35%)
# Processing batch 12000-12100 (9.43%)
# Processing batch 12100-12200 (9.51%)
# Processing batch 12200-12300 (9.59%)
# Processing batch 12300-12400 (9.67%)
# Processing batch 12400-12500 (9.75%)
# Processing batch 12500-12600 (9.82%)
# Processing batch 12600-12700 (9.90%)
# Processing batch 12700-12800 (9.98%)
# Processing batch 12800-12900 (10.06%)
# Processing batch 12900-13000 (10.14%)
# Processing batch 13000-13100 (10.22%)
# Processing batch 13100-13200 (10.30%)
# Processing batch 13200-13300 (10.37%)
# Processing batch 13300-13400 (10.45%)
# Processing batch 13400-13500 (10.53%)
# Processing batch 13500-13600 (10.61%)
# Processing batch 13600-13700 (10.69%)
# Processing batch 13700-13800 (10.77%)
# Processing batch 13800-13900 (10.85%)
# Processing batch 13900-14000 (10.92%)
# Processing batch 21700-21800 (17.05%)
# Processing batch 21800-21900 (17.13%)
# Processing batch 21900-22000 (17.21%)
# Processing batch 22000-22100 (17.29%)
# Processing batch 22100-22200 (17.37%)
# Processing batch 22200-22300 (17.45%)
# Processing batch 22300-22400 (17.53%)
# Processing batch 22400-22500 (17.60%)
# Processing batch 22500-22600 (17.68%)
# Processing batch 22600-22700 (17.76%)
# Processing batch 22700-22800 (17.84%)
# Processing batch 22800-22900 (17.92%)
# Processing batch 22900-23000 (18.00%)
# Processing batch 23000-23100 (18.08%)
# Processing batch 23100-23200 (18.15%)
# Processing batch 23200-23300 (18.23%)
# Processing batch 23300-23400 (18.31%)
# Processing batch 23400-23500 (18.39%)
# Processing batch 23500-23600 (18.47%)
# Processing batch 23600-23700 (18.55%)
# Processing batch 23700-23800 (18.63%)
# Processing batch 23800-23900 (18.70%)
# Processing batch 23900-24000 (18.78%)
# Processing batch 24000-24100 (18.86%)
# Processing batch 24100-24200 (18.94%)
# Processing batch 24200-24300 (19.02%)
# Processing batch 24300-24400 (19.10%)
# Processing batch 24400-24500 (19.18%)
# Processing batch 24500-24600 (19.26%)
# Processing batch 24600-24700 (19.33%)
# Processing batch 24700-24800 (19.41%)
# Processing batch 24800-24900 (19.49%)
# Processing batch 24900-25000 (19.57%)
# Processing batch 25000-25100 (19.65%)
# Processing batch 25100-25200 (19.73%)
# Processing batch 25200-25300 (19.81%)
# Processing batch 25300-25400 (19.88%)
# Processing batch 25400-25500 (19.96%)
# Processing batch 25500-25600 (20.04%)
# Processing batch 25600-25700 (20.12%)
# Processing batch 25700-25800 (20.20%)
# Processing batch 25800-25900 (20.28%)
# Processing batch 25900-26000 (20.36%)
# Processing batch 26000-26100 (20.43%)
# Processing batch 26100-26200 (20.51%)
# Processing batch 26200-26300 (20.59%)
# Processing batch 26300-26400 (20.67%)
# Processing batch 26400-26500 (20.75%)
# Processing batch 26500-26600 (20.83%)
# Processing batch 26600-26700 (20.91%)
# Processing batch 26700-26800 (20.98%)
# Processing batch 26800-26900 (21.06%)
# Processing batch 26900-27000 (21.14%)
# Processing batch 27000-27100 (21.22%)
# Processing batch 27100-27200 (21.30%)
# Processing batch 27200-27300 (21.38%)
# Processing batch 27300-27400 (21.46%)
# Processing batch 27400-27500 (21.53%)
# Processing batch 27500-27600 (21.61%)
# Processing batch 27600-27700 (21.69%)
# Processing batch 27700-27800 (21.77%)
# Processing batch 27800-27900 (21.85%)
# Processing batch 27900-28000 (21.93%)
# Processing batch 28000-28100 (22.01%)
# Processing batch 28100-28200 (22.08%)
# Processing batch 28200-28300 (22.16%)
# Processing batch 28300-28400 (22.24%)
# Processing batch 28400-28500 (22.32%)
# Processing batch 28500-28600 (22.40%)
# Processing batch 28600-28700 (22.48%)
# Processing batch 28700-28800 (22.56%)
# Processing batch 28800-28900 (22.63%)
# Processing batch 28900-29000 (22.71%)
# Processing batch 29000-29100 (22.79%)
# Processing batch 29100-29200 (22.87%)
# Processing batch 29200-29300 (22.95%)
# Processing batch 29300-29400 (23.03%)
# Processing batch 29400-29500 (23.11%)
# Processing batch 29500-29600 (23.18%)
# Processing batch 29600-29700 (23.26%)
# Processing batch 29700-29800 (23.34%)
# Processing batch 29800-29900 (23.42%)
# Processing batch 29900-30000 (23.50%)
# Processing batch 30000-30100 (23.58%)
# Processing batch 30100-30200 (23.66%)
# Processing batch 30200-30300 (23.73%)
# Processing batch 30300-30400 (23.81%)
# Processing batch 30400-30500 (23.89%)
# Processing batch 30500-30600 (23.97%)
# Processing batch 30600-30700 (24.05%)
# Processing batch 30700-30800 (24.13%)
# Processing batch 30800-30900 (24.21%)
# Processing batch 30900-31000 (24.29%)
# Processing batch 31000-31100 (24.36%)
# Processing batch 31100-31200 (24.44%)
# Processing batch 31200-31300 (24.52%)
# Processing batch 31300-31400 (24.60%)
# Processing batch 31400-31500 (24.68%)
# Processing batch 31500-31600 (24.76%)
# Processing batch 31600-31700 (24.84%)
# Processing batch 31700-31800 (24.91%)
# Processing batch 31800-31900 (24.99%)
# Processing batch 31900-32000 (25.07%)
# Processing batch 32000-32100 (25.15%)
# Processing batch 32100-32200 (25.23%)
# Processing batch 32200-32300 (25.31%)
# Processing batch 32300-32400 (25.39%)
# Processing batch 32400-32500 (25.46%)
# Processing batch 32500-32600 (25.54%)
# Processing batch 32600-32700 (25.62%)
# Processing batch 32700-32800 (25.70%)
# Processing batch 32800-32900 (25.78%)
# Processing batch 32900-33000 (25.86%)
# Processing batch 33000-33100 (25.94%)
# Processing batch 33100-33200 (26.01%)
# Processing batch 33200-33300 (26.09%)
# Processing batch 33300-33400 (26.17%)
# Processing batch 33400-33500 (26.25%)
# Processing batch 33500-33600 (26.33%)
# Processing batch 33600-33700 (26.41%)
# Processing batch 33700-33800 (26.49%)
# Processing batch 33800-33900 (26.56%)
# Processing batch 33900-34000 (26.64%)
# Processing batch 34000-34100 (26.72%)
# Processing batch 34100-34200 (26.80%)
# Processing batch 34200-34300 (26.88%)
# Processing batch 34300-34400 (26.96%)
# Processing batch 34400-34500 (27.04%)
# Processing batch 34500-34600 (27.11%)
# Processing batch 34600-34700 (27.19%)
# Processing batch 34700-34800 (27.27%)
# Processing batch 34800-34900 (27.35%)
# Processing batch 34900-35000 (27.43%)
# Processing batch 35000-35100 (27.51%)
# Processing batch 35100-35200 (27.59%)
# Processing batch 35200-35300 (27.66%)
# Processing batch 35300-35400 (27.74%)
# Processing batch 35400-35500 (27.82%)
# Processing batch 35500-35600 (27.90%)
# Processing batch 35600-35700 (27.98%)
# Processing batch 35700-35800 (28.06%)
# Processing batch 35800-35900 (28.14%)
# Processing batch 35900-36000 (28.21%)
# Processing batch 36000-36100 (28.29%)
# Processing batch 36100-36200 (28.37%)
# Processing batch 36200-36300 (28.45%)
# Processing batch 36300-36400 (28.53%)
# Processing batch 36400-36500 (28.61%)
# Processing batch 36500-36600 (28.69%)
# Processing batch 36600-36700 (28.76%)
# Processing batch 36700-36800 (28.84%)
# Processing batch 36800-36900 (28.92%)
# Processing batch 36900-37000 (29.00%)
# Processing batch 44600-44700 (35.05%)
# Processing batch 44700-44800 (35.13%)
# Processing batch 44800-44900 (35.21%)
# Processing batch 44900-45000 (35.29%)
# Processing batch 45000-45100 (35.37%)
# Processing batch 45100-45200 (35.45%)
# Processing batch 45200-45300 (35.52%)
# Processing batch 45300-45400 (35.60%)
# Processing batch 45400-45500 (35.68%)
# Processing batch 45500-45600 (35.76%)
# Processing batch 45600-45700 (35.84%)
# Processing batch 45700-45800 (35.92%)
# Processing batch 45800-45900 (36.00%)
# Processing batch 45900-46000 (36.07%)
# Processing batch 46000-46100 (36.15%)
# Processing batch 46100-46200 (36.23%)
# Processing batch 46200-46300 (36.31%)
# Processing batch 46300-46400 (36.39%)
# Processing batch 46400-46500 (36.47%)
# Processing batch 46500-46600 (36.55%)
# Processing batch 46600-46700 (36.62%)
# Processing batch 46700-46800 (36.70%)
# Processing batch 46800-46900 (36.78%)
# Processing batch 46900-47000 (36.86%)
# Processing batch 47000-47100 (36.94%)
# Processing batch 47100-47200 (37.02%)
# Processing batch 47200-47300 (37.10%)
# Processing batch 47300-47400 (37.17%)
# Processing batch 47400-47500 (37.25%)
# Processing batch 47500-47600 (37.33%)
# Processing batch 47600-47700 (37.41%)
# Processing batch 47700-47800 (37.49%)
# Processing batch 47800-47900 (37.57%)
# Processing batch 47900-48000 (37.65%)
# Processing batch 48000-48100 (37.72%)
# Processing batch 48100-48200 (37.80%)
# Processing batch 48200-48300 (37.88%)
# Processing batch 48300-48400 (37.96%)
# Processing batch 48400-48500 (38.04%)
# Processing batch 48500-48600 (38.12%)
# Processing batch 48600-48700 (38.20%)
# Processing batch 48700-48800 (38.27%)
# Processing batch 48800-48900 (38.35%)
# Processing batch 48900-49000 (38.43%)
# Processing batch 49000-49100 (38.51%)
# Processing batch 49100-49200 (38.59%)
# Processing batch 49200-49300 (38.67%)
# Processing batch 49300-49400 (38.75%)
# Processing batch 49400-49500 (38.82%)
# Processing batch 49500-49600 (38.90%)
# Processing batch 49600-49700 (38.98%)
# Processing batch 49700-49800 (39.06%)
# Processing batch 49800-49900 (39.14%)
# Processing batch 49900-50000 (39.22%)
# Processing batch 50000-50100 (39.30%)
# Processing batch 50100-50200 (39.37%)
# Processing batch 50200-50300 (39.45%)
# Processing batch 50300-50400 (39.53%)
# Processing batch 50400-50500 (39.61%)
# Processing batch 50500-50600 (39.69%)
# Processing batch 50600-50700 (39.77%)
# Processing batch 50700-50800 (39.85%)
# Processing batch 50800-50900 (39.92%)
# Processing batch 50900-51000 (40.00%)
# Processing batch 51000-51100 (40.08%)
# Processing batch 51100-51200 (40.16%)
# Processing batch 51200-51300 (40.24%)
# Processing batch 51300-51400 (40.32%)
# Processing batch 51400-51500 (40.40%)
# Processing batch 51500-51600 (40.48%)
# Processing batch 51600-51700 (40.55%)
# Processing batch 51700-51800 (40.63%)
# Processing batch 51800-51900 (40.71%)
# Processing batch 51900-52000 (40.79%)
# Processing batch 52000-52100 (40.87%)
# Processing batch 52100-52200 (40.95%)
# Processing batch 52200-52300 (41.03%)
# Processing batch 67600-67700 (53.13%)
# Processing batch 67700-67800 (53.21%)
# Processing batch 67800-67900 (53.29%)
# Processing batch 67900-68000 (53.36%)
# Processing batch 68000-68100 (53.44%)
# Processing batch 68100-68200 (53.52%)
# Processing batch 68200-68300 (53.60%)
# Processing batch 68300-68400 (53.68%)
# Processing batch 68400-68500 (53.76%)
# Processing batch 68500-68600 (53.84%)
# Processing batch 68600-68700 (53.91%)
# Processing batch 68700-68800 (53.99%)
# Processing batch 68800-68900 (54.07%)
# Processing batch 68900-69000 (54.15%)
# Processing batch 69000-69100 (54.23%)
# Processing batch 69100-69200 (54.31%)
# Processing batch 69200-69300 (54.39%)
# Processing batch 69300-69400 (54.46%)
# Processing batch 69400-69500 (54.54%)
# Processing batch 69500-69600 (54.62%)
# Processing batch 69600-69700 (54.70%)
# Processing batch 69700-69800 (54.78%)
# Processing batch 69800-69900 (54.86%)
# Processing batch 69900-70000 (54.94%)
# Processing batch 70000-70100 (55.01%)
# Processing batch 70100-70200 (55.09%)
# Processing batch 70200-70300 (55.17%)
# Processing batch 70300-70400 (55.25%)
# Processing batch 70400-70500 (55.33%)
# Processing batch 70500-70600 (55.41%)
# Processing batch 70600-70700 (55.49%)
# Processing batch 70700-70800 (55.56%)
# Processing batch 70800-70900 (55.64%)
# Processing batch 70900-71000 (55.72%)
# Processing batch 71000-71100 (55.80%)
# Processing batch 71100-71200 (55.88%)
# Processing batch 71200-71300 (55.96%)
# Processing batch 71300-71400 (56.04%)
# Processing batch 71400-71500 (56.11%)
# Processing batch 71500-71600 (56.19%)
# Processing batch 71600-71700 (56.27%)
# Processing batch 71700-71800 (56.35%)
# Processing batch 71800-71900 (56.43%)
# Processing batch 71900-72000 (56.51%)
# Processing batch 72000-72100 (56.59%)
# Processing batch 72100-72200 (56.67%)
# Processing batch 72200-72300 (56.74%)
# Processing batch 72300-72400 (56.82%)
# Processing batch 72400-72500 (56.90%)
# Processing batch 72500-72600 (56.98%)
# Processing batch 72600-72700 (57.06%)
# Processing batch 72700-72800 (57.14%)
# Processing batch 72800-72900 (57.22%)
# Processing batch 72900-73000 (57.29%)
# Processing batch 73000-73100 (57.37%)
# Processing batch 73100-73200 (57.45%)
# Processing batch 73200-73300 (57.53%)
# Processing batch 73300-73400 (57.61%)
# Processing batch 73400-73500 (57.69%)
# Processing batch 73500-73600 (57.77%)
# Processing batch 73600-73700 (57.84%)
# Processing batch 73700-73800 (57.92%)
# Processing batch 73800-73900 (58.00%)
# Processing batch 73900-74000 (58.08%)
# Processing batch 74000-74100 (58.16%)
# Processing batch 74100-74200 (58.24%)
# Processing batch 74200-74300 (58.32%)
# Processing batch 74300-74400 (58.39%)
# Processing batch 74400-74500 (58.47%)
# Processing batch 74500-74600 (58.55%)
# Processing batch 74600-74700 (58.63%)
# Processing batch 74700-74800 (58.71%)
# Processing batch 74800-74900 (58.79%)
# Processing batch 74900-75000 (58.87%)
# Processing batch 75000-75100 (58.94%)
# Processing batch 75100-75200 (59.02%)
# Processing batch 75200-75300 (59.10%)
# Processing batch 75300-75400 (59.18%)
# Processing batch 75400-75500 (59.26%)
# Processing batch 75500-75600 (59.34%)
# Processing batch 75600-75700 (59.42%)
# Processing batch 75700-75800 (59.49%)
# Processing batch 75800-75900 (59.57%)
# Processing batch 75900-76000 (59.65%)
# Processing batch 76000-76100 (59.73%)
# Processing batch 76100-76200 (59.81%)
# Processing batch 76200-76300 (59.89%)
# Processing batch 76300-76400 (59.97%)
# Processing batch 76400-76500 (60.04%)
# Processing batch 76500-76600 (60.12%)
# Processing batch 76600-76700 (60.20%)
# Processing batch 76700-76800 (60.28%)
# Processing batch 76800-76900 (60.36%)
# Processing batch 76900-77000 (60.44%)
# Processing batch 77000-77100 (60.52%)
# Processing batch 77100-77200 (60.59%)
# Processing batch 77200-77300 (60.67%)
# Processing batch 77300-77400 (60.75%)
# Processing batch 77400-77500 (60.83%)
# Processing batch 77500-77600 (60.91%)
# Processing batch 77600-77700 (60.99%)
# Processing batch 77700-77800 (61.07%)
# Processing batch 77800-77900 (61.14%)
# Processing batch 77900-78000 (61.22%)
# Processing batch 78000-78100 (61.30%)
# Processing batch 78100-78200 (61.38%)
# Processing batch 78200-78300 (61.46%)
# Processing batch 78300-78400 (61.54%)
# Processing batch 78400-78500 (61.62%)
# Processing batch 78500-78600 (61.69%)
# Processing batch 78600-78700 (61.77%)
# Processing batch 78700-78800 (61.85%)
# Processing batch 78800-78900 (61.93%)
# Processing batch 78900-79000 (62.01%)
# Processing batch 79000-79100 (62.09%)
# Processing batch 79100-79200 (62.17%)
# Processing batch 79200-79300 (62.25%)
# Processing batch 79300-79400 (62.32%)
# Processing batch 79400-79500 (62.40%)
# Processing batch 79500-79600 (62.48%)
# Processing batch 79600-79700 (62.56%)
# Processing batch 79700-79800 (62.64%)
# Processing batch 79800-79900 (62.72%)
# Processing batch 79900-80000 (62.80%)
# Processing batch 80000-80100 (62.87%)
# Processing batch 80100-80200 (62.95%)
# Processing batch 80200-80300 (63.03%)
# Processing batch 80300-80400 (63.11%)
# Processing batch 80400-80500 (63.19%)
# Processing batch 80500-80600 (63.27%)
# Processing batch 80600-80700 (63.35%)
# Processing batch 80700-80800 (63.42%)
# Processing batch 80800-80900 (63.50%)
# Processing batch 80900-81000 (63.58%)
# Processing batch 81000-81100 (63.66%)
# Processing batch 81100-81200 (63.74%)
# Processing batch 81200-81300 (63.82%)
# Processing batch 81300-81400 (63.90%)
# Processing batch 81400-81500 (63.97%)
# Processing batch 81500-81600 (64.05%)
# Processing batch 81600-81700 (64.13%)
# Processing batch 81700-81800 (64.21%)
# Processing batch 81800-81900 (64.29%)
# Processing batch 81900-82000 (64.37%)
# Processing batch 82000-82100 (64.45%)
# Processing batch 82100-82200 (64.52%)
# Processing batch 82200-82300 (64.60%)
# Processing batch 82300-82400 (64.68%)
# Processing batch 82400-82500 (64.76%)
# Processing batch 82500-82600 (64.84%)
# Processing batch 82600-82700 (64.92%)
# Processing batch 82700-82800 (65.00%)
# Processing batch 82800-82900 (65.07%)
# Processing batch 90600-90700 (71.20%)
# Processing batch 90700-90800 (71.28%)
# Processing batch 90800-90900 (71.36%)
# Processing batch 90900-91000 (71.44%)
# Processing batch 91000-91100 (71.52%)
# Processing batch 91100-91200 (71.60%)
# Processing batch 91200-91300 (71.68%)
# Processing batch 91300-91400 (71.75%)
# Processing batch 91400-91500 (71.83%)
# Processing batch 91500-91600 (71.91%)
# Processing batch 91600-91700 (71.99%)
# Processing batch 91700-91800 (72.07%)
# Processing batch 91800-91900 (72.15%)
# Processing batch 91900-92000 (72.23%)
# Processing batch 92000-92100 (72.30%)
# Processing batch 92100-92200 (72.38%)
# Processing batch 92200-92300 (72.46%)
# Processing batch 92300-92400 (72.54%)
# Processing batch 92400-92500 (72.62%)
# Processing batch 92500-92600 (72.70%)
# Processing batch 92600-92700 (72.78%)
# Processing batch 92700-92800 (72.86%)
# Processing batch 92800-92900 (72.93%)
# Processing batch 92900-93000 (73.01%)
# Processing batch 93000-93100 (73.09%)
# Processing batch 93100-93200 (73.17%)
# Processing batch 93200-93300 (73.25%)
# Processing batch 93300-93400 (73.33%)
# Processing batch 93400-93500 (73.41%)
# Processing batch 93500-93600 (73.48%)
# Processing batch 93600-93700 (73.56%)
# Processing batch 93700-93800 (73.64%)
# Processing batch 93800-93900 (73.72%)
# Processing batch 93900-94000 (73.80%)
# Processing batch 94000-94100 (73.88%)
# Processing batch 94100-94200 (73.96%)
# Processing batch 94200-94300 (74.03%)
# Processing batch 94300-94400 (74.11%)
# Processing batch 94400-94500 (74.19%)
# Processing batch 94500-94600 (74.27%)
# Processing batch 94600-94700 (74.35%)
# Processing batch 94700-94800 (74.43%)
# Processing batch 94800-94900 (74.51%)
# Processing batch 94900-95000 (74.58%)
# Processing batch 95000-95100 (74.66%)
# Processing batch 95100-95200 (74.74%)
# Processing batch 95200-95300 (74.82%)
# Processing batch 95300-95400 (74.90%)
# Processing batch 95400-95500 (74.98%)
# Processing batch 95500-95600 (75.06%)
# Processing batch 95600-95700 (75.13%)
# Processing batch 95700-95800 (75.21%)
# Processing batch 95800-95900 (75.29%)
# Processing batch 95900-96000 (75.37%)
# Processing batch 96000-96100 (75.45%)
# Processing batch 96100-96200 (75.53%)
# Processing batch 96200-96300 (75.61%)
# Processing batch 96300-96400 (75.68%)
# Processing batch 96400-96500 (75.76%)
# Processing batch 96500-96600 (75.84%)
# Processing batch 96600-96700 (75.92%)
# Processing batch 96700-96800 (76.00%)
# Processing batch 96800-96900 (76.08%)
# Processing batch 96900-97000 (76.16%)
# Processing batch 97000-97100 (76.23%)
# Processing batch 97100-97200 (76.31%)
# Processing batch 97200-97300 (76.39%)
# Processing batch 97300-97400 (76.47%)
# Processing batch 97400-97500 (76.55%)
# Processing batch 97500-97600 (76.63%)
# Processing batch 97600-97700 (76.71%)
# Processing batch 97700-97800 (76.78%)
# Processing batch 97800-97900 (76.86%)
# Processing batch 97900-98000 (76.94%)
# Processing batch 98000-98100 (77.02%)
# Processing batch 98100-98200 (77.10%)
# Processing batch 98200-98300 (77.18%)
# Processing batch 98300-98400 (77.26%)
# Processing batch 98400-98500 (77.33%)
# Processing batch 98500-98600 (77.41%)
# Processing batch 98600-98700 (77.49%)
# Processing batch 98700-98800 (77.57%)
# Processing batch 98800-98900 (77.65%)
# Processing batch 98900-99000 (77.73%)
# Processing batch 99000-99100 (77.81%)
# Processing batch 99100-99200 (77.88%)
# Processing batch 99200-99300 (77.96%)
# Processing batch 99300-99400 (78.04%)
# Processing batch 99400-99500 (78.12%)
# Processing batch 99500-99600 (78.20%)
# Processing batch 99600-99700 (78.28%)
# Processing batch 99700-99800 (78.36%)
# Processing batch 99800-99900 (78.44%)
# Processing batch 99900-100000 (78.51%)
# Processing batch 100000-100100 (78.59%)
# Processing batch 100100-100200 (78.67%)
# Processing batch 100200-100300 (78.75%)
# Processing batch 100300-100400 (78.83%)
# Processing batch 100400-100500 (78.91%)
# Processing batch 100500-100600 (78.99%)
# Processing batch 100600-100700 (79.06%)
# Processing batch 100700-100800 (79.14%)
# Processing batch 100800-100900 (79.22%)
# Processing batch 100900-101000 (79.30%)
# Processing batch 101000-101100 (79.38%)
# Processing batch 101100-101200 (79.46%)
# Processing batch 101200-101300 (79.54%)
# Processing batch 101300-101400 (79.61%)
# Processing batch 101400-101500 (79.69%)
# Processing batch 101500-101600 (79.77%)
# Processing batch 101600-101700 (79.85%)
# Processing batch 101700-101800 (79.93%)
# Processing batch 101800-101900 (80.01%)
# Processing batch 101900-102000 (80.09%)
# Processing batch 102000-102100 (80.16%)
# Processing batch 102100-102200 (80.24%)
# Processing batch 102200-102300 (80.32%)
# Processing batch 102300-102400 (80.40%)
# Processing batch 102400-102500 (80.48%)
# Processing batch 102500-102600 (80.56%)
# Processing batch 102600-102700 (80.64%)
# Processing batch 102700-102800 (80.71%)
# Processing batch 102800-102900 (80.79%)
# Processing batch 102900-103000 (80.87%)
# Processing batch 103000-103100 (80.95%)
# Processing batch 103100-103200 (81.03%)
# Processing batch 103200-103300 (81.11%)
# Processing batch 103300-103400 (81.19%)
# Processing batch 103400-103500 (81.26%)
# Processing batch 103500-103600 (81.34%)
# Processing batch 103600-103700 (81.42%)
# Processing batch 103700-103800 (81.50%)
# Processing batch 103800-103900 (81.58%)
# Processing batch 103900-104000 (81.66%)
# Processing batch 104000-104100 (81.74%)
# Processing batch 104100-104200 (81.81%)
# Processing batch 104200-104300 (81.89%)
# Processing batch 104300-104400 (81.97%)
# Processing batch 104400-104500 (82.05%)
# Processing batch 104500-104600 (82.13%)
# Processing batch 104600-104700 (82.21%)
# Processing batch 104700-104800 (82.29%)
# Processing batch 104800-104900 (82.36%)
# Processing batch 104900-105000 (82.44%)
# Processing batch 105000-105100 (82.52%)
# Processing batch 105100-105200 (82.60%)
# Processing batch 105200-105300 (82.68%)
# Processing batch 105300-105400 (82.76%)
# Processing batch 105400-105500 (82.84%)
# Processing batch 105500-105600 (82.91%)
# Processing batch 105600-105700 (82.99%)
# Processing batch 105700-105800 (83.07%)
# Processing batch 105800-105900 (83.15%)
# Processing batch 105900-106000 (83.23%)
# Processing batch 106000-106100 (83.31%)
# Processing batch 106100-106200 (83.39%)
# Processing batch 106200-106300 (83.46%)
# Processing batch 106300-106400 (83.54%)
# Processing batch 106400-106500 (83.62%)
# Processing batch 106500-106600 (83.70%)
# Processing batch 106600-106700 (83.78%)
# Processing batch 106700-106800 (83.86%)
# Processing batch 106800-106900 (83.94%)
# Processing batch 106900-107000 (84.02%)
# Processing batch 107000-107100 (84.09%)
# Processing batch 107100-107200 (84.17%)
# Processing batch 107200-107300 (84.25%)
# Processing batch 107300-107400 (84.33%)
# Processing batch 107400-107500 (84.41%)
# Processing batch 107500-107600 (84.49%)
# Processing batch 107600-107700 (84.57%)
# Processing batch 107700-107800 (84.64%)
# Processing batch 107800-107900 (84.72%)
# Processing batch 107900-108000 (84.80%)
# Processing batch 108000-108100 (84.88%)
# Processing batch 108100-108200 (84.96%)
# Processing batch 108200-108300 (85.04%)
# Processing batch 108300-108400 (85.12%)
# Processing batch 108400-108500 (85.19%)
# Processing batch 108500-108600 (85.27%)
# Processing batch 108600-108700 (85.35%)
# Processing batch 108700-108800 (85.43%)
# Processing batch 108800-108900 (85.51%)
# Processing batch 108900-109000 (85.59%)
# Processing batch 109000-109100 (85.67%)
# Processing batch 109100-109200 (85.74%)
# Processing batch 109200-109300 (85.82%)
# Processing batch 109300-109400 (85.90%)
# Processing batch 109400-109500 (85.98%)
# Processing batch 109500-109600 (86.06%)
# Processing batch 109600-109700 (86.14%)
# Processing batch 109700-109800 (86.22%)
# Processing batch 109800-109900 (86.29%)
# Processing batch 109900-110000 (86.37%)
# Processing batch 110000-110100 (86.45%)
# Processing batch 110100-110200 (86.53%)
# Processing batch 110200-110300 (86.61%)
# Processing batch 110300-110400 (86.69%)
# Processing batch 110400-110500 (86.77%)
# Processing batch 110500-110600 (86.84%)
# Processing batch 110600-110700 (86.92%)
# Processing batch 110700-110800 (87.00%)
# Processing batch 110800-110900 (87.08%)
# Processing batch 110900-111000 (87.16%)
# Processing batch 111000-111100 (87.24%)
# Processing batch 111100-111200 (87.32%)
# Processing batch 111200-111300 (87.39%)
# Processing batch 111300-111400 (87.47%)
# Processing batch 111400-111500 (87.55%)
# Processing batch 111500-111600 (87.63%)
# Processing batch 111600-111700 (87.71%)
# Processing batch 111700-111800 (87.79%)
# Processing batch 111800-111900 (87.87%)
# Processing batch 111900-112000 (87.94%)
# Processing batch 112000-112100 (88.02%)
# Processing batch 112100-112200 (88.10%)
# Processing batch 112200-112300 (88.18%)
# Processing batch 112300-112400 (88.26%)
# Processing batch 112400-112500 (88.34%)
# Processing batch 112500-112600 (88.42%)
# Processing batch 112600-112700 (88.49%)
# Processing batch 112700-112800 (88.57%)
# Processing batch 112800-112900 (88.65%)
# Processing batch 112900-113000 (88.73%)
# Processing batch 113000-113100 (88.81%)
# Processing batch 113100-113200 (88.89%)
# Processing batch 113200-113300 (88.97%)
# Processing batch 113300-113400 (89.05%)
# Processing batch 113400-113500 (89.12%)
# Processing batch 121200-121300 (95.25%)
# Processing batch 121300-121400 (95.33%)
# Processing batch 121400-121500 (95.41%)
# Processing batch 121500-121600 (95.49%)
# Processing batch 121600-121700 (95.57%)
# Processing batch 121700-121800 (95.65%)
# Processing batch 121800-121900 (95.73%)
# Processing batch 121900-122000 (95.80%)
# Processing batch 122000-122100 (95.88%)
# Processing batch 122100-122200 (95.96%)
# Processing batch 122200-122300 (96.04%)
# Processing batch 122300-122400 (96.12%)
# Processing batch 122400-122500 (96.20%)
# Processing batch 122500-122600 (96.28%)
# Processing batch 122600-122700 (96.35%)
# Processing batch 122700-122800 (96.43%)
# Processing batch 122800-122900 (96.51%)
# Processing batch 122900-123000 (96.59%)
# Processing batch 123000-123100 (96.67%)
# Processing batch 123100-123200 (96.75%)
# Processing batch 123200-123300 (96.83%)
# Processing batch 123300-123400 (96.90%)
# Processing batch 123400-123500 (96.98%)
# Processing batch 123500-123600 (97.06%)
# Processing batch 123600-123700 (97.14%)
# Processing batch 123700-123800 (97.22%)
# Processing batch 123800-123900 (97.30%)
# Processing batch 123900-124000 (97.38%)
# Processing batch 124000-124100 (97.45%)
# Processing batch 124100-124200 (97.53%)
# Processing batch 124200-124300 (97.61%)
# Processing batch 124300-124400 (97.69%)
# Processing batch 124400-124500 (97.77%)
# Processing batch 124500-124600 (97.85%)
# Processing batch 124600-124700 (97.93%)
# Processing batch 124700-124800 (98.00%)
# Processing batch 124800-124900 (98.08%)
# Processing batch 124900-125000 (98.16%)
# Processing batch 125000-125100 (98.24%)
# Processing batch 125100-125200 (98.32%)
# Processing batch 125200-125300 (98.40%)
# Processing batch 125300-125400 (98.48%)
# Processing batch 125400-125500 (98.55%)
# Processing batch 125500-125600 (98.63%)
# Processing batch 125600-125700 (98.71%)
# Processing batch 125700-125800 (98.79%)
# Processing batch 125800-125900 (98.87%)
# Processing batch 125900-126000 (98.95%)
# Processing batch 126000-126100 (99.03%)
# Processing batch 126100-126200 (99.10%)
# Processing batch 126200-126300 (99.18%)
# Processing batch 126300-126400 (99.26%)
# Processing batch 126400-126500 (99.34%)
# Processing batch 126500-126600 (99.42%)
# Processing batch 126600-126700 (99.50%)
# Processing batch 126700-126800 (99.58%)
# Processing batch 126800-126900 (99.65%)
# Processing batch 126900-127000 (99.73%)
# Processing batch 127000-127100 (99.81%)
# Processing batch 127100-127200 (99.89%)
# Processing batch 127200-127300 (99.97%)

# %%
# Save the mapping to a JSON file
with open("exp_output/pmid_doi_mapping.json", "w") as file:
    json.dump(pmid_doi_mapping, file)

# %%
pmid_doi_mapping
# Out:
# {'17098860': '10.1104/pp.106.086306',
#  '17921257': '10.1073/pnas.0701538104',
#  '19119024': '10.1016/j.immuni.2008.11.005',
#  '19386094': '10.1186/1471-2180-9-76',
#  '20107517': '10.1371/journal.pgen.1000818',
#  '20582282': '10.3389/neuro.15.003.2009',
#  '20661288': '10.1371/journal.pone.0011637',
#  '21775533': '10.1158/1078-0432.CCR-11-1133',
#  '22359577': '10.1371/journal.pone.0031226',
#  '35584667': None,
#  '27760788': None,
#  ...}

# %%
# Load the mapping from a JSON file
with open("exp_output/pmid_doi_mapping.json", "r") as file:
    pmid_doi_mapping_v1 = json.load(file)

# %%
# count the number of None values in the mapping
count_none = sum(1 for doi in pmid_doi_mapping_v1.values() if doi is None)
print(f"Total None values in mapping: {count_none}")
print(f"Total valid mappings: {len(pmid_doi_mapping_v1) - count_none}")
# Out:
# Total None values in mapping: 22530

# %%
doi_to_pmid_mapping = {v: k for k, v in pmid_doi_mapping_v1.items()}

# %%
len(doi_to_pmid_mapping)
# Out:
# 104710

# %%
# let's update the dataframe with the new mapping
df_groud_truth = pd.read_parquet("exp_input/PX_id_HTML_v4.parquet")

# %%
df_groud_truth.columns
# Out:
# Index(['publication', 'fetch_from', 'dataset_uid', 'repo_name', 'doi',
#        'raw_html', 'publisher', 'smallest_elements', 'title', 'keywords'],
#       dtype='object')

# %%
df_groud_truth.head()
# Out:
#                                                                                      publication  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  https://dx.doi.org/10.1001/JAMANEUROL.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            https://dx.doi.org/10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            https://dx.doi.org/10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            https://dx.doi.org/10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              https://dx.doi.org/10.1002/ADHM.202404465
#
#                                                                                       fetch_from  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  https://dx.doi.org/10.1001/jamaneurol.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            https://dx.doi.org/10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            https://dx.doi.org/10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            https://dx.doi.org/10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              https://dx.doi.org/10.1002/adhm.202404465
#
#                                                 dataset_uid repo_name  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763   pxd056570     PRIDE
# https://dx.doi.org/10.1002/1873-3468.15092        pxd057199     PRIDE
# https://dx.doi.org/10.1002/1878-0261.13654        pxd048538     PRIDE
# https://dx.doi.org/10.1002/1878-0261.13733        pxd054727     PRIDE
# https://dx.doi.org/10.1002/ADHM.202404465         pxd052728     PRIDE
#
#                                                                           doi  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  10.1001/jamaneurol.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              10.1002/adhm.202404465
#
#                                                                                           raw_html  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  <html id="doc" lang="en" class="page-article j...
# https://dx.doi.org/10.1002/1873-3468.15092       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/1878-0261.13654       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/1878-0261.13733       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/ADHM.202404465        <html lang="en" class="pb-page" data-request-i...
#
#                                                      publisher  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763    jamanetwork
# https://dx.doi.org/10.1002/1873-3468.15092       onlinelibrary
# https://dx.doi.org/10.1002/1878-0261.13654       onlinelibrary
# https://dx.doi.org/10.1002/1878-0261.13733       onlinelibrary
# https://dx.doi.org/10.1002/ADHM.202404465        onlinelibrary
#
#                                                                                  smallest_elements  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763                                                n/a
# https://dx.doi.org/10.1002/1873-3468.15092       [["<p>The COPASI files (.cps) for the model an...
# https://dx.doi.org/10.1002/1878-0261.13654       [["<p>The MS proteomics data are available at ...
# https://dx.doi.org/10.1002/1878-0261.13733       [["<p>Proteomics data generated during this st...
# https://dx.doi.org/10.1002/ADHM.202404465        [["<p>The mass spectrometry proteomics data ha...
#
#                                                                                              title  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  Characterization of A Novel Mengingoencephalom...
# https://dx.doi.org/10.1002/1873-3468.15092       Homeoviscous adaptation to exogenous fatty aci...
# https://dx.doi.org/10.1002/1878-0261.13654       LC-MSMS based (phospho)proteomics on gastric c...
# https://dx.doi.org/10.1002/1878-0261.13733       E-selectin Affinity Glycoproteomics Reveals Ne...
# https://dx.doi.org/10.1002/ADHM.202404465        in vivo-like scaffold-free 3D in vitro Models ...
#
#                                                                                           keywords
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763           Mengingoencephalomyelitis Autoantibodies
# https://dx.doi.org/10.1002/1873-3468.15092       Escherichia coli, acyl carrier protein, exogen...
# https://dx.doi.org/10.1002/1878-0261.13654       gastric cancer, phosphoproteomics, tyrosine ph...
# https://dx.doi.org/10.1002/1878-0261.13733       E-selectin, cancer glycoproteome, colorectal c...
# https://dx.doi.org/10.1002/ADHM.202404465        Cell sheet engineering, Drug treatment, Dystro...

# %%
# count how many times dx.doi.org is in df_groud_truth['publication']
count,pmcnt = 0,0
for pub in df_groud_truth['publication']:
    if pub is not None and "dx.doi.org" in pub:
        count += 1
    elif pub is not None and "pubmed" in pub:
        pmcnt += 1
print(f"Total dx.doi.org found: {count}")
print(f"Total pubmed found: {pmcnt}")
print(f"Total publications: {len(df_groud_truth['publication'])}")
print(f"Total matches: {count+pmcnt}")
# Out:
# Total dx.doi.org found: 1356
# Total pubmed found: 698
# Total publications: 2061
# Total matches: 2054

# %%
pmid_gse_mapping = df[['pubmedids','accession']].T.to_dict()

# %%
# for each pubmedids, eval string to list and then iterate over the list to get the pmid, then save mapping[pmid] = accession
pmid_gse_mapping = {}
for i, row in df.iterrows():
    lst = ast.literal_eval(row['pubmedids'])
    for pmid in lst:
        pmid_gse_mapping[pmid] = row['accession']

# %%
print(f"len: {len(pmid_gse_mapping)}")
# Out:
# len: 127239

# %%
# for each entry in ground truth, we will create a column with GSE ids. We can use the publication_col to find the DOI or the PM id
# then we can use the mapping {pmid -> doi} to find the PM id for doi
# then we can use the mapping {pmid -> gse} to find the GSE id for the PM id
count, pmcnt = 0, 0
gse_ids = {}
cnt_tot = 0

for i, row in df_groud_truth.iterrows():
    publication = row["publication"]
    
    if publication and "dx.doi.org" in publication:
        match = re.search(r'dx.doi.org/([a-zA-Z0-9./-]+)', publication)
        if match:
            doi = match.group(1)
            count += 1
            if doi in doi_to_pmid_mapping:
                pmid = doi_to_pmid_mapping[doi]  # Convert DOI to PMID
                if pmid in pmid_gse_mapping:
                    cnt_tot += 1
                    if i not in gse_ids:
                        gse_ids[i] = pmid_gse_mapping[pmid]
                    else:
                        gse_ids[i] += "," + pmid_gse_mapping[pmid]

    elif publication and "pubmed" in publication:
        match = re.search(r'pubmed/([0-9]+)', publication)
        if match:
            pmid = match.group(1)
            pmcnt += 1
            if pmid in pmid_gse_mapping:
                cnt_tot += 1
                if i not in gse_ids:
                    gse_ids[i] = pmid_gse_mapping[pmid]
                else:
                    gse_ids[i] += "," + pmid_gse_mapping[pmid]
        
print(f"Total dx.doi.org found: {count}")
print(f"Total pubmed found: {pmcnt}")
print(f"Total matches in gse: {cnt_tot}")
print(f"GSE IDs found: {len(gse_ids)}")
# Out:
# Total dx.doi.org found: 1356
# Total pubmed found: 698
# Total matches in gse: 141
# GSE IDs found: 141

# %%
# update the dataframe with the new GSE ids
for i, gse_id in gse_ids.items():
    if "gse" in gse_id.lower():
        if "gse" in str(df_groud_truth.at[i, "dataset_uid"]):
            df_groud_truth.at[i, "dataset_uid"] += "," + gse_id
        else:
            df_groud_truth.at[i, "dataset_uid"] = gse_id
# Out:
# Updating row https://dx.doi.org/10.1002/advs.202300043 with GSE ID: GSE204773
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[63], line 4
#       2 for i, gse_id in gse_ids.items():
#       3     print(f"Updating row {i} with GSE ID: {gse_id}")
# ----> 4     1/0
#       5     if "gse" in gse_id:
#       6         if "gse" in str(df_groud_truth.at[i, "dataset_uid"]):
#
# ZeroDivisionError: division by zero

# %%
# # use False Positives from a data-gatherer model run
# gse_FPs = []
# # Sample false positives load from txt file where separated by newline
# with open("exp_output/model_FPs.txt", "r") as file:
#     false_positives = file.read().splitlines()
# 
# for fp in false_positives:
#     if 'gse' in fp and 'https' in fp:
#         fp = fp.split("=")[-1]
#         gse_FPs.append(fp)
#     elif 'gse' in fp:
#         gse_FPs.append(fp)
# 
# print(f"Total false positives found: {len(gse_FPs)}")

# %%
# # no capital case in accession
# df["accession"] = df["accession"].astype(str).str.lower()
# # iterate
# i = 0
# gse_uids = []
# for fp in gse_FPs:
#     # check if false positive is in the dataset
#     if fp in df["accession"].values:
#         i+=1
#         # drop false positive from dataset
#         #print(f"False positive {fp} FOUND in dataset.")
#         gse_uids.append(fp)
#     else:
#         print(f"False positive {fp} NOT FOUND in dataset.")
# 
# print(f"Total false positives found also in local GEO data: {i}")
# #print(f"Unique false positives found: {len(set(gse_uids))}")

# %%
# # get all false positives from dataframe
# df_FPs = df[df["accession"].isin(gse_uids)]
# df_FPs

# %%
# function to get PMCid and doi from pubmed id
config_path = 'config_experiment.json'  # Config with input file details
load_dotenv()
orchestrator = Orchestrator(config_path)
orchestrator.setup_data_fetcher()

# %%
for i, row in df_FPs.iterrows():
    pubmed_id = row["pubmedids"]
    orchestrator.logger.info(f"PubMed id: {pubmed_id} --item {i+1}")  
    
    # Convert string representation of list to an actual list
    if isinstance(pubmed_id, str) and pubmed_id.startswith("["):
        pubmed_id = ast.literal_eval(pubmed_id)  # Converts to a real list
        pubmed_ids = pubmed_id if pubmed_id else None  # Extract the first element
        
    if pubmed_ids is None:    
        orchestrator.logger.info(f"pubmed_ids is None")  
        continue

    orchestrator.logger.info(f"Type of elements in pubmed_ids <class 'list'>: {[type(item) for item in pubmed_ids]}")  # Should now be <class 'str'>
    
    pmc_ids, dois = [], []
    
    for pmid in pubmed_ids:    
        pmc_id, doi = orchestrator.data_fetcher.get_opendata_from_pubmed_id(pmid)
        pmc_ids.append(pmc_id)
        dois.append(doi)
        
    orchestrator.logger.info(f"PMC ID: {pmc_ids}")
    orchestrator.logger.info(f"DOI: {dois}\n")
    
    #Store results
    df_FPs.loc[i, "pmcids"] = ",".join([str(x) for x in pmc_ids if x]) if any(pmc_ids) else None
    df_FPs.loc[i, "dois"] = ",".join([str(x) for x in dois if x]) if any(dois) else None

orchestrator.data_fetcher.quit()

# %%
print(f"Shape: {df_FPs.shape}")
print(f"Columns: {df_FPs.columns}")

# %%
df_FPs_copy = df_FPs.copy()

# %%
df1 = pd.read_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")
df1 = df1.drop(columns=["Unnamed: 0"]) if "Unnamed: 0" in df1.columns else df1
print(f"Shape: {df1.shape}")
print(f"Columns: {df1.columns}")

# %%
df1[['publication', 'dataset_uid', 'repo_name', 'doi']]

# %%
df_FPs.loc[:, "dois"] = df_FPs["dois"].astype(str).str.lower()
df1.loc[:, "doi"] = df1['doi'].astype(str).str.lower()

print(f'FP DOI: {df_FPs["dois"]}')

for dois in df_FPs["dois"]:
    for doi in dois.split(","):
        if doi == "nan":
            continue
        if doi in df1["doi"].values:
            print(f"DOI {doi} found in df1")
        else:
            continue

# %%
# explode the dois column which is a string of multiple dois separated by commas
df_FPs = df_FPs.assign(dois=df_FPs["dois"].str.split(",")).explode("dois")
df_FPs

# %%
# Create mapping of DOI to concatenated GSE accession codes
doi_to_gse = (
    df_FPs.groupby("dois")["accession"]
    .apply(lambda x: ",".join(set(x.astype(str))))  # Ensures unique values
    .to_dict()
)

doi_to_gse.pop("nan")  # Remove any NaN keys
doi_to_gse

# %%
for i,row in df1.iterrows():
    doi = row["doi"].lower()
    if doi == "nan" or doi is None:
        continue
    elif doi in doi_to_gse.keys():
        print(f"DOI: {doi} -- GSE: {doi_to_gse[doi]}")
        # update value at dataset_uid by appending GSE
        dataset_uid = df1.loc[i, "dataset_uid"] + "," + doi_to_gse[doi]
        df1.at[i, "dataset_uid"] = dataset_uid
    else:
        continue

# %%
df1[["publication","dataset_uid","doi"]]

# %%
df1.to_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")

# %%
# df1["doi"]

# %%
# # Function to find matching GSE codes for a given publication
# def find_matching_gse(publication, doi_dict):
#     matched_gse_codes = set()  # Use a set to avoid duplicates
#     
#     if pd.notna(publication):  # Ensure publication is not NaN
#         pub_lower = publication.lower().strip()  # Normalize publication case
#         
#         for doi_group, gse_codes in doi_dict.items():
#             # Split the multiple DOIs stored in the key
#             individual_dois = [doi.strip().lower() for doi in doi_group.split(",")]
#             
#             # Check if any of the individual DOIs is a substring of the publication
#             if any(doi in pub_lower for doi in individual_dois):
#                 matched_gse_codes.update(gse_codes.split(","))  # Add each GSE ID separately
# 
#     return ",".join(sorted(matched_gse_codes)) if matched_gse_codes else None  # Ensure consistent ordering
# 
# # Apply the function to find matches and update dataset_uid
# df1["new_dataset_uids"] = df1["doi"].apply(lambda pub: find_matching_gse(pub, doi_to_gse))
# 
# # Concatenate new dataset IDs with existing ones (if any)
# df1["dataset_uid"] = df1.apply(
#     lambda row: f"{row['dataset_uid']},{row['new_dataset_uids']}" if pd.notna(row["new_dataset_uids"]) else row["dataset_uid"], axis=1
# )
# 
# # Remove unnecessary column and strip redundant commas
# df1.drop(columns=["new_dataset_uids"], inplace=True)
# df1["dataset_uid"] = df1["dataset_uid"].str.strip(",")

# %%
# df1[["publication","dataset_uid"]]

# %%
# df1.to_csv("exp_input/PRIDE_GSE_id_HTML_data.csv")

# %%
# we have dataframe df1 with all our scraped Ground Truth data (raw_html, publication, dataset_uid, ...)
# we have dataframe df_FPs with all our (supposedly) false positives on Ground Truth (accession, pmcid, doi)
# with the previous steps in the GEO dataset creation notebook, we now have ground truth for these "False Positives"
# look for matches, then update ground truth with the new data

# for i, row in df1.iterrows():
#     publication = row["publication"].lower()
#     for fp in df_FPs["doi"]:
#         fp = fp.lower()
#         if fp is not None and (fp in publication or fp == publication):
#             print(f"Publication: {publication}")
#             print(f"DOI of ex-false positive: {fp}")
#             vals = df_FPs[df_FPs["doi"] == fp]
#             print(f"ex-False Positive id: {vals['accession'].values}")
#             addenda = ',' + df_FPs[df_FPs["doi"] == fp]["accession"].values
#             #df1.at[i, "dataset_uid"] += addenda
#             #print(df1.at[i, "dataset_uid"])
#             #print(addenda)
#         elif fp is None:
#             print(None)

# %%
df_10 = pd.read_parquet("exp_input/PX_id_HTML_v4.parquet")

# %%
df_10['publisher'].value_counts()
# Out:
# publisher
# pubmed              698
# sciencedirect       259
# nature              208
# cytoscape           182
# mdpi                 83
#                    ...
# icm-experimental      1
# cshlp                 1
# iucr                  1
# karger                1
# jamanetwork           1
# Name: count, Length: 63, dtype: int64

# %%
df_10[df_10['publisher']=='proteomexchange']
# Out:
#                                                                publication  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  https://dx.doi.org/10.6019/PXD051338
# https://dx.doi.org/10.6019/PXD051588  https://dx.doi.org/10.6019/PXD051588
# https://dx.doi.org/10.6019/PXD051745  https://dx.doi.org/10.6019/PXD051745
# https://dx.doi.org/10.6019/PXD051771  https://dx.doi.org/10.6019/PXD051771
# https://dx.doi.org/10.6019/PXD052143  https://dx.doi.org/10.6019/PXD052143
# ...                                                                    ...
# https://dx.doi.org/10.6019/PXD059791  https://dx.doi.org/10.6019/PXD059791
# https://dx.doi.org/10.6019/PXD059803  https://dx.doi.org/10.6019/PXD059803
# https://dx.doi.org/10.6019/PXD059817  https://dx.doi.org/10.6019/PXD059817
# https://dx.doi.org/10.6019/PXD059868  https://dx.doi.org/10.6019/PXD059868
# https://dx.doi.org/10.6019/PXD059932  https://dx.doi.org/10.6019/PXD059932
#
#                                                                 fetch_from  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  https://dx.doi.org/10.6019/pxd051338
# https://dx.doi.org/10.6019/PXD051588  https://dx.doi.org/10.6019/pxd051588
# https://dx.doi.org/10.6019/PXD051745  https://dx.doi.org/10.6019/pxd051745
# https://dx.doi.org/10.6019/PXD051771  https://dx.doi.org/10.6019/pxd051771
# https://dx.doi.org/10.6019/PXD052143  https://dx.doi.org/10.6019/pxd052143
# ...                                                                    ...
# https://dx.doi.org/10.6019/PXD059791  https://dx.doi.org/10.6019/pxd059791
# https://dx.doi.org/10.6019/PXD059803  https://dx.doi.org/10.6019/pxd059803
# https://dx.doi.org/10.6019/PXD059817  https://dx.doi.org/10.6019/pxd059817
# https://dx.doi.org/10.6019/PXD059868  https://dx.doi.org/10.6019/pxd059868
# https://dx.doi.org/10.6019/PXD059932  https://dx.doi.org/10.6019/pxd059932
#
#                                      dataset_uid repo_name                doi  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338   pxd051338     PRIDE  10.6019/pxd051338
# https://dx.doi.org/10.6019/PXD051588   pxd051588     PRIDE  10.6019/pxd051588
# https://dx.doi.org/10.6019/PXD051745   pxd051745     PRIDE  10.6019/pxd051745
# https://dx.doi.org/10.6019/PXD051771   pxd051771     PRIDE  10.6019/pxd051771
# https://dx.doi.org/10.6019/PXD052143   pxd052143     PRIDE  10.6019/pxd052143
# ...                                          ...       ...                ...
# https://dx.doi.org/10.6019/PXD059791   pxd059791     PRIDE  10.6019/pxd059791
# https://dx.doi.org/10.6019/PXD059803   pxd059803     PRIDE  10.6019/pxd059803
# https://dx.doi.org/10.6019/PXD059817   pxd059817     PRIDE  10.6019/pxd059817
# https://dx.doi.org/10.6019/PXD059868   pxd059868     PRIDE  10.6019/pxd059868
# https://dx.doi.org/10.6019/PXD059932   pxd059932     PRIDE  10.6019/pxd059932
#
#                                                                                raw_html  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD051588  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD051745  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD051771  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD052143  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# ...                                                                                 ...
# https://dx.doi.org/10.6019/PXD059791  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD059803  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD059817  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD059868  <html xmlns="http://www.w3.org/1999/xhtml" lan...
# https://dx.doi.org/10.6019/PXD059932  <html xmlns="http://www.w3.org/1999/xhtml" lan...
#
#                                             publisher  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  proteomexchange
# https://dx.doi.org/10.6019/PXD051588  proteomexchange
# https://dx.doi.org/10.6019/PXD051745  proteomexchange
# https://dx.doi.org/10.6019/PXD051771  proteomexchange
# https://dx.doi.org/10.6019/PXD052143  proteomexchange
# ...                                               ...
# https://dx.doi.org/10.6019/PXD059791  proteomexchange
# https://dx.doi.org/10.6019/PXD059803  proteomexchange
# https://dx.doi.org/10.6019/PXD059817  proteomexchange
# https://dx.doi.org/10.6019/PXD059868  proteomexchange
# https://dx.doi.org/10.6019/PXD059932  proteomexchange
#
#                                                                       smallest_elements  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD051588  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD051745  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD051771  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD052143  [["<table class=\"dataset-summary\"><tbody><tr...
# ...                                                                                 ...
# https://dx.doi.org/10.6019/PXD059791  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD059803  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD059817  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD059868  [["<table class=\"dataset-summary\"><tbody><tr...
# https://dx.doi.org/10.6019/PXD059932  [["<table class=\"dataset-summary\"><tbody><tr...
#
#                                                                                   title  \
# fetch_from
# https://dx.doi.org/10.6019/PXD051338  Peptide mass fingerprinting to investigate if ...
# https://dx.doi.org/10.6019/PXD051588  STRUCTURE OF APOLIPOPROTEIN B100 BOUND TO LOW-...
# https://dx.doi.org/10.6019/PXD051745  The Protein Composition of Human Adenovirus Re...
# https://dx.doi.org/10.6019/PXD051771  N-Glycosylation-Defective IL6 Alternatively Ac...
# https://dx.doi.org/10.6019/PXD052143  Cardio-metabolic and cytoskeletal proteomic si...
# ...                                                                                 ...
# https://dx.doi.org/10.6019/PXD059791  Forced Intracellular degradation of Xenoantige...
# https://dx.doi.org/10.6019/PXD059803  Genetic analysis of arabidopsis autophagy-rela...
# https://dx.doi.org/10.6019/PXD059817  Composition and liquid-to-solid maturation of ...
# https://dx.doi.org/10.6019/PXD059868  Composition and liquid-to-solid maturation of ...
# https://dx.doi.org/10.6019/PXD059932  Urinary bacteriophage cooperation with bacteri...
#
#                                                                                keywords
# fetch_from
# https://dx.doi.org/10.6019/PXD051338                                 DHFR variants, PMF
# https://dx.doi.org/10.6019/PXD051588  apolipoprotein B100, cardiovascular disease, c...
# https://dx.doi.org/10.6019/PXD051745  HMGB1, Human adenovirus (HAdV), biomolecular  ...
# https://dx.doi.org/10.6019/PXD051771  EGFR-TKI resistance, EMT, IL6, SRC, YAP, glyco...
# https://dx.doi.org/10.6019/PXD052143  Duchenne muscular dystrophy, cytoskeletal orga...
# ...                                                                                 ...
# https://dx.doi.org/10.6019/PXD059791  cell-based cancer immunotherapy, immunopeptido...
# https://dx.doi.org/10.6019/PXD059803  AIM, ATG8, Autophagy, LDS, Nutrient recycling,...
# https://dx.doi.org/10.6019/PXD059817  Bacterial Dormancy/ Protein Aggregation/ Energ...
# https://dx.doi.org/10.6019/PXD059868  Bacterial Dormancy/ Protein Aggregation/ Energ...
# https://dx.doi.org/10.6019/PXD059932  Biology/Disease-Driven Human Proteome Project ...
#
# [76 rows x 10 columns]

# %%
df_10.columns
# Out:
# Index(['publication', 'fetch_from', 'dataset_uid', 'repo_name', 'doi',
#        'raw_html', 'publisher', 'smallest_elements', 'title', 'keywords'],
#       dtype='object')

# %%
df_10.head()
# Out:
#                                                                                      publication  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  https://dx.doi.org/10.1001/JAMANEUROL.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            https://dx.doi.org/10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            https://dx.doi.org/10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            https://dx.doi.org/10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              https://dx.doi.org/10.1002/ADHM.202404465
#
#                                                                                       fetch_from  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  https://dx.doi.org/10.1001/jamaneurol.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            https://dx.doi.org/10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            https://dx.doi.org/10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            https://dx.doi.org/10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              https://dx.doi.org/10.1002/adhm.202404465
#
#                                                 dataset_uid repo_name  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763   pxd056570     PRIDE
# https://dx.doi.org/10.1002/1873-3468.15092        pxd057199     PRIDE
# https://dx.doi.org/10.1002/1878-0261.13654        pxd048538     PRIDE
# https://dx.doi.org/10.1002/1878-0261.13733        pxd054727     PRIDE
# https://dx.doi.org/10.1002/ADHM.202404465         pxd052728     PRIDE
#
#                                                                           doi  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  10.1001/jamaneurol.2024.4763
# https://dx.doi.org/10.1002/1873-3468.15092            10.1002/1873-3468.15092
# https://dx.doi.org/10.1002/1878-0261.13654            10.1002/1878-0261.13654
# https://dx.doi.org/10.1002/1878-0261.13733            10.1002/1878-0261.13733
# https://dx.doi.org/10.1002/ADHM.202404465              10.1002/adhm.202404465
#
#                                                                                           raw_html  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  <html id="doc" lang="en" class="page-article j...
# https://dx.doi.org/10.1002/1873-3468.15092       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/1878-0261.13654       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/1878-0261.13733       <html lang="en" class="pb-page" data-request-i...
# https://dx.doi.org/10.1002/ADHM.202404465        <html lang="en" class="pb-page" data-request-i...
#
#                                                      publisher  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763    jamanetwork
# https://dx.doi.org/10.1002/1873-3468.15092       onlinelibrary
# https://dx.doi.org/10.1002/1878-0261.13654       onlinelibrary
# https://dx.doi.org/10.1002/1878-0261.13733       onlinelibrary
# https://dx.doi.org/10.1002/ADHM.202404465        onlinelibrary
#
#                                                                                  smallest_elements  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763                                                n/a
# https://dx.doi.org/10.1002/1873-3468.15092       [["<p>The COPASI files (.cps) for the model an...
# https://dx.doi.org/10.1002/1878-0261.13654       [["<p>The MS proteomics data are available at ...
# https://dx.doi.org/10.1002/1878-0261.13733       [["<p>Proteomics data generated during this st...
# https://dx.doi.org/10.1002/ADHM.202404465        [["<p>The mass spectrometry proteomics data ha...
#
#                                                                                              title  \
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763  Characterization of A Novel Mengingoencephalom...
# https://dx.doi.org/10.1002/1873-3468.15092       Homeoviscous adaptation to exogenous fatty aci...
# https://dx.doi.org/10.1002/1878-0261.13654       LC-MSMS based (phospho)proteomics on gastric c...
# https://dx.doi.org/10.1002/1878-0261.13733       E-selectin Affinity Glycoproteomics Reveals Ne...
# https://dx.doi.org/10.1002/ADHM.202404465        in vivo-like scaffold-free 3D in vitro Models ...
#
#                                                                                           keywords
# fetch_from
# https://dx.doi.org/10.1001/JAMANEUROL.2024.4763           Mengingoencephalomyelitis Autoantibodies
# https://dx.doi.org/10.1002/1873-3468.15092       Escherichia coli, acyl carrier protein, exogen...
# https://dx.doi.org/10.1002/1878-0261.13654       gastric cancer, phosphoproteomics, tyrosine ph...
# https://dx.doi.org/10.1002/1878-0261.13733       E-selectin, cancer glycoproteome, colorectal c...
# https://dx.doi.org/10.1002/ADHM.202404465        Cell sheet engineering, Drug treatment, Dystro...

# %%
fetched_data_path = "exp_input/fetched_data.parquet"

fetched_df = pd.read_parquet(fetched_data_path)
