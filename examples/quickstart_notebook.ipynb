# %% [markdown]
# # Quickstart

# %%
from data_gatherer.data_gatherer import DataGatherer

# %% [markdown]
# Instantiate DataGatherer and select which LLM to use.

# %% [markdown]
# To provide the api key you can either add it in an `.env` file in the working directory or set an environment variable for that.

# %%
data_gatherer = DataGatherer(llm_name="gemini-2.0-flash")

# %% [markdown]
# ## Extracting Dataset Citations from Papers
#
# Given one or more scientific publications, you can provide the url to their full-text - or path to the PDF file - as input for the DataGatherer.

# %%
input_articles = ["https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466"]

# %% [markdown]
# Then, with the `process_articles` method, you can extract information from the full-text of the scientific publication and have a summary of the Datasets used in the study.
#
# You can use the `section_filter` parameter to specify which section you want to extract data from (supplementary_material or data_availability_statement).

# %%
article_available_data = data_gatherer.process_articles(input_articles, section_filter='data_availability_statement', semantic_retrieval=True)
article_available_data["https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466"]
# Out:
# /Users/pietro/Desktop/VIDA-NYU/data-gatherer/data_gatherer/data_fetcher.py:842: FutureWarning: Truth-testing of elements was a source of confusion and will always return True in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   if backup_data:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#   dataset_identifier data_repository  \
# 0          PHS001049           dbgap
# 1        PRJNA306801             sra
#
#                                      dataset_webpage citation_type  \
# 0  https://www.ncbi.nlm.nih.gov/projects/gap/cgi-...           n/a
# 1  https://www.ncbi.nlm.nih.gov/bioproject/?term=...           n/a
#
#       source_section  retrieval_pattern            access_mode  \
# 0  data_availability  data availability  Application to access
# 1  data_availability  data availability       Complex download
#
#                                            pub_title  \
# 0  Recurrent WNT pathway alterations are frequent...
# 1  Recurrent WNT pathway alterations are frequent...
#
#                                           source_url raw_data_format
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...             XML
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...             XML

# %%
article_supplementary_material = data_gatherer.process_articles(input_articles, section_filter='supplementary_material')
article_supplementary_material["https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466"]
# Out:
# /Users/pietro/Desktop/VIDA-NYU/data-gatherer/data_gatherer/data_fetcher.py:842: FutureWarning: Truth-testing of elements was a source of confusion and will always return True in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   if backup_data:
#                                 link  \
# 0     41467_2018_6162_MOESM1_ESM.pdf
# 1     41467_2018_6162_MOESM2_ESM.pdf
# 2     41467_2018_6162_MOESM3_ESM.pdf
# 3    41467_2018_6162_MOESM4_ESM.xlsx
# 4    41467_2018_6162_MOESM5_ESM.xlsx
# 5    41467_2018_6162_MOESM6_ESM.xlsx
# 6    41467_2018_6162_MOESM7_ESM.xlsx
# 7    41467_2018_6162_MOESM8_ESM.xlsx
# 8    41467_2018_6162_MOESM9_ESM.xlsx
# 9   41467_2018_6162_MOESM10_ESM.xlsx
# 10  41467_2018_6162_MOESM11_ESM.xlsx
# 11  41467_2018_6162_MOESM12_ESM.xlsx
# 12  41467_2018_6162_MOESM13_ESM.xlsx
# 13  41467_2018_6162_MOESM14_ESM.xlsx
# 14  41467_2018_6162_MOESM15_ESM.xlsx
#
#                                            source_url  \
# 0   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 2   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 3   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 4   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 5   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 6   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 7   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 8   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 9   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 10  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 12  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 13  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 14  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                         download_link     title content_type  \
# 0   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 1   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 2   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 3   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 4   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 5   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 6   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 7   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 8   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 9   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 10  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 11  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 12  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 13  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 14  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
#
#          id                                        caption  \
# 0    MOESM1                      Supplementary Information
# 1    MOESM2                               Peer Review File
# 2    MOESM3  Description of Additional Supplementary Files
# 3    MOESM4                           Supplementary Data 1
# 4    MOESM5                           Supplementary Data 2
# 5    MOESM6                           Supplementary Data 3
# 6    MOESM7                           Supplementary Data 4
# 7    MOESM8                           Supplementary Data 5
# 8    MOESM9                           Supplementary Data 6
# 9   MOESM10                           Supplementary Data 7
# 10  MOESM11                           Supplementary Data 8
# 11  MOESM12                           Supplementary Data 9
# 12  MOESM13                          Supplementary Data 10
# 13  MOESM14                          Supplementary Data 11
# 14  MOESM15                          Supplementary Data 12
#
#                                           description          source_section  \
# 0                          Supplementary  Information  supplementary material
# 1                                  Peer  Review  File  supplementary material
# 2   Description  of  Additional  Supplementary  Files  supplementary material
# 3                              Supplementary  Data  1  supplementary material
# 4                              Supplementary  Data  2  supplementary material
# 5                              Supplementary  Data  3  supplementary material
# 6                              Supplementary  Data  4  supplementary material
# 7                              Supplementary  Data  5  supplementary material
# 8                              Supplementary  Data  6  supplementary material
# 9                              Supplementary  Data  7  supplementary material
# 10                             Supplementary  Data  8  supplementary material
# 11                             Supplementary  Data  9  supplementary material
# 12                            Supplementary  Data  10  supplementary material
# 13                            Supplementary  Data  11  supplementary material
# 14                            Supplementary  Data  12  supplementary material
#
#             retrieval_pattern  \
# 0   .//supplementary-material
# 1   .//supplementary-material
# 2   .//supplementary-material
# 3   .//supplementary-material
# 4   .//supplementary-material
# 5   .//supplementary-material
# 6   .//supplementary-material
# 7   .//supplementary-material
# 8   .//supplementary-material
# 9   .//supplementary-material
# 10  .//supplementary-material
# 11  .//supplementary-material
# 12  .//supplementary-material
# 13  .//supplementary-material
# 14  .//supplementary-material
#
#                                   context_description file_extension  \
# 0   Representative slides from these samples were ...            pdf
# 1                                                                pdf
# 2                                                                pdf
# 3   Representative slides from these samples were ...           xlsx
# 4                                                               xlsx
# 5                                                               xlsx
# 6                                                               xlsx
# 7                                                               xlsx
# 8                                                               xlsx
# 9                                                               xlsx
# 10                                                              xlsx
# 11                                                              xlsx
# 12                                                              xlsx
# 13                                                              xlsx
# 14                                                              xlsx
#
#                                             pub_title raw_data_format
# 0   Recurrent WNT pathway alterations are frequent...             XML
# 1   Recurrent WNT pathway alterations are frequent...             XML
# 2   Recurrent WNT pathway alterations are frequent...             XML
# 3   Recurrent WNT pathway alterations are frequent...             XML
# 4   Recurrent WNT pathway alterations are frequent...             XML
# 5   Recurrent WNT pathway alterations are frequent...             XML
# 6   Recurrent WNT pathway alterations are frequent...             XML
# 7   Recurrent WNT pathway alterations are frequent...             XML
# 8   Recurrent WNT pathway alterations are frequent...             XML
# 9   Recurrent WNT pathway alterations are frequent...             XML
# 10  Recurrent WNT pathway alterations are frequent...             XML
# 11  Recurrent WNT pathway alterations are frequent...             XML
# 12  Recurrent WNT pathway alterations are frequent...             XML
# 13  Recurrent WNT pathway alterations are frequent...             XML
# 14  Recurrent WNT pathway alterations are frequent...             XML
