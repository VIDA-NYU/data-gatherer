# %% [markdown]
# # Workflows Example

# %%
import pandas as pd

from data_gatherer.data_gatherer import DataGatherer

# %% [markdown]
# Instantiate the DataGatherer orchestrator

# %%
data_gatherer = DataGatherer(llm_name="gemini-2.0-flash", log_level="ERROR")

# %% [markdown]
# ## Step I: Fetch data

# %% [markdown]
# The Fetcher is responsible for fetching raw data about scientific publications on the internet. The parent class is DataFetcher, and the child classes are the following:
#
#
#
# - **WebScraper**, given a URL, it scrapes the page extracting the HTML content.
#
#
# - **DatabaseFetcher**, given a key, it fetches raw data (HTML or XML) from a local DataFrame.
#
#
# - **APIClient**, given a URI, it fetches raw data (XML) from an API.

# %%
data_gatherer.setup_data_fetcher()

# %% [markdown]
# ### Fetch from API
#
# When the API is supported (for now only PubMedCentral), the fetcher will use the APIClient to fetch the data in XML format.

# %%
API_supported_input = "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6141466"

# %%
raw_data_API = data_gatherer.fetch_data(API_supported_input)

# %% [markdown]
# ### Fetch from Local Data
#
# Show the structure of the local DataFrame

# %%
pd.read_parquet("../scripts/exp_input/Local_fetched_data.parquet").head(2)
# Out:
#                                            file_name  \
# 0  miR-33b-3p Acts as a Tumor Suppressor by Targe...
# 1  Murine neuronatin deficiency is associated wit...
#
#                                             raw_cont format  length  \
# 0  <html lang="en" class=""><head>\n\n        <me...   html  205313
# 1  <html lang="en" class=""><head>\n\n        <me...   html  238825
#
#                                                 path publication
# 0  ../html_xml_samples/PMC/miR-33b-3p Acts as a T...  pmc8595470
# 1  ../html_xml_samples/PMC/Murine neuronatin defi...  pmc8413370

# %%
local_fetch_supported_input = "https://www.ncbi.nlm.nih.gov/pmc/articles/pmc11425778"

# %%
raw_data_local = data_gatherer.fetch_data(local_fetch_supported_input, local_fetch_file="../scripts/exp_input/Local_fetched_data.parquet")

# %% [markdown]
# ### Fetch Raw HTML from a web page

# %%
API_unsupported_input = "https://www.nature.com/articles/s41467-024-51831-7"

# %%
raw_html = data_gatherer.fetch_data(API_unsupported_input, browser='Firefox', headless=True)

# %% [markdown]
# ## Step II: Parse data
#
# The Parser is responsible for extracting the relevant information from the raw documents fetched by the Fetcher. It has two main discovery methods:
#
#
# - **Retrieve-Then-Read**, the parser passes to the LLMs only the relevant sections of the raw document, and the LLMs extract the relevant information.
#
#
# - **Full-Document-Read**, Large-context LLMs read the entire raw document and extract the relevant information.

# %% [markdown]
# ### Retrieve-Then-Read
# version 0.1.0 supports this parse method only for PMC XML and HTML documents

# %%
results_RTR = data_gatherer.parse_data(API_supported_input, raw_data_API, publisher="PMC", use_portkey_for_gemini=True, prompt_name="retrieve_datasets_simple_JSON")
results_RTR
# Out:
#    dataset_identifier data_repository  \
# 0           PHS001049           dbgap
# 1         PRJNA306801             sra
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# 5                 NaN             NaN
# 6                 NaN             NaN
# 7                 NaN             NaN
# 8                 NaN             NaN
# 9                 NaN             NaN
# 10                NaN             NaN
# 11                NaN             NaN
# 12                NaN             NaN
# 13                NaN             NaN
# 14                NaN             NaN
#
#                                       dataset_webpage          source_section  \
# 0   https://www.ncbi.nlm.nih.gov/projects/gap/cgi-...       data_availability
# 1   https://www.ncbi.nlm.nih.gov/bioproject/?term=...       data_availability
# 0                                                 NaN  supplementary material
# 1                                                 NaN  supplementary material
# 2                                                 NaN  supplementary material
# 3                                                 NaN  supplementary material
# 4                                                 NaN  supplementary material
# 5                                                 NaN  supplementary material
# 6                                                 NaN  supplementary material
# 7                                                 NaN  supplementary material
# 8                                                 NaN  supplementary material
# 9                                                 NaN  supplementary material
# 10                                                NaN  supplementary material
# 11                                                NaN  supplementary material
# 12                                                NaN  supplementary material
# 13                                                NaN  supplementary material
# 14                                                NaN  supplementary material
#
#             retrieval_pattern            access_mode  \
# 0           data availability  Application to access
# 1           data availability       Complex download
# 0   .//supplementary-material                    NaN
# 1   .//supplementary-material                    NaN
# 2   .//supplementary-material                    NaN
# 3   .//supplementary-material                    NaN
# 4   .//supplementary-material                    NaN
# 5   .//supplementary-material                    NaN
# 6   .//supplementary-material                    NaN
# 7   .//supplementary-material                    NaN
# 8   .//supplementary-material                    NaN
# 9   .//supplementary-material                    NaN
# 10  .//supplementary-material                    NaN
# 11  .//supplementary-material                    NaN
# 12  .//supplementary-material                    NaN
# 13  .//supplementary-material                    NaN
# 14  .//supplementary-material                    NaN
#
#                                 link  \
# 0                                NaN
# 1                                NaN
# 0     41467_2018_6162_MOESM1_ESM.pdf
# 1     41467_2018_6162_MOESM2_ESM.pdf
# 2     41467_2018_6162_MOESM3_ESM.pdf
# 3    41467_2018_6162_MOESM4_ESM.xlsx
# 4    41467_2018_6162_MOESM5_ESM.xlsx
# 5    41467_2018_6162_MOESM6_ESM.xlsx
# 6    41467_2018_6162_MOESM7_ESM.xlsx
# 7    41467_2018_6162_MOESM8_ESM.xlsx
# 8    41467_2018_6162_MOESM9_ESM.xlsx
# 9   41467_2018_6162_MOESM10_ESM.xlsx
# 10  41467_2018_6162_MOESM11_ESM.xlsx
# 11  41467_2018_6162_MOESM12_ESM.xlsx
# 12  41467_2018_6162_MOESM13_ESM.xlsx
# 13  41467_2018_6162_MOESM14_ESM.xlsx
# 14  41467_2018_6162_MOESM15_ESM.xlsx
#
#                                            source_url  \
# 0                                                 NaN
# 1                                                 NaN
# 0   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 2   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 3   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 4   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 5   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 6   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 7   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 8   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 9   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 10  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 11  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 12  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 13  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 14  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                         download_link     title content_type  \
# 0                                                 NaN       NaN          NaN
# 1                                                 NaN       NaN          NaN
# 0   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 1   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 2   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 3   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 4   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 5   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 6   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 7   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 8   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 9   https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 10  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 11  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 12  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 13  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
# 14  https://pmc.ncbi.nlm.nih.gov/articles/instance...  No Title   local-data
#
#          id                                        caption  \
# 0       NaN                                            NaN
# 1       NaN                                            NaN
# 0    MOESM1                      Supplementary Information
# 1    MOESM2                               Peer Review File
# 2    MOESM3  Description of Additional Supplementary Files
# 3    MOESM4                           Supplementary Data 1
# 4    MOESM5                           Supplementary Data 2
# 5    MOESM6                           Supplementary Data 3
# 6    MOESM7                           Supplementary Data 4
# 7    MOESM8                           Supplementary Data 5
# 8    MOESM9                           Supplementary Data 6
# 9   MOESM10                           Supplementary Data 7
# 10  MOESM11                           Supplementary Data 8
# 11  MOESM12                           Supplementary Data 9
# 12  MOESM13                          Supplementary Data 10
# 13  MOESM14                          Supplementary Data 11
# 14  MOESM15                          Supplementary Data 12
#
#                                           description file_extension  \
# 0                                                 NaN           None
# 1                                                 NaN           None
# 0                          Supplementary  Information            pdf
# 1                                  Peer  Review  File            pdf
# 2   Description  of  Additional  Supplementary  Files            pdf
# 3                              Supplementary  Data  1           xlsx
# 4                              Supplementary  Data  2           xlsx
# 5                              Supplementary  Data  3           xlsx
# 6                              Supplementary  Data  4           xlsx
# 7                              Supplementary  Data  5           xlsx
# 8                              Supplementary  Data  6           xlsx
# 9                              Supplementary  Data  7           xlsx
# 10                             Supplementary  Data  8           xlsx
# 11                             Supplementary  Data  9           xlsx
# 12                            Supplementary  Data  10           xlsx
# 13                            Supplementary  Data  11           xlsx
# 14                            Supplementary  Data  12           xlsx
#
#                                             pub_title
# 0   Recurrent WNT pathway alterations are frequent...
# 1   Recurrent WNT pathway alterations are frequent...
# 0   Recurrent WNT pathway alterations are frequent...
# 1   Recurrent WNT pathway alterations are frequent...
# 2   Recurrent WNT pathway alterations are frequent...
# 3   Recurrent WNT pathway alterations are frequent...
# 4   Recurrent WNT pathway alterations are frequent...
# 5   Recurrent WNT pathway alterations are frequent...
# 6   Recurrent WNT pathway alterations are frequent...
# 7   Recurrent WNT pathway alterations are frequent...
# 8   Recurrent WNT pathway alterations are frequent...
# 9   Recurrent WNT pathway alterations are frequent...
# 10  Recurrent WNT pathway alterations are frequent...
# 11  Recurrent WNT pathway alterations are frequent...
# 12  Recurrent WNT pathway alterations are frequent...
# 13  Recurrent WNT pathway alterations are frequent...
# 14  Recurrent WNT pathway alterations are frequent...

# %%
results_RTR = data_gatherer.parse_data(local_fetch_supported_input, raw_data_local, publisher="PMC", use_portkey_for_gemini=True, prompt_name="retrieve_datasets_simple_JSON", raw_data_format="HTML")
results_RTR
# Out:
#   dataset_identifier   data_repository  \
# 0       MSV000092944  massive.ucsd.edu
# 0                NaN               NaN
# 8                NaN               NaN
#
#                                      dataset_webpage       access_mode  \
# 0  https://massive.ucsd.edu/ProteoSAFe/dataset.js...  Complex download
# 0                                                NaN               NaN
# 8                                                NaN               NaN
#
#                                                 link  \
# 0                                                NaN
# 0      https://doi.org/10.1021/acs.jproteome.4c00338
# 8  /articles/instance/11425778/bin/NIHMS2020672-s...
#
#                             title     file_info description source_section  \
# 0                             NaN           NaN         NaN            NaN
# 0   10.1021/acs.jproteome.4c00338           n/a         n/a            n/a
# 8  NIHMS2020672-supplement-SI.pdf  (1.4MB, pdf)         n/a        d67e776
#
#                                  section_class  \
# 0                                          NaN
# 0  pmc-layout__citation font-secondary font-xs
# 8                                      media p
#
#                                        download_link file_extension  \
# 0                                                NaN           None
# 0                                               None           None
# 8  https://www.ncbi.nlm.nih.gov/pmc/articles/inst...            pdf
#
#                                          a_attr_href  \
# 0                                                NaN
# 0      https://doi.org/10.1021/acs.jproteome.4c00338
# 8  /articles/instance/11425778/bin/NIHMS2020672-s...
#
#                   a_attr_class a_attr_data-ga-action a_attr_target  \
# 0                          NaN                   NaN           NaN
# 0  usa-link usa-link--external      click_feat_suppl        _blank
# 8                     usa-link      click_feat_suppl           NaN
#
#             a_attr_rel                                         source_url  \
# 0                  NaN  https://www.ncbi.nlm.nih.gov/pmc/articles/pmc1...
# 0  noopener noreferrer  https://www.ncbi.nlm.nih.gov/pmc/articles/pmc1...
# 8                  NaN  https://www.ncbi.nlm.nih.gov/pmc/articles/pmc1...
#
#         pub_title
# 0  No title found
# 0  No title found
# 8  No title found

# %%
results_RTR = data_gatherer.parse_data(API_unsupported_input, raw_html, publisher="Nature", use_portkey_for_gemini=True, prompt_name="retrieve_datasets_simple_JSON", raw_data_format ="HTML", semantic_retrieval=True)
results_RTR
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#   dataset_identifier          data_repository  \
# 0          GSE269782                      geo
# 1           GSE31210                      geo
# 2          GSE106765                      geo
# 3           GSE60189                      geo
# 4           GSE59239                      geo
# 5          GSE122005                      geo
# 6           GSE38121                      geo
# 7           GSE71587                      geo
# 8           GSE37699                      geo
# 9          PXD051771  www.proteomexchange.org
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
#
#                                      dataset_webpage       access_mode  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 5  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 6  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 7  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 8  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 9  https://www.proteomexchange.org/cgi/GetDataset...  Complex download
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0  https://static-content.springer.com/esm/art%3A...
# 1  https://static-content.springer.com/esm/art%3A...
# 2  https://static-content.springer.com/esm/art%3A...
# 3  https://static-content.springer.com/esm/art%3A...
#
#                        title file_info description source_section  \
# 0                        NaN       NaN         NaN            NaN
# 1                        NaN       NaN         NaN            NaN
# 2                        NaN       NaN         NaN            NaN
# 3                        NaN       NaN         NaN            NaN
# 4                        NaN       NaN         NaN            NaN
# 5                        NaN       NaN         NaN            NaN
# 6                        NaN       NaN         NaN            NaN
# 7                        NaN       NaN         NaN            NaN
# 8                        NaN       NaN         NaN            NaN
# 9                        NaN       NaN         NaN            NaN
# 0  Supplementary Information       n/a         n/a         MOESM1
# 1           Peer Review File       n/a         n/a         MOESM2
# 2          Reporting Summary       n/a         n/a         MOESM3
# 3                Source data       n/a         n/a         MOESM4
#
#                    section_class  ... file_extension a_attr_class  \
# 0                            NaN  ...           None          NaN
# 1                            NaN  ...           None          NaN
# 2                            NaN  ...           None          NaN
# 3                            NaN  ...           None          NaN
# 4                            NaN  ...           None          NaN
# 5                            NaN  ...           None          NaN
# 6                            NaN  ...           None          NaN
# 7                            NaN  ...           None          NaN
# 8                            NaN  ...           None          NaN
# 9                            NaN  ...           None          NaN
# 0  c-article-supplementary__item  ...            pdf   print-link
# 1  c-article-supplementary__item  ...            pdf   print-link
# 2  c-article-supplementary__item  ...            pdf   print-link
# 3  c-article-supplementary__item  ...           xlsx   print-link
#
#   a_attr_data-track a_attr_data-track-action a_attr_data-test  \
# 0               NaN                      NaN              NaN
# 1               NaN                      NaN              NaN
# 2               NaN                      NaN              NaN
# 3               NaN                      NaN              NaN
# 4               NaN                      NaN              NaN
# 5               NaN                      NaN              NaN
# 6               NaN                      NaN              NaN
# 7               NaN                      NaN              NaN
# 8               NaN                      NaN              NaN
# 9               NaN                      NaN              NaN
# 0             click  view supplementary info   supp-info-link
# 1             click  view supplementary info   supp-info-link
# 2             click  view supplementary info   supp-info-link
# 3             click  view supplementary info   supp-info-link
#
#      a_attr_data-track-label  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 0  supplementary information
# 1           peer review file
# 2          reporting summary
# 3                source data
#
#                                          a_attr_href  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0  https://static-content.springer.com/esm/art%3A...
# 1  https://static-content.springer.com/esm/art%3A...
# 2  https://static-content.springer.com/esm/art%3A...
# 3  https://static-content.springer.com/esm/art%3A...
#
#   a_attr_data-supp-info-image  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 0
# 1
# 2
# 3
#
#                                           source_url       pub_title
# 0  https://www.nature.com/articles/s41467-024-518...  No title found
# 1  https://www.nature.com/articles/s41467-024-518...  No title found
# 2  https://www.nature.com/articles/s41467-024-518...  No title found
# 3  https://www.nature.com/articles/s41467-024-518...  No title found
# 4  https://www.nature.com/articles/s41467-024-518...  No title found
# 5  https://www.nature.com/articles/s41467-024-518...  No title found
# 6  https://www.nature.com/articles/s41467-024-518...  No title found
# 7  https://www.nature.com/articles/s41467-024-518...  No title found
# 8  https://www.nature.com/articles/s41467-024-518...  No title found
# 9  https://www.nature.com/articles/s41467-024-518...  No title found
# 0  https://www.nature.com/articles/s41467-024-518...  No title found
# 1  https://www.nature.com/articles/s41467-024-518...  No title found
# 2  https://www.nature.com/articles/s41467-024-518...  No title found
# 3  https://www.nature.com/articles/s41467-024-518...  No title found
#
# [14 rows x 21 columns]

# %% [markdown]
# ### Full-Document-Read

# %%
results_FDR = data_gatherer.parse_data(API_unsupported_input, raw_html, publisher="Nature", prompt_name="GPT_from_full_input_Examples", full_document_read=True, raw_data_format="HTML")
results_FDR
# Out:
#   dataset_identifier          data_repository  \
# 0           GSE31210                      geo
# 1          GSE269782                      geo
# 2          GSE106765                      geo
# 3           GSE60189                      geo
# 4           GSE59239                      geo
# 5          GSE122005                      geo
# 6           GSE38121                      geo
# 7           GSE71587                      geo
# 8           GSE37699                      geo
# 9          PXD051771  www.proteomexchange.org
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
#
#                                      dataset_webpage       access_mode  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 5  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 6  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 7  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 8  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Complex download
# 9  https://www.proteomexchange.org/cgi/GetDataset...  Complex download
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0  https://static-content.springer.com/esm/art%3A...
# 1  https://static-content.springer.com/esm/art%3A...
# 2  https://static-content.springer.com/esm/art%3A...
# 3  https://static-content.springer.com/esm/art%3A...
#
#                        title file_info description source_section  \
# 0                        NaN       NaN         NaN            NaN
# 1                        NaN       NaN         NaN            NaN
# 2                        NaN       NaN         NaN            NaN
# 3                        NaN       NaN         NaN            NaN
# 4                        NaN       NaN         NaN            NaN
# 5                        NaN       NaN         NaN            NaN
# 6                        NaN       NaN         NaN            NaN
# 7                        NaN       NaN         NaN            NaN
# 8                        NaN       NaN         NaN            NaN
# 9                        NaN       NaN         NaN            NaN
# 0  Supplementary Information       n/a         n/a         MOESM1
# 1           Peer Review File       n/a         n/a         MOESM2
# 2          Reporting Summary       n/a         n/a         MOESM3
# 3                Source data       n/a         n/a         MOESM4
#
#                    section_class  ... file_extension a_attr_class  \
# 0                            NaN  ...           None          NaN
# 1                            NaN  ...           None          NaN
# 2                            NaN  ...           None          NaN
# 3                            NaN  ...           None          NaN
# 4                            NaN  ...           None          NaN
# 5                            NaN  ...           None          NaN
# 6                            NaN  ...           None          NaN
# 7                            NaN  ...           None          NaN
# 8                            NaN  ...           None          NaN
# 9                            NaN  ...           None          NaN
# 0  c-article-supplementary__item  ...            pdf   print-link
# 1  c-article-supplementary__item  ...            pdf   print-link
# 2  c-article-supplementary__item  ...            pdf   print-link
# 3  c-article-supplementary__item  ...           xlsx   print-link
#
#   a_attr_data-track a_attr_data-track-action a_attr_data-test  \
# 0               NaN                      NaN              NaN
# 1               NaN                      NaN              NaN
# 2               NaN                      NaN              NaN
# 3               NaN                      NaN              NaN
# 4               NaN                      NaN              NaN
# 5               NaN                      NaN              NaN
# 6               NaN                      NaN              NaN
# 7               NaN                      NaN              NaN
# 8               NaN                      NaN              NaN
# 9               NaN                      NaN              NaN
# 0             click  view supplementary info   supp-info-link
# 1             click  view supplementary info   supp-info-link
# 2             click  view supplementary info   supp-info-link
# 3             click  view supplementary info   supp-info-link
#
#      a_attr_data-track-label  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 0  supplementary information
# 1           peer review file
# 2          reporting summary
# 3                source data
#
#                                          a_attr_href  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0  https://static-content.springer.com/esm/art%3A...
# 1  https://static-content.springer.com/esm/art%3A...
# 2  https://static-content.springer.com/esm/art%3A...
# 3  https://static-content.springer.com/esm/art%3A...
#
#   a_attr_data-supp-info-image  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 0
# 1
# 2
# 3
#
#                                           source_url       pub_title
# 0  https://www.nature.com/articles/s41467-024-518...  No title found
# 1  https://www.nature.com/articles/s41467-024-518...  No title found
# 2  https://www.nature.com/articles/s41467-024-518...  No title found
# 3  https://www.nature.com/articles/s41467-024-518...  No title found
# 4  https://www.nature.com/articles/s41467-024-518...  No title found
# 5  https://www.nature.com/articles/s41467-024-518...  No title found
# 6  https://www.nature.com/articles/s41467-024-518...  No title found
# 7  https://www.nature.com/articles/s41467-024-518...  No title found
# 8  https://www.nature.com/articles/s41467-024-518...  No title found
# 9  https://www.nature.com/articles/s41467-024-518...  No title found
# 0  https://www.nature.com/articles/s41467-024-518...  No title found
# 1  https://www.nature.com/articles/s41467-024-518...  No title found
# 2  https://www.nature.com/articles/s41467-024-518...  No title found
# 3  https://www.nature.com/articles/s41467-024-518...  No title found
#
# [14 rows x 21 columns]

# %%
parsed_data = {"results_RTR" : results_RTR, "results_FDR": results_FDR}

# %% [markdown]
# ## Step III: Classify data
#
# For now, we are only considering raw data files, i.e. those objects that can be accessed from a repository with an accession code. However, the classifier can be extended to include other types of objects, such as supplementary materials.

# %%
print(f"Fetched from {len(parsed_data)} publications.")
raw_data_files = data_gatherer.classifier.get_raw_data_files(parsed_data)
print(f"Fetched {len(raw_data_files)} raw data files:")
# Out:
# Fetched from 2 publications.
# Fetched 20 raw data files:

# %%
raw_data_files
# Out:
#    publication_url dataset_identifier          data_repository  \
# 0      results_RTR          GSE269782                      geo
# 1      results_RTR           GSE31210                      geo
# 2      results_RTR          GSE106765                      geo
# 3      results_RTR           GSE60189                      geo
# 4      results_RTR           GSE59239                      geo
# 5      results_RTR          GSE122005                      geo
# 6      results_RTR           GSE38121                      geo
# 7      results_RTR           GSE71587                      geo
# 8      results_RTR           GSE37699                      geo
# 9      results_RTR          PXD051771  www.proteomexchange.org
# 14     results_FDR           GSE31210                      geo
# 15     results_FDR          GSE269782                      geo
# 16     results_FDR          GSE106765                      geo
# 17     results_FDR           GSE60189                      geo
# 18     results_FDR           GSE59239                      geo
# 19     results_FDR          GSE122005                      geo
# 20     results_FDR           GSE38121                      geo
# 21     results_FDR           GSE71587                      geo
# 22     results_FDR           GSE37699                      geo
# 23     results_FDR          PXD051771  www.proteomexchange.org
#
#                                       dataset_webpage
# 0   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 5   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 6   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 7   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 8   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 9   https://www.proteomexchange.org/cgi/GetDataset...
# 14  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 15  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 16  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 17  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 18  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 19  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 20  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 21  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 22  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 23  https://www.proteomexchange.org/cgi/GetDataset...
